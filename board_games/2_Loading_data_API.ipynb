# %% [markdown]
# # Data load II.
#
# ### What the code does:
# * This code loads the data from the Board Game Atlas API and creates a csv file

# %% [markdown]
# **Import libraries**

# %%
import pandas as pd
import requests
import json
import time
import math

# %% [markdown]
# ### API call options:
# * In general search we can specify over 40 parameters such as: designer, publisher, maximum price etc.
# * One call can return maximum 100 responses.
# * If we search for name, it will return board games whose name contain the string specified (even if exact parameter is set to True).

# %% [markdown]
# ### Technical notes:
# * The full list of codes in this workbook could run for about 30-50 minutes (depending on connection to API server), most of which is from the two API calls.

# %%
# Get category list - Sample
total_url = 'https://api.boardgameatlas.com/api/search?pretty=true&client_id=6MXavgYBke'
total_response = requests.get(total_url)
total_dict = json.loads(total_response.text)

# %%
# Total number of board games listed
total_dict['count']
# Out:
# 142173

# %% [markdown]
# ### Main issues:
# * With the highest limit 100, it would take 1421 calls to return all games listed.
# * However, the majority of games are depreciated without too much valuable information.
# * If we were to search by name, we could only get 1 game at a time.
# * Therefore, we decided to look for parameters that partition the results and likely return valuable information.
# * For starters, we looked into games with categories listed

# %% [markdown]
# **Get games by categories**

# %%
# Get category list - Sample
categ_url = 'https://api.boardgameatlas.com/api/game/categories?client_id=6MXavgYBke'
categ_response = requests.get(categ_url)
categ_dict = json.loads(categ_response.text)
list(categ_dict.values())[0][0]
# Out:
# {'id': '2bdFPJUvFo',
#  'name': '18XX',
#  'url': 'https://www.boardgameatlas.com/category/2bdFPJUvFo/18xx'}

# %%
# Get category ids
categ_ids = []
for cat_num in list(range(0,len(categ_dict['categories']))):
    categ_ids.append(categ_dict['categories'][cat_num]['id'])
categ_ids[1:15]
# Out:
# ['85OKv8p5Ow',
#  'hBqZ3Ar4RJ',
#  'GtuMb7ei27',
#  'OE07lsfVqf',
#  'KUBCKBkGxV',
#  'DjAhqEHOD0',
#  '20iDvpbh7A',
#  'tJxatX2ZbW',
#  'nWDac9tQzt',
#  'dghLhwyxVb',
#  '4mOtRRwSoj',
#  'a8NM5cugJX',
#  'MWoxgHrOJD',
#  'eFaACC6y2c']

# %%
# Number of categories
len(categ_ids)
# Out:
# 156

# %% [markdown]
# #### 2. Request board game data using the category ids

# %%
# Sample request
categ_url = 'https://api.boardgameatlas.com/api/search?client_id=6MXavgYBke&limit=100&categories=2bdFPJUvFo'
response = requests.get(categ_url)
games_dict = json.loads(response.text)
list(games_dict.values())[0][0]
# Out:
# {'id': 'o6knI5ct0u',
#  'handle': 'mayfair-games-1830-railways-and-robber-barons--north-east-us',
#  'url': 'https://www.boardgameatlas.com/game/o6knI5ct0u/mayfair-games-1830-railways-and-robber-barons--north-east-us',
#  'edit_url': 'https://www.boardgameatlas.com/game/o6knI5ct0u/edit',
#  'name': '1830: Railways & Robber Barons',
#  'price': '52.99',
#  'price_ca': '74.99',
#  'price_uk': '50.15',
#  'price_au': '89.95',
#  'msrp': 69.99,
#  'msrps': [{'country': 'US', 'price': 69.99}],
#  'discount': '0.24',
#  'year_published': 1986,
#  'min_players': 2,
#  'max_players': 7,
#  'min_playtime': 180,
#  'max_playtime': 360,
#  'min_age': 14,
#  'description': "<p>1830. It is the dawn of the &quot;Age of Railroading&quot; in America. You're a wealthy investor and speculator betting that the new technology will revolutionize transport. Commerce will no longer depend on rutted roads and slow canals. Instead, it will ride the rails on swift, powerful &quot;Iron Horses.&quot;</p>\r\n<p><strong>1830</strong> is an acclaimed railroad investment and building game covering the years 1830 to present. You and your fellow players become the stockholders of America's first railroad corporations. Since the largest shareholder becomes president, you compete for control of the strongest firms. As president, generate revenue by building track and buying and operating trains-regardless of shareholders' needs. Meanwhile, you pay heed to the volatile stock market. You strive to invest in flourishing companies in order to earn healthy dividends. You try to buy stock in corporations that are rising in value, collect strong, and sell before the stock values drop.</p>\r\n<p>Get ready to be a railroad baron. Start investing and building. Become America's first great rail tycoon!</p>\r\n<p>The 2011 version of <em>1830</em> was published by Mayfair Games in partnership with Lookout Games of Germany. This publication was developed under license from Francis Tresham in co-operation with Bruce Shelley (the original <em>1830</em> developer). This version contains rules and components for Francis Tresham's original classic design, a faster-playing basic game, and new variants from some of the world's best railroad game developers.</p>",
#  'commentary': '',
#  'faq': '',
#  'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559257858925-51BztJ2q4WL.jpg',
#  'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559257858925-51BztJ2q4WL.jpg',
#  'matches_specs': None,
#  'specs': [],
#  'mechanics': [{'id': 'AZxlPpi5oq',
#    'url': 'https://www.boardgameatlas.com/mechanic/AZxlPpi5oq/undefined'},
#   {'id': 'issXRWXSLg',
#    'url': 'https://www.boardgameatlas.com/mechanic/issXRWXSLg/undefined'},
#   {'id': 'BeD8NYAaSU',
#    'url': 'https://www.boardgameatlas.com/mechanic/BeD8NYAaSU/undefined'},
#   {'id': 'ohABM4GjbC',
#    'url': 'https://www.boardgameatlas.com/mechanic/ohABM4GjbC/undefined'},
#   {'id': 'jbLrZb1xIb',
#    'url': 'https://www.boardgameatlas.com/mechanic/jbLrZb1xIb/undefined'},
#   {'id': '8PN2HE86wg',
#    'url': 'https://www.boardgameatlas.com/mechanic/8PN2HE86wg/undefined'}],
#  'categories': [{'id': '2bdFPJUvFo',
#    'url': 'https://www.boardgameatlas.com/category/2bdFPJUvFo/undefined'},
#   {'id': 'N0TkEGfEsF',
#    'url': 'https://www.boardgameatlas.com/category/N0TkEGfEsF/undefined'},
#   {'id': 'JwHcKqxh33',
#    'url': 'https://www.boardgameatlas.com/category/JwHcKqxh33/undefined'},
#   {'id': 'CWYOF9xu7O',
#    'url': 'https://www.boardgameatlas.com/category/CWYOF9xu7O/undefined'}],
#  'publishers': [{'id': 'w1jOf2uAOD',
#    'num_games': None,
#    'score': 9999999,
#    'game': {},
#    'url': 'https://www.boardgameatlas.com/publisher/w1jOf2uAOD/undefined',
#    'images': {'thumb': None,
#     'small': None,
#     'medium': None,
#     'large': None,
#     'original': None}},
#   {'id': 'r2R8bUHIRD',
#    'num_games': None,
#    'score': 9999999,
#    'game': {},
#    'url': 'https://www.boardgameatlas.com/publisher/r2R8bUHIRD/undefined',
#    'images': {'thumb': None,
#     'small': None,
#     'medium': None,
#     'large': None,
#     'original': None}},
#   {'id': 'oQcGa4viSd',
#    'num_games': None,
#    'score': 9999999,
#    'game': {},
#    'url': 'https://www.boardgameatlas.com/publisher/oQcGa4viSd/undefined',
#    'images': {'thumb': None,
#     'small': None,
#     'medium': None,
#     'large': None,
#     'original': None}},
#   {'id': '7GTti1NuCH',
#    'num_games': None,
#    'score': 9999999,
#    'game': {},
#    'url': 'https://www.boardgameatlas.com/publisher/7GTti1NuCH/undefined',
#    'images': {'thumb': None,
#     'small': None,
#     'medium': None,
#     'large': None,
#     'original': None}},
#   {'id': 'j3lCGDByb2',
#    'num_games': None,
#    'score': 9999999,
#    'game': {},
#    'url': 'https://www.boardgameatlas.com/publisher/j3lCGDByb2/undefined',
#    'images': {'thumb': None,
#     'small': None,
#     'medium': None,
#     'large': None,
#     'original': None}}],
#  'designers': [{'id': 'RpZJ6vqsPR',
#    'num_games': None,
#    'score': 9999999,
#    'game': {},
#    'url': 'https://www.boardgameatlas.com/designer/RpZJ6vqsPR/undefined',
#    'images': {'thumb': None,
#     'small': None,
#     'medium': None,
#     'large': None,
#     'original': None}}],
#  'primary_publisher': {'id': 'w1jOf2uAOD',
#   'name': 'The Avalon Hill Game Co',
#   'url': 'https://www.boardgameatlas.com/publisher/w1jOf2uAOD/the-avalon-hill-game-co'},
#  'primary_designer': {'id': 'RpZJ6vqsPR',
#   'name': 'Francis Tresham',
#   'url': 'https://www.boardgameatlas.com/designer/RpZJ6vqsPR/francis-tresham'},
#  'developers': [],
#  'related_to': [],
#  'artists': ['Mike Atkinson',
#   'Jared Blando',
#   'Charles Kibler',
#   'James Talbot',
#   'Mark Zug'],
#  'names': [],
#  'rules_url': 'https://lookout-spiele.de/wp-content/uploads/1830_Spielregeln_EN_WEB.pdf',
#  'amazon_rank': 559911,
#  'official_url': 'http://www.mayfairgames.com/products/1830-north-east-us?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#  'sell_sheet_url': None,
#  'store_images_url': None,
#  'comment_count': 0,
#  'num_user_ratings': 36,
#  'average_user_rating': 4.006944444444444,
#  'historical_low_prices': [{'country': 'UK',
#    'date': '2021-12-18T12:07:52.735Z',
#    'price': 50.15,
#    'isLow': False},
#   {'country': 'AU',
#    'date': '2022-01-18T12:30:39.425Z',
#    'price': 89.95,
#    'isLow': False},
#   {'country': 'CA',
#    'date': '2022-03-08T15:27:32.086Z',
#    'price': 74.99,
#    'isLow': False},
#   {'country': 'US',
#    'date': '2022-03-21T12:52:51.418Z',
#    'price': 52.99,
#    'isLow': False}],
#  'active': True,
#  'num_user_complexity_votes': 2,
#  'average_learning_complexity': 3,
#  'average_strategy_complexity': 4.5,
#  'visits': 1920,
#  'lists': 273,
#  'mentions': 4,
#  'links': 0,
#  'plays': 244,
#  'rank': 874,
#  'type': 'game',
#  'num_distributors': 1,
#  'trending_rank': 0,
#  'listing_clicks': 0,
#  'is_historical_low': False,
#  'players': '2-7',
#  'playtime': '180-360',
#  'msrp_text': '$69.99',
#  'price_text': '$52.99',
#  'tags': ["1830: Ferrovie e Capitani d'Industria",
#   '1830: Schienenleger & Spekulanten',
#   '1830: The Game of Railroads and Robber Barons',
#   '1830 Revised Edition',
#   '1830 Railways Robber Barons Revised Edition',
#   '1830 (Revised Edition) [Pre-Order]',
#   '1830 Revised Edition Dent Ding',
#   '1830 Railways and Robber Barons',
#   '1830 Railways Robber Barons',
#   '1830: Railways & Robber Barons (Lookout Games Edition)',
#   '1830',
#   '1830 The Game of Railroads and Robber Barons'],
#  'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1559257858925-51BztJ2q4WL.jpg',
#   'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1559257858925-51BztJ2q4WL.jpg',
#   'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1559257858925-51BztJ2q4WL.jpg',
#   'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1559257858925-51BztJ2q4WL.jpg',
#   'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559257858925-51BztJ2q4WL.jpg'},
#  'description_preview': ' 1830. It is the dawn of the "Age of Railroading" in America. You\'re a wealthy investor and speculator betting that the new technology will revolutionize transport. Commerce will no longer depend on rutted roads and slow canals. Instead, it will ride the rails on swift, powerful "Iron Horses." \r\n  1830  is an acclaimed railroad investment and building game covering the years 1830 to present. You and your fellow players become the stockholders of America\'s first railroad corporations. Since the largest shareholder becomes president, you compete for control of the strongest firms. As president, generate revenue by building track and buying and operating trains-regardless of shareholders\' needs. Meanwhile, you pay heed to the volatile stock market. You strive to invest in flourishing companies in order to earn healthy dividends. You try to buy stock in corporations that are rising in value, collect strong, and sell before the stock values drop. \r\n Get ready to be a railroad baron. Start investing and building. Become America\'s first great rail tycoon! \r\n The 2011 version of  1830  was published by Mayfair Games in partnership with Lookout Games of Germany. This publication was developed under license from Francis Tresham in co-operation with Bruce Shelley (the original  1830  developer). This version contains rules and components for Francis Tresham\'s original classic design, a faster-playing basic game, and new variants from some of the world\'s best railroad game developers. '}

# %% [markdown]
# ### Further issues:
# * A single category may contain thousands of results.
# * In theory we can skip any number results, but in practice the maximum skip value allowed is 1000.
# * Therefore, with any call returning maximum 100 results, in total we can obtain up-to 1100 results from any category.

# %%
# Get board games
categ_df = pd.DataFrame()
for category_id in categ_ids:
    next_categ_url = 'https://api.boardgameatlas.com/api/search?client_id=6MXavgYBke&limit=100&categories={}'.format(category_id)
    next_response = requests.get(next_categ_url)
    next_games_dict = json.loads(next_response.text)
    categ_df = categ_df.append(pd.DataFrame(next_games_dict['games']))
    time.sleep(1)
    # This is how we specify getting 1100 results.
    if next_games_dict['count'] > 1000:
        for hundred in list(range(1,11)):
            limit = 100 * hundred
            next_categ_url = 'https://api.boardgameatlas.com/api/search?client_id=6MXavgYBke&limit=100&categories={}&skip={}'.format(
                category_id , limit)
            next_response = requests.get(next_categ_url)
            next_games_dict = json.loads(next_response.text)
            categ_df = categ_df.append(pd.DataFrame(next_games_dict['games']))
            time.sleep(1)
    elif next_games_dict['count'] > 100:
        for hundred in list(range(1,(math.ceil(next_games_dict['count'] / 100)))):
            limit = 100 * hundred
            next_categ_url = 'https://api.boardgameatlas.com/api/search?client_id=6MXavgYBke&limit=100&categories={}&skip={}'.format(
                category_id , limit)
            next_response = requests.get(next_categ_url)
            next_games_dict = json.loads(next_response.text)
            categ_df = categ_df.append(pd.DataFrame(next_games_dict['games']))
            time.sleep(1)

# %%
pd.options.display.max_columns = None
display(categ_df.head())
# Out:
#            id                                             handle  \
# 0  o6knI5ct0u  mayfair-games-1830-railways-and-robber-barons-...
# 1  eSCVHuUFPs                      1846-the-race-for-the-midwest
# 2  uEPtE5OOOU         1862-railway-mania-in-the-eastern-counties
# 3  Krn8i8C0fI                                       18chesapeake
# 4  eJuGpFzljd          184454-switzerland-and-austria-board-game
#
#                                                  url  \
# 0  https://www.boardgameatlas.com/game/o6knI5ct0u...
# 1  https://www.boardgameatlas.com/game/eSCVHuUFPs...
# 2  https://www.boardgameatlas.com/game/uEPtE5OOOU...
# 3  https://www.boardgameatlas.com/game/Krn8i8C0fI...
# 4  https://www.boardgameatlas.com/game/eJuGpFzljd...
#
#                                             edit_url  \
# 0  https://www.boardgameatlas.com/game/o6knI5ct0u...
# 1  https://www.boardgameatlas.com/game/eSCVHuUFPs...
# 2  https://www.boardgameatlas.com/game/uEPtE5OOOU...
# 3  https://www.boardgameatlas.com/game/Krn8i8C0fI...
# 4  https://www.boardgameatlas.com/game/eJuGpFzljd...
#
#                                           name  price price_ca price_uk  \
# 0               1830: Railways & Robber Barons  52.99    74.99    50.15
# 1               1846: The Race for the Midwest  46.99    67.95     0.00
# 2  1862: Railway Mania in the Eastern Counties  57.99    79.95     0.00
# 3                                 18Chesapeake   0.00     0.00     0.00
# 4                                  1844 / 1854  75.99   112.95     0.00
#
#   price_au   msrp                                              msrps discount  \
# 0    89.95  69.99                [{'country': 'US', 'price': 69.99}]     0.24
# 1     0.00   69.0  [{'country': 'US', 'price': 69}, {'country': '...     0.32
# 2   127.99   79.0                   [{'country': 'US', 'price': 79}]     0.27
# 3     0.00   89.0  [{'country': 'US', 'price': 89}, {'country': '...     0.00
# 4     0.00  94.99  [{'country': 'UK', 'price': 87.99}, {'country'...     0.20
#
#    year_published  min_players  max_players  min_playtime  max_playtime  \
# 0          1986.0          2.0          7.0         180.0         360.0
# 1          2005.0          3.0          5.0         240.0         240.0
# 2          2013.0          1.0          8.0         300.0         300.0
# 3          2020.0          2.0          6.0         180.0         180.0
# 4          2016.0          3.0          7.0         300.0         300.0
#
#    min_age                                        description commentary faq  \
# 0     14.0  <p>1830. It is the dawn of the &quot;Age of Ra...
# 1     14.0  <p>1846 - the midwest railroad boom has gone b...
# 2     12.0  <p>1862: Railway Mania in the Eastern Counties...
# 3     13.0  <p>18Chesapeake is a member of the <a href="ht...
# 4     12.0  <p>The railway history of both Switzerland and...
#
#                                            thumb_url  \
# 0  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 1  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 2  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 3  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 4  https://s3-us-west-1.amazonaws.com/5cc.images/...
#
#                                            image_url matches_specs specs  \
# 0  https://s3-us-west-1.amazonaws.com/5cc.images/...          None    []
# 1  https://s3-us-west-1.amazonaws.com/5cc.images/...          None    []
# 2  https://s3-us-west-1.amazonaws.com/5cc.images/...          None    []
# 3  https://s3-us-west-1.amazonaws.com/5cc.images/...          None    []
# 4  https://s3-us-west-1.amazonaws.com/5cc.images/...          None    []
#
#                                            mechanics  \
# 0  [{'id': 'AZxlPpi5oq', 'url': 'https://www.boar...
# 1  [{'id': 'AZxlPpi5oq', 'url': 'https://www.boar...
# 2  [{'id': 'qCXa8MX0wk', 'url': 'https://www.boar...
# 3  [{'id': 'AZxlPpi5oq', 'url': 'https://www.boar...
# 4  [{'id': 'ohABM4GjbC', 'url': 'https://www.boar...
#
#                                           categories  \
# 0  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...
# 1  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...
# 2  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...
# 3  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...
# 4  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...
#
#                                           publishers  \
# 0  [{'id': 'w1jOf2uAOD', 'num_games': None, 'scor...
# 1  [{'id': 'VKIPDDgZ2X', 'num_games': None, 'scor...
# 2  [{'id': 'd5oY0duBgG', 'num_games': None, 'scor...
# 3  [{'id': 'ZOP4wDStJq', 'num_games': None, 'scor...
# 4  [{'id': '7GTti1NuCH', 'num_games': None, 'scor...
#
#                                            designers  \
# 0  [{'id': 'RpZJ6vqsPR', 'num_games': None, 'scor...
# 1  [{'id': 'CeUZNYVdQj', 'num_games': None, 'scor...
# 2  [{'id': 'xMrDEmBdTo', 'num_games': None, 'scor...
# 3  [{'id': 'fN0XCgUAPZ', 'num_games': None, 'scor...
# 4  [{'id': 'gFwNqit3MM', 'num_games': None, 'scor...
#
#                                    primary_publisher  \
# 0  {'id': 'w1jOf2uAOD', 'name': 'The Avalon Hill ...
# 1  {'id': 'VKIPDDgZ2X', 'name': 'Deep Thought Gam...
# 2  {'name': 'GMT Games', 'id': 'd5oY0duBgG', 'url...
# 3  {'id': 'ZOP4wDStJq', 'name': 'All-Aboard Games...
# 4  {'name': 'Mayfair Games', 'id': '7GTti1NuCH', ...
#
#                                     primary_designer developers related_to  \
# 0  {'id': 'RpZJ6vqsPR', 'name': 'Francis Tresham'...         []         []
# 1  {'id': 'CeUZNYVdQj', 'name': 'Thomas Lehmann',...         []         []
# 2  {'name': 'Mike Hutton', 'id': 'xMrDEmBdTo', 'u...         []         []
# 3  {'id': 'fN0XCgUAPZ', 'name': 'Scott Petersen',...         []         []
# 4  {'name': 'Helmut Ohley', 'id': 'gFwNqit3MM', '...         []         []
#
#                                              artists names  \
# 0  [Mike Atkinson, Jared Blando, Charles Kibler, ...    []
# 1  [Chris Lawson, Rodger B. MacGowan, Kurt Miller...    []
# 2                                      [Mike Hutton]    []
# 3                              [Brigette Indelicato]    []
# 4                                    [Klemens Franz]    []
#
#                                            rules_url  amazon_rank  \
# 0  https://lookout-spiele.de/wp-content/uploads/1...     559911.0
# 1  https://s3-us-west-2.amazonaws.com/gmtwebsitea...     125448.0
# 2  https://gmtwebsiteassets.s3-us-west-2.amazonaw...          NaN
# 3                                               None          NaN
# 4                                               None     473334.0
#
#                                         official_url sell_sheet_url  \
# 0  http://www.mayfairgames.com/products/1830-nort...            NaN
# 1  https://www.gmtgames.com/p-847-1846-the-race-t...            NaN
# 2  https://www.gmtgames.com/p-692-1862-railway-ma...            NaN
# 3  https://all-aboardgames.com/products/us-only-1...            NaN
# 4                                               None            NaN
#
#   store_images_url  comment_count  num_user_ratings  average_user_rating  \
# 0              NaN              0                36             4.006944
# 1              NaN              0                37             3.885135
# 2              NaN              0                 9             4.111111
# 3              NaN              0                11             4.454545
# 4              NaN              0                 6             4.000000
#
#                                historical_low_prices  active  \
# 0  [{'country': 'UK', 'date': '2021-12-18T12:07:5...    True
# 1  [{'country': 'UK', 'date': '2021-12-14T18:14:1...    True
# 2  [{'country': 'UK', 'date': '2021-12-11T11:48:1...    True
# 3  [{'country': 'US', 'date': '2022-02-08T01:34:2...    True
# 4  [{'country': 'UK', 'date': '2021-12-03T08:56:5...    True
#
#    num_user_complexity_votes  average_learning_complexity  \
# 0                          2                          3.0
# 1                          1                          4.0
# 2                          0                          0.0
# 3                          1                          3.0
# 4                          0                          0.0
#
#    average_strategy_complexity  visits  lists  mentions  links  plays  \
# 0                          4.5    1920    273         4      0    244
# 1                          4.0    1095    228         2      0    316
# 2                          0.0    1077    123        13      1     71
# 3                          4.0     874    172         1      0    161
# 4                          0.0     507     51         0      0      5
#
#       rank  type  num_distributors  trending_rank  listing_clicks  \
# 0      874  game                 1              0               0
# 1      927  game                 3              0              11
# 2  9999999  game                 2              0               0
# 3  9999999  game                 0              0               0
# 4  9999999  game                 0              0               0
#
#    is_historical_low players playtime msrp_text  price_text  \
# 0              False     2-7  180-360    $69.99      $52.99
# 1              False     3-5      240    $69.00      $46.99
# 2              False     1-8      300    $79.00      $57.99
# 3              False     2-6      180    $89.00  Price: N/A
# 4              False     3-7      300    $94.99      $75.99
#
#                                                 tags  \
# 0  [1830: Ferrovie e Capitani d'Industria, 1830: ...
# 1  [1846 The Race to the Midwest Printing, 1846: ...
# 2  [1862: Railway Mania in the Eastern Counties, ...
# 3                                     [18Chesapeake]
# 4  [1844/1854 Switzerland/Austria, 1844/1854, 184...
#
#                                               images  \
# 0  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...
# 1  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...
# 2  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...
# 3  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...
# 4  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...
#
#                                  description_preview      sku           upc  \
# 0   1830. It is the dawn of the "Age of Railroadi...      NaN           NaN
# 1   1846 - the midwest railroad boom has gone bus...  GMT1605  817054011155
# 2   1862: Railway Mania in the Eastern Counties i...  GMT1904  817054011704
# 3   18Chesapeake is a member of the  18xx  series...      NaN           NaN
# 4   The railway history of both Switzerland and A...      NaN           NaN
#
#                        skus  \
# 0                       NaN
# 1  [2149184041, 2149209107]
# 2              [2149191519]
# 3                       NaN
# 4                       NaN
#
#                                          sku_objects  size_height  size_depth  \
# 0                                                NaN          NaN         NaN
# 1  [{'name': 'Noble Knight Games', 'sku': '214918...          NaN         NaN
# 2  [{'name': 'Noble Knight Games', 'sku': '214919...          9.0         3.0
# 3                                                NaN          NaN         NaN
# 4                                                NaN          NaN         NaN
#
#    cs_rating  weight_amount weight_units  size_width isbn availability_status  \
# 0        NaN            NaN          NaN         NaN  NaN                 NaN
# 1        NaN            NaN          NaN         NaN  NaN                 NaN
# 2        NaN            NaN          NaN         NaN  NaN                 NaN
# 3        NaN            NaN          NaN         NaN  NaN                 NaN
# 4        NaN            NaN          NaN         NaN  NaN                 NaN
#
#   size_units video_links
# 0        NaN         NaN
# 1        NaN         NaN
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN

# %%
# Number of games 
len(categ_df)
# Out:
# 16815

# %%
# Feature list
categ_df.dtypes
# Out:
# id                      object
# handle                  object
# url                     object
# edit_url                object
# name                    object
#                         ...
# size_width             float64
# isbn                    object
# availability_status     object
# size_units              object
# video_links             object
# Length: 80, dtype: object

# %% [markdown]
# #### 3. Keep only the needed fields

# %%
# Keep only useful fields
categ_df_short = categ_df.loc[:, categ_df.columns.isin([
    'artists',
    'average_learning_complexity',
    'average_strategy_complexity',
    'average_user_rating',
    'categories',
    'comment_count',
    'description',
    'description_preview',
    'designers',
    'discount',
    'id',
    'is_historical_low',
    'listing_clicks',
    'max_players',
    'max_playtime',
    'min_age',
    'min_players',
    'min_playtime',
    'name',
    'num_user_ratings',
    'players',
    'plays',
    'playtime',
    'price',
    'price_au',
    'price_ca',
    'price_uk',
    'primary_publisher',
    'publishers',
    'visits',
    'year_published'  
])]

# %%
categ_df_short.isnull().sum()
# Out:
# id                                0
# name                              0
# price                             0
# price_ca                          0
# price_uk                          0
# price_au                          0
# discount                          0
# year_published                 2086
# min_players                    1350
# max_players                    1350
# min_playtime                   1931
# max_playtime                   1934
# min_age                        2128
# description                       0
# categories                        0
# publishers                        0
# designers                         0
# primary_publisher               747
# artists                           0
# comment_count                     0
# num_user_ratings                  0
# average_user_rating               0
# average_learning_complexity       0
# average_strategy_complexity       0
# visits                            0
# plays                             0
# listing_clicks                    0
# is_historical_low                 0
# players                        1391
# playtime                       2115
# description_preview               0
# dtype: int64

# %% [markdown]
# #### 4. Data cleaning

# %%
# Lowercase name
categ_df_short['name_lower']=categ_df_short['name'].str.lower()
# Out:
# C:\Users\abogn\AppData\Local\Temp/ipykernel_3140/3815326140.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categ_df_short['name_lower']=categ_df_short['name'].str.lower()

# %%
# Remove original fields
categ_df_short = categ_df_short.loc[:, ~categ_df_short.columns.isin(['artists', 'primary_publisher', 'categories', 'designers', 'publishers', 'description', 'description_preview'])]

# %%
# Feature list
categ_df_short.dtypes
# Out:
# id                              object
# name                            object
# price                           object
# price_ca                        object
# price_uk                        object
# price_au                        object
# discount                        object
# year_published                 float64
# min_players                    float64
# max_players                    float64
# min_playtime                   float64
# max_playtime                   float64
# min_age                        float64
# comment_count                    int64
# num_user_ratings                 int64
# average_user_rating            float64
# average_learning_complexity    float64
# average_strategy_complexity    float64
# visits                           int64
# plays                            int64
# listing_clicks                   int64
# is_historical_low                 bool
# players                         object
# playtime                        object
# name_lower                      object
# dtype: object

# %%
pd.options.display.max_columns = None
categ_df_short.head()
# Out:
#            id                                         name  price price_ca  \
# 0  o6knI5ct0u               1830: Railways & Robber Barons  52.99    74.99
# 1  eSCVHuUFPs               1846: The Race for the Midwest  46.99    67.95
# 2  uEPtE5OOOU  1862: Railway Mania in the Eastern Counties  57.99    79.95
# 3  Krn8i8C0fI                                 18Chesapeake   0.00     0.00
# 4  eJuGpFzljd                                  1844 / 1854  75.99   112.95
#
#   price_uk price_au discount  year_published  min_players  max_players  \
# 0    50.15    89.95     0.24          1986.0          2.0          7.0
# 1     0.00     0.00     0.32          2005.0          3.0          5.0
# 2     0.00   127.99     0.27          2013.0          1.0          8.0
# 3     0.00     0.00     0.00          2020.0          2.0          6.0
# 4     0.00     0.00     0.20          2016.0          3.0          7.0
#
#    min_playtime  max_playtime  min_age  comment_count  num_user_ratings  \
# 0         180.0         360.0     14.0              0                36
# 1         240.0         240.0     14.0              0                37
# 2         300.0         300.0     12.0              0                 9
# 3         180.0         180.0     13.0              0                11
# 4         300.0         300.0     12.0              0                 6
#
#    average_user_rating  average_learning_complexity  \
# 0             4.006944                          3.0
# 1             3.885135                          4.0
# 2             4.111111                          0.0
# 3             4.454545                          3.0
# 4             4.000000                          0.0
#
#    average_strategy_complexity  visits  plays  listing_clicks  \
# 0                          4.5    1920    244               0
# 1                          4.0    1095    316              11
# 2                          0.0    1077     71               0
# 3                          4.0     874    161               0
# 4                          0.0     507      5               0
#
#    is_historical_low players playtime  \
# 0              False     2-7  180-360
# 1              False     3-5      240
# 2              False     1-8      300
# 3              False     2-6      180
# 4              False     3-7      300
#
#                                     name_lower
# 0               1830: railways & robber barons
# 1               1846: the race for the midwest
# 2  1862: railway mania in the eastern counties
# 3                                 18chesapeake
# 4                                  1844 / 1854

# %% [markdown]
# #### 5. Remove duplicates

# %%
# Remove duplicates
no_duplicate_categ_df = categ_df_short[~categ_df_short.duplicated(subset=['name_lower', 'year_published'])]

# %%
len(no_duplicate_categ_df)
# Out:
# 8135

# %%
pd.options.display.max_columns = None
no_duplicate_categ_df.head()
# Out:
#            id                                         name  price price_ca  \
# 0  o6knI5ct0u               1830: Railways & Robber Barons  52.99    74.99
# 1  eSCVHuUFPs               1846: The Race for the Midwest  46.99    67.95
# 2  uEPtE5OOOU  1862: Railway Mania in the Eastern Counties  57.99    79.95
# 3  Krn8i8C0fI                                 18Chesapeake   0.00     0.00
# 4  eJuGpFzljd                                  1844 / 1854  75.99   112.95
#
#   price_uk price_au discount  year_published  min_players  max_players  \
# 0    50.15    89.95     0.24          1986.0          2.0          7.0
# 1     0.00     0.00     0.32          2005.0          3.0          5.0
# 2     0.00   127.99     0.27          2013.0          1.0          8.0
# 3     0.00     0.00     0.00          2020.0          2.0          6.0
# 4     0.00     0.00     0.20          2016.0          3.0          7.0
#
#    min_playtime  max_playtime  min_age  comment_count  num_user_ratings  \
# 0         180.0         360.0     14.0              0                36
# 1         240.0         240.0     14.0              0                37
# 2         300.0         300.0     12.0              0                 9
# 3         180.0         180.0     13.0              0                11
# 4         300.0         300.0     12.0              0                 6
#
#    average_user_rating  average_learning_complexity  \
# 0             4.006944                          3.0
# 1             3.885135                          4.0
# 2             4.111111                          0.0
# 3             4.454545                          3.0
# 4             4.000000                          0.0
#
#    average_strategy_complexity  visits  plays  listing_clicks  \
# 0                          4.5    1920    244               0
# 1                          4.0    1095    316              11
# 2                          0.0    1077     71               0
# 3                          4.0     874    161               0
# 4                          0.0     507      5               0
#
#    is_historical_low players playtime  \
# 0              False     2-7  180-360
# 1              False     3-5      240
# 2              False     1-8      300
# 3              False     2-6      180
# 4              False     3-7      300
#
#                                     name_lower
# 0               1830: railways & robber barons
# 1               1846: the race for the midwest
# 2  1862: railway mania in the eastern counties
# 3                                 18chesapeake
# 4                                  1844 / 1854

# %% [markdown]
# #### 5. Load More data

# %% [markdown]
# ### Considerations:
# * So far we have less names than in the original csv and we haven't matched names yet.
# * To increase data we tried the second categorical variables in the API call, which is the list of mechanics in a game.

# %%
# The call is very similar, but this time we only select the fields we know we will use, you can specify this at the API call.

field_list = ""
for list_item in list(categ_df_short.columns):
    field_list = field_list + "," + list_item
field_list = field_list[1:]
field_list = field_list[:-11]
field_list
# Out:
# 'id,name,price,price_ca,price_uk,price_au,discount,year_published,min_players,max_players,min_playtime,max_playtime,min_age,comment_count,num_user_ratings,average_user_rating,average_learning_complexity,average_strategy_complexity,visits,plays,listing_clicks,is_historical_low,players,playtime'

# %%
# Get mechanics list 
mechanics_url = 'https://api.boardgameatlas.com/api/game/mechanics?pretty=true&client_id=6MXavgYBke'
mechanics_response = requests.get(mechanics_url)
mechanics_dict = json.loads(mechanics_response.text)

# %%
# Get mechanics ids
mechanics_ids = []
for mech_num in list(range(0,len(mechanics_dict['mechanics']))):
    mechanics_ids.append(mechanics_dict['mechanics'][mech_num]['id'])

# %%
# Get board games
mech_df = pd.DataFrame()
for mech_id in mechanics_ids:
    next_mech_url = 'https://api.boardgameatlas.com/api/search?client_id=6MXavgYBke&limit=100&mechanics={}&fields={}'.format(mech_id,field_list)
    next_response = requests.get(next_mech_url)
    next_games_dict = json.loads(next_response.text)
    mech_df = mech_df.append(pd.DataFrame(next_games_dict['games']))
    time.sleep(1)
    if next_games_dict['count'] > 1000:
        for hundred in list(range(1,11)):
            limit = 100 * hundred
            next_mech_url = 'https://api.boardgameatlas.com/api/search?client_id=6MXavgYBke&limit=100&mechanics={}&skip={}&fields={}'.format(mech_id , limit, field_list)
            next_response = requests.get(next_mech_url)
            next_games_dict = json.loads(next_response.text)
            mech_df = mech_df.append(pd.DataFrame(next_games_dict['games']))
            time.sleep(1)
    elif next_games_dict['count'] > 100:
        for hundred in list(range(1,(math.ceil(next_games_dict['count'] / 100)))):
            limit = 100 * hundred
            next_mech_url = 'https://api.boardgameatlas.com/api/search?client_id=6MXavgYBke&limit=100&mechanics={}&skip={}&fields={}'.format(mech_id , limit, field_list)
            next_response = requests.get(next_mech_url)
            next_games_dict = json.loads(next_response.text)
            mech_df = mech_df.append(pd.DataFrame(next_games_dict['games']))
            time.sleep(1)

# %%
# Add lower name
mech_df_names = mech_df.copy()
mech_df_names['name_lower'] = mech_df_names['name'].str.lower()

# %%
# Remove duplicates

print(len(mech_df_names))
no_duplicate_mech_df = mech_df_names[~mech_df_names.duplicated(subset=['name_lower', 'year_published'])]
no_duplicate_mech_df = no_duplicate_mech_df.reset_index()
len(no_duplicate_mech_df)
# Out:
# 38405
# 16638

# %% [markdown]
# #### 6. Finalizing results

# %% [markdown]
# ### Other options:
# * We managed to get a lot more results with the second query
# * Our final option would be to request make individual requests based on game names, but it would take too long.
# * Therefore, the last step is to join the category and mechnism tables and save the results.

# %%
board_games_api = pd.concat( [no_duplicate_categ_df, no_duplicate_mech_df])
pd.options.display.max_columns = None
board_games_api.head()
# Out:
#            id                                         name  price price_ca  \
# 0  o6knI5ct0u               1830: Railways & Robber Barons  52.99    74.99
# 1  eSCVHuUFPs               1846: The Race for the Midwest  46.99    67.95
# 2  uEPtE5OOOU  1862: Railway Mania in the Eastern Counties  57.99    79.95
# 3  Krn8i8C0fI                                 18Chesapeake   0.00     0.00
# 4  eJuGpFzljd                                  1844 / 1854  75.99   112.95
#
#   price_uk price_au discount  year_published  min_players  max_players  \
# 0    50.15    89.95     0.24          1986.0          2.0          7.0
# 1     0.00     0.00     0.32          2005.0          3.0          5.0
# 2     0.00   127.99     0.27          2013.0          1.0          8.0
# 3     0.00     0.00     0.00          2020.0          2.0          6.0
# 4     0.00     0.00     0.20          2016.0          3.0          7.0
#
#    min_playtime  max_playtime  min_age  comment_count  num_user_ratings  \
# 0         180.0         360.0     14.0              0                36
# 1         240.0         240.0     14.0              0                37
# 2         300.0         300.0     12.0              0                 9
# 3         180.0         180.0     13.0              0                11
# 4         300.0         300.0     12.0              0                 6
#
#    average_user_rating  average_learning_complexity  \
# 0             4.006944                          3.0
# 1             3.885135                          4.0
# 2             4.111111                          0.0
# 3             4.454545                          3.0
# 4             4.000000                          0.0
#
#    average_strategy_complexity  visits  plays  listing_clicks  \
# 0                          4.5    1920    244               0
# 1                          4.0    1095    316              11
# 2                          0.0    1077     71               0
# 3                          4.0     874    161               0
# 4                          0.0     507      5               0
#
#    is_historical_low players playtime  \
# 0              False     2-7  180-360
# 1              False     3-5      240
# 2              False     1-8      300
# 3              False     2-6      180
# 4              False     3-7      300
#
#                                     name_lower  index
# 0               1830: railways & robber barons    NaN
# 1               1846: the race for the midwest    NaN
# 2  1862: railway mania in the eastern counties    NaN
# 3                                 18chesapeake    NaN
# 4                                  1844 / 1854    NaN

# %%
# Remove duplicates

print(len(board_games_api))
board_games_api = board_games_api[~board_games_api.duplicated(subset=['id'])]
len(board_games_api)
# Out:
# 24773
# 20156

# %%
# Save dataset 
board_games_api.to_csv("2loading_output.csv", sep=',' , quotechar='"')

# %% [markdown]
# ### Final note:
# * Our approach to API calls netted over 20k results under 30 minutes which is much faster than individual requests.
# * However, our selection was not random, we could only query the first 1100 results of any category/mechanism.
# * Upon further investigation, we found that results are ordered by relevance and the ending pages we could not access contain
# mainly missing information.
# * Consider the last page of [card games category](https://www.boardgameatlas.com/category/eX8uuNlQkQ/card-game?skip=1900&categories=eX8uuNlQkQ): most prices and other relevant information are missing.
# * As you will see in further notebooks, we would likely discard most of these results for our analysis, therefore the issue of representation would not be resolved with more APi calls.
