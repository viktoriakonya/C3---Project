# %% [markdown]
# **Import libraries**

# %%
import pandas as pd
import requests
import json
import time
import math

# %% [markdown]
# #### **I. Load raw data from tidyTuesday**

# %%
# Import data
board_games_raw = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2019/2019-03-12/board_games.csv")

# %%
# Check data
board_games_raw.head()
# Out:
#    game_id                                        description  \
# 0        1  Die Macher is a game about seven sequential po...
# 1        2  Dragonmaster is a trick-taking card game based...
# 2        3  Part of the Knizia tile-laying trilogy, Samura...
# 3        4  When you see the triangular box and the luxuri...
# 4        5  In Acquire, each player strategically invests ...
#
#                                           image  max_players  max_playtime  \
# 0   //cf.geekdo-images.com/images/pic159509.jpg            5           240
# 1   //cf.geekdo-images.com/images/pic184174.jpg            4            30
# 2  //cf.geekdo-images.com/images/pic3211873.jpg            4            60
# 3   //cf.geekdo-images.com/images/pic285299.jpg            4            60
# 4   //cf.geekdo-images.com/images/pic342163.jpg            6            90
#
#    min_age  min_players  min_playtime            name  playing_time  ...  \
# 0       14            3           240      Die Macher           240  ...
# 1       12            3            30    Dragonmaster            30  ...
# 2       10            2            30         Samurai            60  ...
# 3       12            2            60  Tal der Könige            60  ...
# 4       12            3            90         Acquire            90  ...
#
#                         artist                        category compilation  \
# 0          Marcus Gschwendtner  Economic,Negotiation,Political         NaN
# 1                   Bob Pepper               Card Game,Fantasy         NaN
# 2              Franz Vohwinkel      Abstract Strategy,Medieval         NaN
# 3                          NaN                         Ancient         NaN
# 4  Scott Okumura,Peter Whitley                        Economic         NaN
#
#                 designer expansion  \
# 0     Karl-Heinz Schmiel       NaN
# 1  G. W. "Jerry" D'Arcey       NaN
# 2          Reiner Knizia       NaN
# 3      Christian Beierer       NaN
# 4            Sid Sackson       NaN
#
#                                               family  \
# 0         Country: Germany,Valley Games Classic Line
# 1                                   Animals: Dragons
# 2  Asian Theme,Country: Japan,Knizia tile-laying ...
# 3             Country: Egypt,Promotional Board Games
# 4                                3M Bookshelf Series
#
#                                             mechanic  \
# 0  Area Control / Area Influence,Auction/Bidding,...
# 1                                       Trick-taking
# 2  Area Control / Area Influence,Hand Management,...
# 3  Action Point Allowance System,Area Control / A...
# 4       Hand Management,Stock Holding,Tile Placement
#
#                                            publisher average_rating  \
# 0  Hans im Glück Verlags-GmbH,Moskito Spiele,Vall...        7.66508
# 1                           E.S. Lowe,Milton Bradley        6.60815
# 2  999 Games,ABACUSSPIELE,Astrel Games,Ceilikan J...        7.44119
# 3                                             KOSMOS        6.60675
# 4  3M,Avalon Hill,Avalon Hill (Hasbro),Dujardin,G...        7.35830
#
#   users_rated
# 0        4498
# 1         478
# 2       12019
# 3         314
# 4       15195
#
# [5 rows x 22 columns]

# %%
len(board_games_raw)
# Out:
# 10532

# %%
# Lowercase name
board_games_raw['name_lower']=board_games_raw['name'].str.lower()

# %%
board_games_raw.head()
# Out:
#    game_id                                        description  \
# 0        1  Die Macher is a game about seven sequential po...
# 1        2  Dragonmaster is a trick-taking card game based...
# 2        3  Part of the Knizia tile-laying trilogy, Samura...
# 3        4  When you see the triangular box and the luxuri...
# 4        5  In Acquire, each player strategically invests ...
#
#                                           image  max_players  max_playtime  \
# 0   //cf.geekdo-images.com/images/pic159509.jpg            5           240
# 1   //cf.geekdo-images.com/images/pic184174.jpg            4            30
# 2  //cf.geekdo-images.com/images/pic3211873.jpg            4            60
# 3   //cf.geekdo-images.com/images/pic285299.jpg            4            60
# 4   //cf.geekdo-images.com/images/pic342163.jpg            6            90
#
#    min_age  min_players  min_playtime            name  playing_time  ...  \
# 0       14            3           240      Die Macher           240  ...
# 1       12            3            30    Dragonmaster            30  ...
# 2       10            2            30         Samurai            60  ...
# 3       12            2            60  Tal der Könige            60  ...
# 4       12            3            90         Acquire            90  ...
#
#                          category  compilation               designer  \
# 0  Economic,Negotiation,Political          NaN     Karl-Heinz Schmiel
# 1               Card Game,Fantasy          NaN  G. W. "Jerry" D'Arcey
# 2      Abstract Strategy,Medieval          NaN          Reiner Knizia
# 3                         Ancient          NaN      Christian Beierer
# 4                        Economic          NaN            Sid Sackson
#
#   expansion                                             family  \
# 0       NaN         Country: Germany,Valley Games Classic Line
# 1       NaN                                   Animals: Dragons
# 2       NaN  Asian Theme,Country: Japan,Knizia tile-laying ...
# 3       NaN             Country: Egypt,Promotional Board Games
# 4       NaN                                3M Bookshelf Series
#
#                                             mechanic  \
# 0  Area Control / Area Influence,Auction/Bidding,...
# 1                                       Trick-taking
# 2  Area Control / Area Influence,Hand Management,...
# 3  Action Point Allowance System,Area Control / A...
# 4       Hand Management,Stock Holding,Tile Placement
#
#                                            publisher average_rating  \
# 0  Hans im Glück Verlags-GmbH,Moskito Spiele,Vall...        7.66508
# 1                           E.S. Lowe,Milton Bradley        6.60815
# 2  999 Games,ABACUSSPIELE,Astrel Games,Ceilikan J...        7.44119
# 3                                             KOSMOS        6.60675
# 4  3M,Avalon Hill,Avalon Hill (Hasbro),Dujardin,G...        7.35830
#
#   users_rated      name_lower
# 0        4498      die macher
# 1         478    dragonmaster
# 2       12019         samurai
# 3         314  tal der könige
# 4       15195         acquire
#
# [5 rows x 23 columns]

# %%
# Check number of nulls
board_games_raw.isnull().sum()
# Out:
# game_id               0
# description           0
# image                 1
# max_players           0
# max_playtime          0
# min_age               0
# min_players           0
# min_playtime          0
# name                  0
# playing_time          0
# thumbnail             1
# year_published        0
# artist             2773
# category             94
# compilation       10122
# designer            126
# expansion          7780
# family             2808
# mechanic            950
# publisher             3
# average_rating        0
# users_rated           0
# name_lower            0
# dtype: int64

# %%
# Keep only useful fields
board_games_raw = board_games_raw.loc[:, ~board_games_raw.columns.isin(['image', 'thumbnail', 'compilation', ])]

# %%
# Todo: 
#  - unlist family, mechanic, publisher

# %%
# Save dataset 
board_games_raw.to_csv("board_games_raw.csv", sep=';' , quotechar='"')

# %% [markdown]
# **II. Call API**

# %%
# Get category list
categ_url = 'https://api.boardgameatlas.com/api/game/categories?client_id=6MXavgYBke'
categ_response = requests.get(categ_url)
categ_dict = json.loads(categ_response.text)
categ_dict
# Out:
# {'categories': [{'id': '2bdFPJUvFo',
#    'name': '18XX',
#    'url': 'https://www.boardgameatlas.com/category/2bdFPJUvFo/18xx'},
#   {'id': '85OKv8p5Ow',
#    'name': '4x',
#    'url': 'https://www.boardgameatlas.com/category/85OKv8p5Ow/4x'},
#   {'id': 'hBqZ3Ar4RJ',
#    'name': 'Abstract',
#    'url': 'https://www.boardgameatlas.com/category/hBqZ3Ar4RJ/abstract'},
#   {'id': 'KUBCKBkGxV',
#    'name': 'Adventure',
#    'url': 'https://www.boardgameatlas.com/category/KUBCKBkGxV/adventure'},
#   {'id': 'DjAhqEHOD0',
#    'name': 'Aerial Warfare',
#    'url': 'https://www.boardgameatlas.com/category/DjAhqEHOD0/aerial-warfare'},
#   {'id': '20iDvpbh7A',
#    'name': 'Age of Reason',
#    'url': 'https://www.boardgameatlas.com/category/20iDvpbh7A/age-of-reason'},
#   {'id': 'tJxatX2ZbW',
#    'name': 'Aliens',
#    'url': 'https://www.boardgameatlas.com/category/tJxatX2ZbW/aliens'},
#   {'id': 'nWDac9tQzt',
#    'name': 'Alternate History',
#    'url': 'https://www.boardgameatlas.com/category/nWDac9tQzt/alternate-history'},
#   {'id': 'dghLhwyxVb',
#    'name': 'American History',
#    'url': 'https://www.boardgameatlas.com/category/dghLhwyxVb/american-history'},
#   {'id': '4mOtRRwSoj',
#    'name': 'American West',
#    'url': 'https://www.boardgameatlas.com/category/4mOtRRwSoj/american-west'},
#   {'id': 'a8NM5cugJX',
#    'name': 'Ancient',
#    'url': 'https://www.boardgameatlas.com/category/a8NM5cugJX/ancient'},
#   {'id': 'MWoxgHrOJD',
#    'name': 'Animals',
#    'url': 'https://www.boardgameatlas.com/category/MWoxgHrOJD/animals'},
#   {'id': 'eFaACC6y2c',
#    'name': 'Apocalyptic',
#    'url': 'https://www.boardgameatlas.com/category/eFaACC6y2c/apocalyptic'},
#   {'id': 'CBboNLI1Uj',
#    'name': 'Arabian',
#    'url': 'https://www.boardgameatlas.com/category/CBboNLI1Uj/arabian'},
#   {'id': 'k0dglq5j6N',
#    'name': 'Art',
#    'url': 'https://www.boardgameatlas.com/category/k0dglq5j6N/art'},
#   {'id': 'Bq6M0TJyg7',
#    'name': 'Asymmetric',
#    'url': 'https://www.boardgameatlas.com/category/Bq6M0TJyg7/asymmetric'},
#   {'id': 'QB4sEpx1Uu',
#    'name': 'Aviation',
#    'url': 'https://www.boardgameatlas.com/category/QB4sEpx1Uu/aviation'},
#   {'id': 'wpItJuRDiz',
#    'name': 'Banking',
#    'url': 'https://www.boardgameatlas.com/category/wpItJuRDiz/banking'},
#   {'id': 'PinhJrhnxU',
#    'name': 'Bluffing',
#    'url': 'https://www.boardgameatlas.com/category/PinhJrhnxU/bluffing'},
#   {'id': 'fW5vusE96B',
#    'name': 'Campaign',
#    'url': 'https://www.boardgameatlas.com/category/fW5vusE96B/campaign'},
#   {'id': 'eX8uuNlQkQ',
#    'name': 'Card Game',
#    'url': 'https://www.boardgameatlas.com/category/eX8uuNlQkQ/card-game'},
#   {'id': 'HKaYVNIxAJ',
#    'name': "Children's Game",
#    'url': 'https://www.boardgameatlas.com/category/HKaYVNIxAJ/childrens-game'},
#   {'id': '36WFElclV3',
#    'name': 'Christian',
#    'url': 'https://www.boardgameatlas.com/category/36WFElclV3/christian'},
#   {'id': 'ODWOjWAJj3',
#    'name': 'City Building',
#    'url': 'https://www.boardgameatlas.com/category/ODWOjWAJj3/city-building'},
#   {'id': 'w8XD66FUZ2',
#    'name': 'Civil War',
#    'url': 'https://www.boardgameatlas.com/category/w8XD66FUZ2/civil-war'},
#   {'id': '329DxyFL9D',
#    'name': 'Civilization',
#    'url': 'https://www.boardgameatlas.com/category/329DxyFL9D/civilization'},
#   {'id': 'bVMxJo31bS',
#    'name': 'Cold war',
#    'url': 'https://www.boardgameatlas.com/category/bVMxJo31bS/cold-war'},
#   {'id': 'vXxLT0FDTZ',
#    'name': 'Collectible Components',
#    'url': 'https://www.boardgameatlas.com/category/vXxLT0FDTZ/collectible-components'},
#   {'id': 'bSzUpE5oOZ',
#    'name': 'Colonial',
#    'url': 'https://www.boardgameatlas.com/category/bSzUpE5oOZ/colonial'},
#   {'id': 'gscaL52VDG',
#    'name': 'Combat',
#    'url': 'https://www.boardgameatlas.com/category/gscaL52VDG/combat'},
#   {'id': 'G5kfqnPBP6',
#    'name': 'Comic Book / Strip',
#    'url': 'https://www.boardgameatlas.com/category/G5kfqnPBP6/comic-book--strip'},
#   {'id': 'pacCjl7His',
#    'name': 'Competitive',
#    'url': 'https://www.boardgameatlas.com/category/pacCjl7His/competitive'},
#   {'id': 'ge8pIhEUGE',
#    'name': 'Cooperative',
#    'url': 'https://www.boardgameatlas.com/category/ge8pIhEUGE/cooperative'},
#   {'id': '7DfHn28Pcf',
#    'name': 'Crime',
#    'url': 'https://www.boardgameatlas.com/category/7DfHn28Pcf/crime'},
#   {'id': 'nfQONtMbDU',
#    'name': 'Cube Rail',
#    'url': 'https://www.boardgameatlas.com/category/nfQONtMbDU/cube-rail'},
#   {'id': 'Ef4oYLHNhI',
#    'name': 'Cyberpunk',
#    'url': 'https://www.boardgameatlas.com/category/Ef4oYLHNhI/cyberpunk'},
#   {'id': 'bCBXJy9qDw',
#    'name': 'Deduction',
#    'url': 'https://www.boardgameatlas.com/category/bCBXJy9qDw/deduction'},
#   {'id': 'bKrxqD9mYc',
#    'name': 'Dexterity',
#    'url': 'https://www.boardgameatlas.com/category/bKrxqD9mYc/dexterity'},
#   {'id': 'mavSOM8vjH',
#    'name': 'Dice',
#    'url': 'https://www.boardgameatlas.com/category/mavSOM8vjH/dice'},
#   {'id': '42pmul4oHH',
#    'name': 'Dinosaurs',
#    'url': 'https://www.boardgameatlas.com/category/42pmul4oHH/dinosaurs'},
#   {'id': 'We3MM46qBr',
#    'name': 'Drinking',
#    'url': 'https://www.boardgameatlas.com/category/We3MM46qBr/drinking'},
#   {'id': 'g2Hwv8t0Y5',
#    'name': 'Dungeon Crawl',
#    'url': 'https://www.boardgameatlas.com/category/g2Hwv8t0Y5/dungeon-crawl'},
#   {'id': 'N0TkEGfEsF',
#    'name': 'Economic',
#    'url': 'https://www.boardgameatlas.com/category/N0TkEGfEsF/economic'},
#   {'id': 'B3NRLMK4xD',
#    'name': 'Educational',
#    'url': 'https://www.boardgameatlas.com/category/B3NRLMK4xD/educational'},
#   {'id': 'crxgUzJSEz',
#    'name': 'Electronic',
#    'url': 'https://www.boardgameatlas.com/category/crxgUzJSEz/electronic'},
#   {'id': 'gsekjrPJz0',
#    'name': 'Environmental',
#    'url': 'https://www.boardgameatlas.com/category/gsekjrPJz0/environmental'},
#   {'id': 'u5ZiYctU6T',
#    'name': 'Espionage',
#    'url': 'https://www.boardgameatlas.com/category/u5ZiYctU6T/espionage'},
#   {'id': 'v4SfYtS2Lr',
#    'name': 'Expansion',
#    'url': 'https://www.boardgameatlas.com/category/v4SfYtS2Lr/expansion'},
#   {'id': 'yq6hVlbM2R',
#    'name': 'Exploration',
#    'url': 'https://www.boardgameatlas.com/category/yq6hVlbM2R/exploration'},
#   {'id': '7rV11PKqME',
#    'name': 'Family Game',
#    'url': 'https://www.boardgameatlas.com/category/7rV11PKqME/family-game'},
#   {'id': 'ctumBZyj5l',
#    'name': 'Fan Made',
#    'url': 'https://www.boardgameatlas.com/category/ctumBZyj5l/fan-made'},
#   {'id': 'ZTneo8TaIO',
#    'name': 'Fantasy',
#    'url': 'https://www.boardgameatlas.com/category/ZTneo8TaIO/fantasy'},
#   {'id': 'Wr8uXcoR9p',
#    'name': 'Farming',
#    'url': 'https://www.boardgameatlas.com/category/Wr8uXcoR9p/farming'},
#   {'id': 'upXZ8vNfNO',
#    'name': 'Fighting',
#    'url': 'https://www.boardgameatlas.com/category/upXZ8vNfNO/fighting'},
#   {'id': 'ELg06sncRX',
#    'name': 'Finance',
#    'url': 'https://www.boardgameatlas.com/category/ELg06sncRX/finance'},
#   {'id': 'YrDuNj8lvr',
#    'name': 'Food',
#    'url': 'https://www.boardgameatlas.com/category/YrDuNj8lvr/food'},
#   {'id': 'JvIs75sWte',
#    'name': 'Game System',
#    'url': 'https://www.boardgameatlas.com/category/JvIs75sWte/game-system'},
#   {'id': 'Eyuf8PzjDo',
#    'name': 'Gulf War',
#    'url': 'https://www.boardgameatlas.com/category/Eyuf8PzjDo/gulf-war'},
#   {'id': 'KzEQIwIub7',
#    'name': 'Historic',
#    'url': 'https://www.boardgameatlas.com/category/KzEQIwIub7/historic'},
#   {'id': 'cAIkk5aLdQ',
#    'name': 'Horror',
#    'url': 'https://www.boardgameatlas.com/category/cAIkk5aLdQ/horror'},
#   {'id': 'TYnxiuiI3X',
#    'name': 'Humor',
#    'url': 'https://www.boardgameatlas.com/category/TYnxiuiI3X/humor'},
#   {'id': 'zqFmdU4Fp2',
#    'name': 'Industry/Manufacturing',
#    'url': 'https://www.boardgameatlas.com/category/zqFmdU4Fp2/industrymanufacturing'},
#   {'id': 'rrvd68LjOR',
#    'name': 'Kickstarter',
#    'url': 'https://www.boardgameatlas.com/category/rrvd68LjOR/kickstarter'},
#   {'id': '3souLOXUqI',
#    'name': 'Korean War',
#    'url': 'https://www.boardgameatlas.com/category/3souLOXUqI/korean-war'},
#   {'id': 'AGKGd3txp9',
#    'name': 'Law',
#    'url': 'https://www.boardgameatlas.com/category/AGKGd3txp9/law'},
#   {'id': 'XeYUw9159M',
#    'name': 'Legacy',
#    'url': 'https://www.boardgameatlas.com/category/XeYUw9159M/legacy'},
#   {'id': 'HZ7kUiqEbs',
#    'name': 'Letters',
#    'url': 'https://www.boardgameatlas.com/category/HZ7kUiqEbs/letters'},
#   {'id': 'GCwXmvBCvA',
#    'name': 'Mad Scientist',
#    'url': 'https://www.boardgameatlas.com/category/GCwXmvBCvA/mad-scientist'},
#   {'id': 'pIMmuVYnQp',
#    'name': 'Mafia',
#    'url': 'https://www.boardgameatlas.com/category/pIMmuVYnQp/mafia'},
#   {'id': 'POlqwScVxD',
#    'name': 'Math',
#    'url': 'https://www.boardgameatlas.com/category/POlqwScVxD/math'},
#   {'id': 'ZhlfIPxYsw',
#    'name': 'Mature / Adult',
#    'url': 'https://www.boardgameatlas.com/category/ZhlfIPxYsw/mature--adult'},
#   {'id': 'ruQAhyLfum',
#    'name': 'Maze',
#    'url': 'https://www.boardgameatlas.com/category/ruQAhyLfum/maze'},
#   {'id': 'AeWXMxbm91',
#    'name': 'Medical',
#    'url': 'https://www.boardgameatlas.com/category/AeWXMxbm91/medical'},
#   {'id': 'QAYkTHK1Dd',
#    'name': 'Medieval',
#    'url': 'https://www.boardgameatlas.com/category/QAYkTHK1Dd/medieval'},
#   {'id': 'AujCle9cUq',
#    'name': 'Memory',
#    'url': 'https://www.boardgameatlas.com/category/AujCle9cUq/memory'},
#   {'id': 'Cc10AY9UX5',
#    'name': 'Mental Health',
#    'url': 'https://www.boardgameatlas.com/category/Cc10AY9UX5/mental-health'},
#   {'id': 'FC6ElKI9tk',
#    'name': 'Miniatures',
#    'url': 'https://www.boardgameatlas.com/category/FC6ElKI9tk/miniatures'},
#   {'id': 'L6NUwNdblq',
#    'name': 'Modern Warfare',
#    'url': 'https://www.boardgameatlas.com/category/L6NUwNdblq/modern-warfare'},
#   {'id': 'Sod2YBWMKi',
#    'name': 'Movies / TV / Radio theme',
#    'url': 'https://www.boardgameatlas.com/category/Sod2YBWMKi/movies--tv--radio-theme'},
#   {'id': 'Kk70K0524Z',
#    'name': 'Murder/Mystery',
#    'url': 'https://www.boardgameatlas.com/category/Kk70K0524Z/murdermystery'},
#   {'id': 'herNFAxMdz',
#    'name': 'Music',
#    'url': 'https://www.boardgameatlas.com/category/herNFAxMdz/music'},
#   {'id': 'MHkqIVxwtx',
#    'name': 'Mythology',
#    'url': 'https://www.boardgameatlas.com/category/MHkqIVxwtx/mythology'},
#   {'id': 'IpcJzp0TVC',
#    'name': 'Napoleonic',
#    'url': 'https://www.boardgameatlas.com/category/IpcJzp0TVC/napoleonic'},
#   {'id': 'vqZ5XzGWQD',
#    'name': 'Nautical',
#    'url': 'https://www.boardgameatlas.com/category/vqZ5XzGWQD/nautical'},
#   {'id': 'jZEDOpx07e',
#    'name': 'Negotiation',
#    'url': 'https://www.boardgameatlas.com/category/jZEDOpx07e/negotiation'},
#   {'id': 'rtslXnT90O',
#    'name': 'Ninjas',
#    'url': 'https://www.boardgameatlas.com/category/rtslXnT90O/ninjas'},
#   {'id': 'dO9HVl2TW7',
#    'name': 'Novel-based',
#    'url': 'https://www.boardgameatlas.com/category/dO9HVl2TW7/novelbased'},
#   {'id': '9r6mtYVCAZ',
#    'name': 'Number',
#    'url': 'https://www.boardgameatlas.com/category/9r6mtYVCAZ/number'},
#   {'id': 'TCYEfWLB8c',
#    'name': 'One vs Many',
#    'url': 'https://www.boardgameatlas.com/category/TCYEfWLB8c/one-vs-many'},
#   {'id': 'X8J7RM6dxX',
#    'name': 'Party Game',
#    'url': 'https://www.boardgameatlas.com/category/X8J7RM6dxX/party-game'},
#   {'id': 'UL3b9M86gA',
#    'name': 'Pike and Shot',
#    'url': 'https://www.boardgameatlas.com/category/UL3b9M86gA/pike-and-shot'},
#   {'id': '9EIayX6n5a',
#    'name': 'Pirates',
#    'url': 'https://www.boardgameatlas.com/category/9EIayX6n5a/pirates'},
#   {'id': 'vRbkg1W0AB',
#    'name': 'Plants/Gardening',
#    'url': 'https://www.boardgameatlas.com/category/vRbkg1W0AB/plants-gardening'},
#   {'id': 'TKQncFVX74',
#    'name': 'Political',
#    'url': 'https://www.boardgameatlas.com/category/TKQncFVX74/political'},
#   {'id': '8Z7nWG2kOw',
#    'name': 'Post-Apocalyptic',
#    'url': 'https://www.boardgameatlas.com/category/8Z7nWG2kOw/postapocalyptic'},
#   {'id': '5APB1MWk6X',
#    'name': 'Post-Napoleonic',
#    'url': 'https://www.boardgameatlas.com/category/5APB1MWk6X/postnapoleonic'},
#   {'id': 'YyszHun1HP',
#    'name': 'Prehistoric',
#    'url': 'https://www.boardgameatlas.com/category/YyszHun1HP/prehistoric'},
#   {'id': 'ov6sEmlkiC',
#    'name': 'Print & Play',
#    'url': 'https://www.boardgameatlas.com/category/ov6sEmlkiC/print--play'},
#   {'id': 'dAyk5NtNTV',
#    'name': 'Prison Escape',
#    'url': 'https://www.boardgameatlas.com/category/dAyk5NtNTV/prison-escape'},
#   {'id': 'WVMOS3s2pb',
#    'name': 'Puzzle',
#    'url': 'https://www.boardgameatlas.com/category/WVMOS3s2pb/puzzle'},
#   {'id': '2Gu62aKdma',
#    'name': 'RPG',
#    'url': 'https://www.boardgameatlas.com/category/2Gu62aKdma/rpg'},
#   {'id': 'tQGLgwdbYH',
#    'name': 'Racing',
#    'url': 'https://www.boardgameatlas.com/category/tQGLgwdbYH/racing'},
#   {'id': 'PzWI2uaif0',
#    'name': 'Real-time',
#    'url': 'https://www.boardgameatlas.com/category/PzWI2uaif0/realtime'},
#   {'id': 'DRqeVkXWqX',
#    'name': 'Religious',
#    'url': 'https://www.boardgameatlas.com/category/DRqeVkXWqX/religious'},
#   {'id': 'nuHYRFmMjU',
#    'name': 'Renaissance',
#    'url': 'https://www.boardgameatlas.com/category/nuHYRFmMjU/renaissance'},
#   {'id': 'zyj9ZK3mHB',
#    'name': 'Resource Management',
#    'url': 'https://www.boardgameatlas.com/category/zyj9ZK3mHB/resource-management'},
#   {'id': 'oojGpMQQ2l',
#    'name': 'Robots',
#    'url': 'https://www.boardgameatlas.com/category/oojGpMQQ2l/robots'},
#   {'id': 'KSBdPfxs6F',
#    'name': 'Roman Empire',
#    'url': 'https://www.boardgameatlas.com/category/KSBdPfxs6F/roman-empire'},
#   {'id': 'E5rYwP0Ybr',
#    'name': 'Romance',
#    'url': 'https://www.boardgameatlas.com/category/E5rYwP0Ybr/romance'},
#   {'id': 'SzUZdSjCN2',
#    'name': 'Route Building',
#    'url': 'https://www.boardgameatlas.com/category/SzUZdSjCN2/route-building'},
#   {'id': '3B3QpKvXD3',
#    'name': 'Sci-Fi',
#    'url': 'https://www.boardgameatlas.com/category/3B3QpKvXD3/scifi'},
#   {'id': 'UjUO40mmeL',
#    'name': 'Screen Printed Meeples',
#    'url': 'https://www.boardgameatlas.com/category/UjUO40mmeL/screen-printed-meeples'},
#   {'id': 'WCMkyAqVlf',
#    'name': 'Semi-Cooperative',
#    'url': 'https://www.boardgameatlas.com/category/WCMkyAqVlf/semicooperative'},
#   {'id': 'VzyslQJGrG',
#    'name': 'Solo / Solitaire',
#    'url': 'https://www.boardgameatlas.com/category/VzyslQJGrG/solo--solitaire'},
#   {'id': '0MdRqhkNpw',
#    'name': 'Space Exploration',
#    'url': 'https://www.boardgameatlas.com/category/0MdRqhkNpw/space-exploration'},
#   {'id': 'Hc6vcim5DS',
#    'name': 'Spies/Secret Agents',
#    'url': 'https://www.boardgameatlas.com/category/Hc6vcim5DS/spiessecret-agents'},
#   {'id': 'hShsL2DktG',
#    'name': 'Sports',
#    'url': 'https://www.boardgameatlas.com/category/hShsL2DktG/sports'},
#   {'id': '4hZlqoitAY',
#    'name': 'Steampunk',
#    'url': 'https://www.boardgameatlas.com/category/4hZlqoitAY/steampunk'},
#   {'id': 'jGXefW0E2i',
#    'name': 'Storytelling',
#    'url': 'https://www.boardgameatlas.com/category/jGXefW0E2i/storytelling'},
#   {'id': 'alkjFhA58S',
#    'name': 'Strategic-Level',
#    'url': 'https://www.boardgameatlas.com/category/alkjFhA58S/strategic-level'},
#   {'id': 'loGUMKV9K9',
#    'name': 'Tactical-Level',
#    'url': 'https://www.boardgameatlas.com/category/loGUMKV9K9/tactical-level'},
#   {'id': 'buDTYyPw4D',
#    'name': 'Territory Building',
#    'url': 'https://www.boardgameatlas.com/category/buDTYyPw4D/territory-building'},
#   {'id': 'XN9Byxf3MK',
#    'name': 'Theme Park',
#    'url': 'https://www.boardgameatlas.com/category/XN9Byxf3MK/theme-park'},
#   {'id': 'BHxvD7ZjfA',
#    'name': 'Tile Placement',
#    'url': 'https://www.boardgameatlas.com/category/BHxvD7ZjfA/tile-placement'},
#   {'id': '2KVQJ2k60k',
#    'name': 'Time Travel',
#    'url': 'https://www.boardgameatlas.com/category/2KVQJ2k60k/time-travel'},
#   {'id': 'JwHcKqxh33',
#    'name': 'Trains',
#    'url': 'https://www.boardgameatlas.com/category/JwHcKqxh33/trains'},
#   {'id': 'CWYOF9xu7O',
#    'name': 'Transportation',
#    'url': 'https://www.boardgameatlas.com/category/CWYOF9xu7O/transportation'},
#   {'id': 'TR4CiP8Huj',
#    'name': 'Travel',
#    'url': 'https://www.boardgameatlas.com/category/TR4CiP8Huj/travel'},
#   {'id': 'YGHGDjahKY',
#    'name': 'Trivia',
#    'url': 'https://www.boardgameatlas.com/category/YGHGDjahKY/trivia'},
#   {'id': 'djokexoK0U',
#    'name': 'Video Game Theme',
#    'url': 'https://www.boardgameatlas.com/category/djokexoK0U/video-game-theme'},
#   {'id': 'jS8aA9kDFW',
#    'name': 'Vietnam War',
#    'url': 'https://www.boardgameatlas.com/category/jS8aA9kDFW/vietnam-war'},
#   {'id': 'muDQil3Mkb',
#    'name': 'Viking',
#    'url': 'https://www.boardgameatlas.com/category/muDQil3Mkb/viking'},
#   {'id': 'jX8asGGR6o',
#    'name': 'Wargame',
#    'url': 'https://www.boardgameatlas.com/category/jX8asGGR6o/wargame'},
#   {'id': 'uJgSEPT6zE',
#    'name': 'Werewolves',
#    'url': 'https://www.boardgameatlas.com/category/uJgSEPT6zE/werewolves'},
#   {'id': 'rHvAx4hH2f',
#    'name': 'Word Game',
#    'url': 'https://www.boardgameatlas.com/category/rHvAx4hH2f/word-game'},
#   {'id': 'wTLJSVEbm6',
#    'name': 'World War I',
#    'url': 'https://www.boardgameatlas.com/category/wTLJSVEbm6/world-war-i'},
#   {'id': 'fl3TogdUzX',
#    'name': 'World War II',
#    'url': 'https://www.boardgameatlas.com/category/fl3TogdUzX/world-war-ii'},
#   {'id': 'OlkGBmu4Va',
#    'name': 'World War III',
#    'url': 'https://www.boardgameatlas.com/category/OlkGBmu4Va/world-war-iii'},
#   {'id': '30B899LSDs',
#    'name': 'Zodiac',
#    'url': 'https://www.boardgameatlas.com/category/30B899LSDs/zodiac'},
#   {'id': 'FmGV9rVu1c',
#    'name': 'Zombies',
#    'url': 'https://www.boardgameatlas.com/category/FmGV9rVu1c/zombies'},
#   {'id': 'B1N2QOByCl',
#    'name': 'Zone Control',
#    'url': 'https://www.boardgameatlas.com/category/B1N2QOByCl/zone-control'}]}

# %%
# Get category ids
categ_ids = []
for cat_num in list(range(0,len(categ_dict['categories']))):
    categ_ids.append(categ_dict['categories'][cat_num]['id'])
categ_ids
# Out:
# ['2bdFPJUvFo',
#  '85OKv8p5Ow',
#  'hBqZ3Ar4RJ',
#  'KUBCKBkGxV',
#  'DjAhqEHOD0',
#  '20iDvpbh7A',
#  'tJxatX2ZbW',
#  'nWDac9tQzt',
#  'dghLhwyxVb',
#  '4mOtRRwSoj',
#  'a8NM5cugJX',
#  'MWoxgHrOJD',
#  'eFaACC6y2c',
#  'CBboNLI1Uj',
#  'k0dglq5j6N',
#  'Bq6M0TJyg7',
#  'QB4sEpx1Uu',
#  'wpItJuRDiz',
#  'PinhJrhnxU',
#  'fW5vusE96B',
#  'eX8uuNlQkQ',
#  'HKaYVNIxAJ',
#  '36WFElclV3',
#  'ODWOjWAJj3',
#  'w8XD66FUZ2',
#  '329DxyFL9D',
#  'bVMxJo31bS',
#  'vXxLT0FDTZ',
#  'bSzUpE5oOZ',
#  'gscaL52VDG',
#  'G5kfqnPBP6',
#  'pacCjl7His',
#  'ge8pIhEUGE',
#  '7DfHn28Pcf',
#  'nfQONtMbDU',
#  'Ef4oYLHNhI',
#  'bCBXJy9qDw',
#  'bKrxqD9mYc',
#  'mavSOM8vjH',
#  '42pmul4oHH',
#  'We3MM46qBr',
#  'g2Hwv8t0Y5',
#  'N0TkEGfEsF',
#  'B3NRLMK4xD',
#  'crxgUzJSEz',
#  'gsekjrPJz0',
#  'u5ZiYctU6T',
#  'v4SfYtS2Lr',
#  'yq6hVlbM2R',
#  '7rV11PKqME',
#  'ctumBZyj5l',
#  'ZTneo8TaIO',
#  'Wr8uXcoR9p',
#  'upXZ8vNfNO',
#  'ELg06sncRX',
#  'YrDuNj8lvr',
#  'JvIs75sWte',
#  'Eyuf8PzjDo',
#  'KzEQIwIub7',
#  'cAIkk5aLdQ',
#  'TYnxiuiI3X',
#  'zqFmdU4Fp2',
#  'rrvd68LjOR',
#  '3souLOXUqI',
#  'AGKGd3txp9',
#  'XeYUw9159M',
#  'HZ7kUiqEbs',
#  'GCwXmvBCvA',
#  'pIMmuVYnQp',
#  'POlqwScVxD',
#  'ZhlfIPxYsw',
#  'ruQAhyLfum',
#  'AeWXMxbm91',
#  'QAYkTHK1Dd',
#  'AujCle9cUq',
#  'Cc10AY9UX5',
#  'FC6ElKI9tk',
#  'L6NUwNdblq',
#  'Sod2YBWMKi',
#  'Kk70K0524Z',
#  'herNFAxMdz',
#  'MHkqIVxwtx',
#  'IpcJzp0TVC',
#  'vqZ5XzGWQD',
#  'jZEDOpx07e',
#  'rtslXnT90O',
#  'dO9HVl2TW7',
#  '9r6mtYVCAZ',
#  'TCYEfWLB8c',
#  'X8J7RM6dxX',
#  'UL3b9M86gA',
#  '9EIayX6n5a',
#  'vRbkg1W0AB',
#  'TKQncFVX74',
#  '8Z7nWG2kOw',
#  '5APB1MWk6X',
#  'YyszHun1HP',
#  'ov6sEmlkiC',
#  'dAyk5NtNTV',
#  'WVMOS3s2pb',
#  '2Gu62aKdma',
#  'tQGLgwdbYH',
#  'PzWI2uaif0',
#  'DRqeVkXWqX',
#  'nuHYRFmMjU',
#  'zyj9ZK3mHB',
#  'oojGpMQQ2l',
#  'KSBdPfxs6F',
#  'E5rYwP0Ybr',
#  'SzUZdSjCN2',
#  '3B3QpKvXD3',
#  'UjUO40mmeL',
#  'WCMkyAqVlf',
#  'VzyslQJGrG',
#  '0MdRqhkNpw',
#  'Hc6vcim5DS',
#  'hShsL2DktG',
#  '4hZlqoitAY',
#  'jGXefW0E2i',
#  'alkjFhA58S',
#  'loGUMKV9K9',
#  'buDTYyPw4D',
#  'XN9Byxf3MK',
#  'BHxvD7ZjfA',
#  '2KVQJ2k60k',
#  'JwHcKqxh33',
#  'CWYOF9xu7O',
#  'TR4CiP8Huj',
#  'YGHGDjahKY',
#  'djokexoK0U',
#  'jS8aA9kDFW',
#  'muDQil3Mkb',
#  'jX8asGGR6o',
#  'uJgSEPT6zE',
#  'rHvAx4hH2f',
#  'wTLJSVEbm6',
#  'fl3TogdUzX',
#  'OlkGBmu4Va',
#  '30B899LSDs',
#  'FmGV9rVu1c',
#  'B1N2QOByCl']

# %%
# Number of categories
len(categ_ids)
# Out:
# 141

# %%
# Sample
categ_url = 'https://api.boardgameatlas.com/api/search?client_id=6MXavgYBke&limit=100&categories=2bdFPJUvFo'
response = requests.get(categ_url)
games_dict = json.loads(response.text)
games_dict
# Out:
# {'games': [{'id': 'o6knI5ct0u',
#    'handle': 'mayfair-games-1830-railways-and-robber-barons--north-east-us',
#    'url': 'https://www.boardgameatlas.com/game/o6knI5ct0u/mayfair-games-1830-railways-and-robber-barons--north-east-us',
#    'edit_url': 'https://www.boardgameatlas.com/game/o6knI5ct0u/edit',
#    'name': '1830: Railways & Robber Barons',
#    'price': '55.99',
#    'distributors': [{'id': 'G7bYgDUpyD',
#      'store_name': 'Asmodee',
#      'name': '1830 (Revised Edition)',
#      'url': 'https://www.asmodeena.com/active-catalog-csv',
#      'msrp': 76.99,
#      'updated_at_ago': '3 hours ago',
#      'stock': 1,
#      'sku': 'LK0043',
#      'pfGameDistributorInfo': {'objectId': 'NeHDiBOndN'},
#      'msrp_text': '$76.99'}],
#    'price_ca': '74.99',
#    'price_uk': '0.00',
#    'price_au': '89.95',
#    'msrp': 69.99,
#    'msrps': [{'country': 'CA', 'price': 0},
#     {'country': 'UK', 'price': 0},
#     {'country': 'US', 'price': 69.99}],
#    'discount': '0.20',
#    'year_published': 1986,
#    'min_players': 2,
#    'max_players': 7,
#    'min_playtime': 180,
#    'max_playtime': 360,
#    'min_age': 14,
#    'description': "<p>1830. It is the dawn of the &quot;Age of Railroading&quot; in America. You're a wealthy investor and speculator betting that the new technology will revolutionize transport. Commerce will no longer depend on rutted roads and slow canals. Instead, it will ride the rails on swift, powerful &quot;Iron Horses.&quot;</p>\r\n<p><strong>1830</strong> is an acclaimed railroad investment and building game covering the years 1830 to present. You and your fellow players become the stockholders of America's first railroad corporations. Since the largest shareholder becomes president, you compete for control of the strongest firms. As president, generate revenue by building track and buying and operating trains-regardless of shareholders' needs. Meanwhile, you pay heed to the volatile stock market. You strive to invest in flourishing companies in order to earn healthy dividends. You try to buy stock in corporations that are rising in value, collect strong, and sell before the stock values drop.</p>\r\n<p>Get ready to be a railroad baron. Start investing and building. Become America's first great rail tycoon!</p>\r\n<p>The 2011 version of <em>1830</em> was published by Mayfair Games in partnership with Lookout Games of Germany. This publication was developed under license from Francis Tresham in co-operation with Bruce Shelley (the original <em>1830</em> developer). This version contains rules and components for Francis Tresham's original classic design, a faster-playing basic game, and new variants from some of the world's best railroad game developers.</p>",
#    'commentary': '',
#    'faq': '',
#    'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559257858925-51BztJ2q4WL.jpg',
#    'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559257858925-51BztJ2q4WL.jpg',
#    'matches_specs': None,
#    'specs': [],
#    'mechanics': [{'id': 'ohABM4GjbC',
#      'url': 'https://www.boardgameatlas.com/mechanic/ohABM4GjbC/undefined'},
#     {'id': 'jbLrZb1xIb',
#      'url': 'https://www.boardgameatlas.com/mechanic/jbLrZb1xIb/undefined'},
#     {'id': '8PN2HE86wg',
#      'url': 'https://www.boardgameatlas.com/mechanic/8PN2HE86wg/undefined'}],
#    'categories': [{'id': '2bdFPJUvFo',
#      'url': 'https://www.boardgameatlas.com/category/2bdFPJUvFo/undefined'},
#     {'id': 'JwHcKqxh33',
#      'url': 'https://www.boardgameatlas.com/category/JwHcKqxh33/undefined'}],
#    'publishers': [{'id': 'w1jOf2uAOD',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/w1jOf2uAOD/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': 'r2R8bUHIRD',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/r2R8bUHIRD/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': 'oQcGa4viSd',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/oQcGa4viSd/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': '7GTti1NuCH',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/7GTti1NuCH/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': 'j3lCGDByb2',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/j3lCGDByb2/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'designers': [{'id': 'RpZJ6vqsPR',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/RpZJ6vqsPR/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'primary_publisher': {'id': 'w1jOf2uAOD',
#     'name': 'The Avalon Hill Game Co',
#     'url': 'https://www.boardgameatlas.com/publisher/w1jOf2uAOD/the-avalon-hill-game-co'},
#    'primary_designer': {'id': 'RpZJ6vqsPR',
#     'name': 'Francis Tresham',
#     'url': 'https://www.boardgameatlas.com/designer/RpZJ6vqsPR/francis-tresham'},
#    'developers': [],
#    'related_to': [],
#    'artists': ['Mike Atkinson',
#     'Jared Blando',
#     'Charles Kibler',
#     'James Talbot',
#     'Mark Zug'],
#    'names': [],
#    'rules_url': 'https://lookout-spiele.de/wp-content/uploads/1830_Spielregeln_EN_WEB.pdf',
#    'amazon_rank': 559911,
#    'official_url': 'http://www.mayfairgames.com/products/1830-north-east-us?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#    'comment_count': 0,
#    'num_user_ratings': 36,
#    'average_user_rating': 4.006944444444444,
#    'historical_low_prices': [{'country': 'US',
#      'date': '2021-12-13T11:04:13.759Z',
#      'price': 55.99,
#      'isLow': False},
#     {'country': 'UK',
#      'date': '2021-12-18T12:07:52.735Z',
#      'price': 50.15,
#      'isLow': False},
#     {'country': 'AU',
#      'date': '2022-01-18T12:30:39.425Z',
#      'price': 89.95,
#      'isLow': False},
#     {'country': 'CA',
#      'date': '2022-03-08T15:27:32.086Z',
#      'price': 74.99,
#      'isLow': False}],
#    'active': True,
#    'num_user_complexity_votes': 2,
#    'average_learning_complexity': 3,
#    'average_strategy_complexity': 4.5,
#    'visits': 1869,
#    'lists': 273,
#    'mentions': 3,
#    'links': 0,
#    'plays': 240,
#    'rank': 874,
#    'type': 'game',
#    'num_distributors': 1,
#    'trending_rank': 0,
#    'listing_clicks': 0,
#    'is_historical_low': False,
#    'msrp_text': '$69.99',
#    'price_text': '$55.99',
#    'tags': ["1830: Ferrovie e Capitani d'Industria",
#     '1830: Schienenleger & Spekulanten',
#     '1830: The Game of Railroads and Robber Barons',
#     '1830 Revised Edition',
#     '1830 Railways Robber Barons Revised Edition',
#     '1830 (Revised Edition) [Pre-Order]',
#     '1830 Revised Edition Dent Ding',
#     '1830 Railways and Robber Barons',
#     '1830 Railways Robber Barons',
#     '1830: Railways & Robber Barons (Lookout Games Edition)',
#     '1830',
#     '1830 The Game of Railroads and Robber Barons'],
#    'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1559257858925-51BztJ2q4WL.jpg',
#     'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1559257858925-51BztJ2q4WL.jpg',
#     'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1559257858925-51BztJ2q4WL.jpg',
#     'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1559257858925-51BztJ2q4WL.jpg',
#     'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559257858925-51BztJ2q4WL.jpg'},
#    'description_preview': ' 1830. It is the dawn of the "Age of Railroading" in America. You\'re a wealthy investor and speculator betting that the new technology will revolutionize transport. Commerce will no longer depend on rutted roads and slow canals. Instead, it will ride the rails on swift, powerful "Iron Horses." \r\n  1830  is an acclaimed railroad investment and building game covering the years 1830 to present. You and your fellow players become the stockholders of America\'s first railroad corporations. Since the largest shareholder becomes president, you compete for control of the strongest firms. As president, generate revenue by building track and buying and operating trains-regardless of shareholders\' needs. Meanwhile, you pay heed to the volatile stock market. You strive to invest in flourishing companies in order to earn healthy dividends. You try to buy stock in corporations that are rising in value, collect strong, and sell before the stock values drop. \r\n Get ready to be a railroad baron. Start investing and building. Become America\'s first great rail tycoon! \r\n The 2011 version of  1830  was published by Mayfair Games in partnership with Lookout Games of Germany. This publication was developed under license from Francis Tresham in co-operation with Bruce Shelley (the original  1830  developer). This version contains rules and components for Francis Tresham\'s original classic design, a faster-playing basic game, and new variants from some of the world\'s best railroad game developers. '},
#   {'id': 'uEPtE5OOOU',
#    'handle': '1862-railway-mania-in-the-eastern-counties',
#    'url': 'https://www.boardgameatlas.com/game/uEPtE5OOOU/1862-railway-mania-in-the-eastern-counties',
#    'edit_url': 'https://www.boardgameatlas.com/game/uEPtE5OOOU/edit',
#    'name': '1862: Railway Mania in the Eastern Counties',
#    'price': '45.51',
#    'distributors': [{'id': 'EX3EM6jraQ',
#      'store_name': 'GTS Distribution',
#      'name': '1862: RAILWAY MANIA IN THE EASTERN COUNTIES OF ENGLAND',
#      'url': 'https://www.gtsdistribution.com/pc_product_detail.asp?key=EBA90DB6773E47348CDCD0C5BF6FD06C',
#      'msrp': 0,
#      'updated_at_ago': '4 hours ago',
#      'stock': 1,
#      'publisher': 'GMT GAMES',
#      'image_url': 'https://df91xcjifaff3.cloudfront.net/images/gmt1904.jpg',
#      'description': "<b>1862: Railway Mania in the Eastern Counties</b> is an '18xx' game, one of many rail games by different designers inspired by Francis Tresham's 1829. Although it shares many traits in common with the other 18XX games, it has several unique features.",
#      'upc': '817054011704',
#      'sku': 'GMT1904',
#      'pfGameDistributorInfo': {'objectId': 'TE1OOyu17J'},
#      'msrp_text': 'N/A'}],
#    'price_ca': '79.95',
#    'price_uk': '0.00',
#    'price_au': '127.99',
#    'msrp': 79,
#    'msrps': [{'country': 'US', 'price': 79}],
#    'discount': '0.42',
#    'year_published': 2013,
#    'min_players': 1,
#    'max_players': 8,
#    'min_playtime': 300,
#    'max_playtime': 300,
#    'min_age': 12,
#    'description': '<p>1862: Railway Mania in the Eastern Counties is an 18xx game set in East Anglia, England. It features a company-packed board, where 16 of 20 companies are randomly selected for use on a board containing only 37 hexes. Major features of the game are:</p>\r\n<ul>\r\n<li>Petitioning parliament as a means of floating your preferred company</li>\r\n<li>a mixture of full and partial capitalisation for companies</li>\r\n<li>three train types with differing objectives and building requirements</li>\r\n<li>company mergers and re-floatation</li>\r\n<li>1860-style semi-linear stock-market featuring multiple stock jumps.</li>\r\n</ul>\r\n<p>The GMT version plays from 1-8, unlike the previous printing which played 2-8.</p>',
#    'commentary': '',
#    'faq': '',
#    'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1596759565235',
#    'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1596759565235',
#    'matches_specs': None,
#    'specs': [],
#    'mechanics': [{'id': 'qCXa8MX0wk',
#      'url': 'https://www.boardgameatlas.com/mechanic/qCXa8MX0wk/undefined'},
#     {'id': 'AZxlPpi5oq',
#      'url': 'https://www.boardgameatlas.com/mechanic/AZxlPpi5oq/undefined'},
#     {'id': 'ohABM4GjbC',
#      'url': 'https://www.boardgameatlas.com/mechanic/ohABM4GjbC/undefined'},
#     {'id': 'jbLrZb1xIb',
#      'url': 'https://www.boardgameatlas.com/mechanic/jbLrZb1xIb/undefined'},
#     {'id': '8PN2HE86wg',
#      'url': 'https://www.boardgameatlas.com/mechanic/8PN2HE86wg/undefined'}],
#    'categories': [{'id': '2bdFPJUvFo',
#      'url': 'https://www.boardgameatlas.com/category/2bdFPJUvFo/undefined'}],
#    'publishers': [{'id': 'd5oY0duBgG',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/d5oY0duBgG/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': '1oaT2XrPzU',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/1oaT2XrPzU/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'designers': [{'id': 'xMrDEmBdTo',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/xMrDEmBdTo/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'primary_publisher': {'name': 'GMT Games',
#     'id': 'd5oY0duBgG',
#     'url': 'https://www.boardgameatlas.com/publisher/d5oY0duBgG/gmt-games'},
#    'primary_designer': {'name': 'Mike Hutton',
#     'id': 'xMrDEmBdTo',
#     'url': 'https://www.boardgameatlas.com/designer/xMrDEmBdTo/mike-hutton'},
#    'developers': [],
#    'related_to': [],
#    'artists': ['Mike Hutton'],
#    'names': [],
#    'rules_url': 'https://gmtwebsiteassets.s3-us-west-2.amazonaws.com/1862/1862_TRAIN_RULES-Final.pdf',
#    'official_url': 'https://www.gmtgames.com/p-692-1862-railway-mania-in-the-eastern-counties.aspx?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#    'comment_count': 0,
#    'num_user_ratings': 9,
#    'average_user_rating': 4.111111111111111,
#    'size_height': 9,
#    'size_depth': 3,
#    'historical_low_prices': [{'country': 'UK',
#      'date': '2021-12-11T11:48:13.406Z',
#      'price': 66.49,
#      'isLow': False},
#     {'country': 'CA',
#      'date': '2022-01-10T07:09:41.619Z',
#      'price': 99.07,
#      'isLow': False},
#     {'country': 'AU',
#      'date': '2022-01-20T14:33:15.572Z',
#      'price': 127.99,
#      'isLow': False},
#     {'country': 'US',
#      'date': '2022-03-09T17:23:32.677Z',
#      'price': 45.51,
#      'isLow': False}],
#    'active': True,
#    'num_user_complexity_votes': 0,
#    'average_learning_complexity': 0,
#    'average_strategy_complexity': 0,
#    'visits': 1048,
#    'lists': 120,
#    'mentions': 13,
#    'links': 1,
#    'plays': 70,
#    'rank': 9999999,
#    'type': 'game',
#    'sku': 'GMT1904',
#    'upc': '817054011704',
#    'num_distributors': 2,
#    'trending_rank': 0,
#    'listing_clicks': 0,
#    'is_historical_low': False,
#    'msrp_text': '$79.00',
#    'price_text': '$45.51',
#    'tags': ['1862: Railway Mania in the Eastern Counties',
#     '1862: Railway Mania in The Eastern Counties',
#     '18EA',
#     '1862: Railway Mania in the Eastern Counties of England',
#     '1862: Railway Mania',
#     '1862: Railway Mania in the Eastern Counties (Minor Damage)'],
#    'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1596759565235',
#     'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1596759565235',
#     'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1596759565235',
#     'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1596759565235',
#     'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1596759565235'},
#    'description_preview': ' 1862: Railway Mania in the Eastern Counties is an 18xx game set in East Anglia, England. It features a company-packed board, where 16 of 20 companies are randomly selected for use on a board containing only 37 hexes. Major features of the game are: \r\n \r\n Petitioning parliament as a means of floating your preferred company \r\n a mixture of full and partial capitalisation for companies \r\n three train types with differing objectives and building requirements \r\n company mergers and re-floatation \r\n 1860-style semi-linear stock-market featuring multiple stock jumps. \r\n \r\n The GMT version plays from 1-8, unlike the previous printing which played 2-8. '},
#   {'id': 'Krn8i8C0fI',
#    'handle': '18chesapeake',
#    'url': 'https://www.boardgameatlas.com/game/Krn8i8C0fI/18chesapeake',
#    'edit_url': 'https://www.boardgameatlas.com/game/Krn8i8C0fI/edit',
#    'name': '18Chesapeake',
#    'price': '0.00',
#    'price_ca': '0.00',
#    'price_uk': '0.00',
#    'price_au': '0.00',
#    'msrp': 89,
#    'msrps': [{'country': 'US', 'price': 89},
#     {'country': 'CA', 'price': 0},
#     {'country': 'UK', 'price': 0}],
#    'discount': '0.00',
#    'year_published': 2020,
#    'min_players': 2,
#    'max_players': 6,
#    'min_playtime': 180,
#    'max_playtime': 180,
#    'min_age': 13,
#    'description': '<p>18Chesapeake is a member of the\xa0<a href="https://boardgamegeek.com/wiki/page/18xx">18xx</a>\xa0series of games. The series is based on 1829, by Francis Tresham. 18Chesapeake is set in the Chesapeake region of the United States and west to Ohio and the West Virginia Coalfields.</p>\r\n<p>Two to six players represent investors in railroad companies, spending their initial capital to buy wholly owned private companies and minor companies and later shares in public companies.</p>\r\n<p>The public companies are each controlled by the largest shareholder (its president). Public companies build track and run trains in order to earn revenues. Public company revenues can be paid out as dividends to shareholders or retained to fund further track and rolling stock.</p>\r\n<p>A feature of 18Chesapeake, as with all the other games in the series, is that the interests of a public company’s president and the interests of its shareholders are not identical, so minority shareholders need to be careful in their investments.</p>\r\n<p>18Chesapeake is a moderate length game. Experienced, brisk players can expect to take about 2-1/2 hours to complete a game. Novices or more deliberate players might add an hour to that time.</p>',
#    'commentary': '',
#    'faq': '',
#    'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1610607271262',
#    'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1610607271262',
#    'matches_specs': None,
#    'specs': [],
#    'mechanics': [{'id': 'AZxlPpi5oq',
#      'url': 'https://www.boardgameatlas.com/mechanic/AZxlPpi5oq/undefined'},
#     {'id': 'ohABM4GjbC',
#      'url': 'https://www.boardgameatlas.com/mechanic/ohABM4GjbC/undefined'},
#     {'id': 'jbLrZb1xIb',
#      'url': 'https://www.boardgameatlas.com/mechanic/jbLrZb1xIb/undefined'},
#     {'id': '8PN2HE86wg',
#      'url': 'https://www.boardgameatlas.com/mechanic/8PN2HE86wg/undefined'}],
#    'categories': [{'id': '2bdFPJUvFo',
#      'url': 'https://www.boardgameatlas.com/category/2bdFPJUvFo/undefined'},
#     {'id': 'N0TkEGfEsF',
#      'url': 'https://www.boardgameatlas.com/category/N0TkEGfEsF/undefined'},
#     {'id': 'rrvd68LjOR',
#      'url': 'https://www.boardgameatlas.com/category/rrvd68LjOR/undefined'},
#     {'id': 'JwHcKqxh33',
#      'url': 'https://www.boardgameatlas.com/category/JwHcKqxh33/undefined'}],
#    'publishers': [{'id': 'ZOP4wDStJq',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/ZOP4wDStJq/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'designers': [{'id': 'fN0XCgUAPZ',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/fN0XCgUAPZ/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'primary_publisher': {'id': 'ZOP4wDStJq',
#     'name': 'All-Aboard Games',
#     'url': 'https://www.boardgameatlas.com/publisher/ZOP4wDStJq/allaboard-games'},
#    'primary_designer': {'id': 'fN0XCgUAPZ',
#     'name': 'Scott Petersen',
#     'url': 'https://www.boardgameatlas.com/designer/fN0XCgUAPZ/scott-petersen'},
#    'developers': [],
#    'related_to': [],
#    'artists': ['Brigette Indelicato'],
#    'names': [],
#    'rules_url': None,
#    'official_url': 'https://all-aboardgames.com/products/us-only-18chesapeake-preorder?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#    'comment_count': 0,
#    'num_user_ratings': 11,
#    'average_user_rating': 4.454545454545455,
#    'historical_low_prices': [{'country': 'US',
#      'date': '2022-02-08T01:34:29.252Z',
#      'price': 21.99,
#      'isLow': False}],
#    'active': True,
#    'num_user_complexity_votes': 1,
#    'average_learning_complexity': 3,
#    'average_strategy_complexity': 4,
#    'visits': 856,
#    'lists': 171,
#    'mentions': 1,
#    'links': 0,
#    'plays': 157,
#    'rank': 9999999,
#    'type': 'game',
#    'num_distributors': 0,
#    'trending_rank': 0,
#    'listing_clicks': 0,
#    'is_historical_low': False,
#    'msrp_text': '$89.00',
#    'price_text': 'Price: N/A',
#    'tags': ['18Chesapeake'],
#    'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1610607271262',
#     'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1610607271262',
#     'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1610607271262',
#     'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1610607271262',
#     'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1610607271262'},
#    'description_preview': ' 18Chesapeake is a member of the\xa0 18xx \xa0series of games. The series is based on 1829, by Francis Tresham. 18Chesapeake is set in the Chesapeake region of the United States and west to Ohio and the West Virginia Coalfields. \r\n Two to six players represent investors in railroad companies, spending their initial capital to buy wholly owned private companies and minor companies and later shares in public companies. \r\n The public companies are each controlled by the largest shareholder (its president). Public companies build track and run trains in order to earn revenues. Public company revenues can be paid out as dividends to shareholders or retained to fund further track and rolling stock. \r\n A feature of 18Chesapeake, as with all the other games in the series, is that the interests of a public company’s president and the interests of its shareholders are not identical, so minority shareholders need to be careful in their investments. \r\n 18Chesapeake is a moderate length game. Experienced, brisk players can expect to take about 2-1/2 hours to complete a game. Novices or more deliberate players might add an hour to that time. '},
#   {'id': 'eJuGpFzljd',
#    'handle': '184454-switzerland-and-austria-board-game',
#    'url': 'https://www.boardgameatlas.com/game/eJuGpFzljd/184454-switzerland-and-austria-board-game',
#    'edit_url': 'https://www.boardgameatlas.com/game/eJuGpFzljd/edit',
#    'name': '1844 / 1854',
#    'price': '69.99',
#    'price_ca': '112.99',
#    'price_uk': '0.00',
#    'price_au': '0.00',
#    'msrp': 94.99,
#    'msrps': [{'country': 'UK', 'price': 87.99},
#     {'country': 'US', 'price': 94.99}],
#    'discount': '0.26',
#    'year_published': 2016,
#    'min_players': 3,
#    'max_players': 7,
#    'min_playtime': 300,
#    'max_playtime': 300,
#    'min_age': 12,
#    'description': '<p>The railway history of both Switzerland and Austria can be explored in <strong>1844/1854</strong>, both based on the 1829 game system created by Francis Tresham, that have been thoroughly revised for this new edition.</p>\r\n<p>In 1844, set in Switzerland, the challenge lies in running distinctive businesses. Local railway companies, which merged at that time to form SBB, and national historical societies require different decisions and strategies.</p>\r\n<p>A special feature of 1854, set in Austria, is located in the stock split, which comes into play in the additional shares.</p>',
#    'commentary': '',
#    'faq': '',
#    'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559257726327-515XPuqnuXL.jpg',
#    'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559257726327-515XPuqnuXL.jpg',
#    'matches_specs': None,
#    'specs': [],
#    'mechanics': [{'id': 'ohABM4GjbC',
#      'url': 'https://www.boardgameatlas.com/mechanic/ohABM4GjbC/undefined'},
#     {'id': 'jbLrZb1xIb',
#      'url': 'https://www.boardgameatlas.com/mechanic/jbLrZb1xIb/undefined'},
#     {'id': '8PN2HE86wg',
#      'url': 'https://www.boardgameatlas.com/mechanic/8PN2HE86wg/undefined'}],
#    'categories': [{'id': '2bdFPJUvFo',
#      'url': 'https://www.boardgameatlas.com/category/2bdFPJUvFo/undefined'}],
#    'publishers': [{'id': '7GTti1NuCH',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/7GTti1NuCH/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'designers': [{'id': 'gFwNqit3MM',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/gFwNqit3MM/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': 'jVfgvldclE',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/jVfgvldclE/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'primary_publisher': {'name': 'Mayfair Games',
#     'id': '7GTti1NuCH',
#     'url': 'https://www.boardgameatlas.com/publisher/7GTti1NuCH/mayfair-games'},
#    'primary_designer': {'name': 'Helmut Ohley',
#     'id': 'gFwNqit3MM',
#     'url': 'https://www.boardgameatlas.com/designer/gFwNqit3MM/helmut-ohley'},
#    'developers': [],
#    'related_to': [],
#    'artists': ['Klemens Franz'],
#    'names': [],
#    'rules_url': None,
#    'amazon_rank': 473334,
#    'official_url': None,
#    'comment_count': 0,
#    'num_user_ratings': 6,
#    'average_user_rating': 4,
#    'historical_low_prices': [{'country': 'UK',
#      'date': '2021-12-03T08:56:51.389Z',
#      'price': 69.97,
#      'isLow': False},
#     {'country': 'CA',
#      'date': '2021-12-03T08:56:51.792Z',
#      'price': 112.99,
#      'isLow': True},
#     {'country': 'US',
#      'date': '2022-02-02T06:46:39.871Z',
#      'price': 69.99,
#      'isLow': False}],
#    'active': True,
#    'num_user_complexity_votes': 0,
#    'average_learning_complexity': 0,
#    'average_strategy_complexity': 0,
#    'visits': 498,
#    'lists': 51,
#    'mentions': 0,
#    'links': 0,
#    'plays': 5,
#    'rank': 9999999,
#    'type': 'game',
#    'num_distributors': 0,
#    'trending_rank': 0,
#    'listing_clicks': 0,
#    'is_historical_low': False,
#    'msrp_text': '$94.99',
#    'price_text': '$69.99',
#    'tags': ['1844/1854 Switzerland/Austria', '1844/1854', '1844 1854'],
#    'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1559257726327-515XPuqnuXL.jpg',
#     'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1559257726327-515XPuqnuXL.jpg',
#     'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1559257726327-515XPuqnuXL.jpg',
#     'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1559257726327-515XPuqnuXL.jpg',
#     'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559257726327-515XPuqnuXL.jpg'},
#    'description_preview': ' The railway history of both Switzerland and Austria can be explored in  1844/1854 , both based on the 1829 game system created by Francis Tresham, that have been thoroughly revised for this new edition. \r\n In 1844, set in Switzerland, the challenge lies in running distinctive businesses. Local railway companies, which merged at that time to form SBB, and national historical societies require different decisions and strategies. \r\n A special feature of 1854, set in Austria, is located in the stock split, which comes into play in the additional shares. '},
#   {'id': 'IKKs90JOkr',
#    'handle': '1822-the-railways-of-great-britain',
#    'url': 'https://www.boardgameatlas.com/game/IKKs90JOkr/1822-the-railways-of-great-britain',
#    'edit_url': 'https://www.boardgameatlas.com/game/IKKs90JOkr/edit',
#    'name': '1822: The Railways of Great Britain',
#    'price': '0.00',
#    'price_ca': '35.25',
#    'price_uk': '0.00',
#    'price_au': '71.99',
#    'msrp': 44.76,
#    'msrps': [{'country': 'US', 'price': 44.76}],
#    'discount': '0.00',
#    'year_published': 2016,
#    'min_players': 3,
#    'max_players': 7,
#    'min_playtime': 300,
#    'max_playtime': 420,
#    'min_age': 12,
#    'description': '',
#    'commentary': '',
#    'faq': '',
#    'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1547932322061',
#    'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1547932322061',
#    'matches_specs': None,
#    'specs': [],
#    'mechanics': [{'id': 'qCXa8MX0wk',
#      'url': 'https://www.boardgameatlas.com/mechanic/qCXa8MX0wk/undefined'},
#     {'id': 'AZxlPpi5oq',
#      'url': 'https://www.boardgameatlas.com/mechanic/AZxlPpi5oq/undefined'},
#     {'id': 'ohABM4GjbC',
#      'url': 'https://www.boardgameatlas.com/mechanic/ohABM4GjbC/undefined'},
#     {'id': 'jbLrZb1xIb',
#      'url': 'https://www.boardgameatlas.com/mechanic/jbLrZb1xIb/undefined'},
#     {'id': '8PN2HE86wg',
#      'url': 'https://www.boardgameatlas.com/mechanic/8PN2HE86wg/undefined'}],
#    'categories': [{'id': '2bdFPJUvFo',
#      'url': 'https://www.boardgameatlas.com/category/2bdFPJUvFo/undefined'}],
#    'publishers': [{'id': 'ZOP4wDStJq',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/ZOP4wDStJq/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'designers': [{'id': '4G68cQLZKP',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/4G68cQLZKP/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'primary_publisher': {'name': 'All-Aboard Games',
#     'id': 'ZOP4wDStJq',
#     'url': 'https://www.boardgameatlas.com/publisher/ZOP4wDStJq/allaboard-games'},
#    'primary_designer': {'name': 'Simon Cutforth',
#     'id': '4G68cQLZKP',
#     'url': 'https://www.boardgameatlas.com/designer/4G68cQLZKP/simon-cutforth'},
#    'developers': [],
#    'related_to': [],
#    'artists': [],
#    'names': [],
#    'rules_url': None,
#    'official_url': 'http://www.all-aboardgames.com/home/simon-cutforth-s-1822-1822-the-railways-of-great-britain?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#    'comment_count': 0,
#    'num_user_ratings': 5,
#    'average_user_rating': 4.2,
#    'historical_low_prices': [{'country': 'AU',
#      'date': '2021-02-16T00:35:23.725Z',
#      'price': 71.99,
#      'isLow': False},
#     {'country': 'CA',
#      'date': '2021-04-07T05:47:18.151Z',
#      'price': 35.25,
#      'isLow': False},
#     {'country': 'US',
#      'date': '2022-02-08T10:54:13.405Z',
#      'price': 124.95,
#      'isLow': False}],
#    'active': True,
#    'num_user_complexity_votes': 0,
#    'average_learning_complexity': 0,
#    'average_strategy_complexity': 0,
#    'visits': 367,
#    'lists': 64,
#    'mentions': 1,
#    'links': 0,
#    'plays': 65,
#    'rank': 9999999,
#    'type': 'game',
#    'num_distributors': 0,
#    'trending_rank': 0,
#    'listing_clicks': 0,
#    'is_historical_low': False,
#    'msrp_text': '$44.76',
#    'price_text': 'Price: N/A',
#    'tags': ['1822: The Railways of Great Britain'],
#    'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1547932322061',
#     'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1547932322061',
#     'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1547932322061',
#     'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1547932322061',
#     'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1547932322061'},
#    'description_preview': ''},
#   {'id': 'PoTU2CknMS',
#    'handle': '1860-railways-on-the-isle-of-wight-24p-240-minutes-ages-13',
#    'url': 'https://www.boardgameatlas.com/game/PoTU2CknMS/1860-railways-on-the-isle-of-wight-24p-240-minutes-ages-13',
#    'edit_url': 'https://www.boardgameatlas.com/game/PoTU2CknMS/edit',
#    'name': '1860: Railways on the Isle of Wight',
#    'price': '0.00',
#    'price_ca': '0.00',
#    'price_uk': '0.00',
#    'price_au': '0.00',
#    'msrp': 0,
#    'msrps': [{'country': 'US', 'price': 0}],
#    'discount': '0.00',
#    'year_published': 2004,
#    'min_players': 2,
#    'max_players': 4,
#    'min_playtime': 240,
#    'max_playtime': 240,
#    'min_age': 13,
#    'description': "<p>A game tracing the development of railways on the Isle of Wight, <strong>1860</strong> is part of the 18xx series of economic railway games, based on Francis Tresham's original concepts.</p>",
#    'commentary': '',
#    'faq': '',
#    'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1611766983874',
#    'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1611766983874',
#    'matches_specs': None,
#    'specs': [],
#    'mechanics': [{'id': 'ohABM4GjbC',
#      'url': 'https://www.boardgameatlas.com/mechanic/ohABM4GjbC/undefined'},
#     {'id': 'jbLrZb1xIb',
#      'url': 'https://www.boardgameatlas.com/mechanic/jbLrZb1xIb/undefined'},
#     {'id': '8PN2HE86wg',
#      'url': 'https://www.boardgameatlas.com/mechanic/8PN2HE86wg/undefined'}],
#    'categories': [{'id': '2bdFPJUvFo',
#      'url': 'https://www.boardgameatlas.com/category/2bdFPJUvFo/undefined'}],
#    'publishers': [{'id': 'UPqP0MXLqj',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/UPqP0MXLqj/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'designers': [{'id': 'xMrDEmBdTo',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/xMrDEmBdTo/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'primary_publisher': {'name': 'Z-Man Games, Inc.',
#     'id': 'UPqP0MXLqj',
#     'url': 'https://www.boardgameatlas.com/publisher/UPqP0MXLqj/zman-games-inc'},
#    'primary_designer': {'name': 'Mike Hutton',
#     'id': 'xMrDEmBdTo',
#     'url': 'https://www.boardgameatlas.com/designer/xMrDEmBdTo/mike-hutton'},
#    'developers': [],
#    'related_to': [],
#    'artists': ['Mike Hutton'],
#    'names': [],
#    'rules_url': None,
#    'amazon_rank': 2003663,
#    'official_url': 'https://www.kickstarter.com/projects/all-aboardgames/1860-railways-on-the-isle-of-wight?ref=discovery_category_newest&utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#    'comment_count': 0,
#    'num_user_ratings': 9,
#    'average_user_rating': 3.7777777777777777,
#    'active': True,
#    'num_user_complexity_votes': 0,
#    'average_learning_complexity': 0,
#    'average_strategy_complexity': 0,
#    'visits': 250,
#    'lists': 76,
#    'mentions': 1,
#    'links': 0,
#    'plays': 41,
#    'rank': 9999999,
#    'type': 'game',
#    'num_distributors': 0,
#    'trending_rank': 0,
#    'listing_clicks': 0,
#    'is_historical_low': False,
#    'price_text': 'Price: N/A',
#    'tags': ['1860: Railways on the Isle of Wight'],
#    'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1611766983874',
#     'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1611766983874',
#     'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1611766983874',
#     'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1611766983874',
#     'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1611766983874'},
#    'description_preview': " A game tracing the development of railways on the Isle of Wight,  1860  is part of the 18xx series of economic railway games, based on Francis Tresham's original concepts. "},
#   {'id': 'YTVVvtMEQp',
#    'handle': '1857',
#    'url': 'https://www.boardgameatlas.com/game/YTVVvtMEQp/1857',
#    'edit_url': 'https://www.boardgameatlas.com/game/YTVVvtMEQp/edit',
#    'name': '1857',
#    'price': '0.00',
#    'price_ca': '0.00',
#    'price_uk': '0.00',
#    'price_au': '0.00',
#    'msrp': 0,
#    'msrps': [{'country': 'US', 'price': 0}],
#    'discount': '0.00',
#    'year_published': 2015,
#    'min_players': 3,
#    'max_players': 6,
#    'min_playtime': 120,
#    'max_playtime': 240,
#    'min_age': 0,
#    'description': '<p><strong>1857</strong> — one of three titles in Winsome Games 2015 Essen Set — is an 18xx game set in Argentina and requires some of the components from 1830 in order to play. There are 8 companies in the game with 6 unique privates. Several of these privates continue to function if owned by a railroad when they would normally close and removed from the game. Companies also have stations on the board from the beginning of the game that block passage through those locations, even before the company floats.</p>',
#    'commentary': '',
#    'faq': '',
#    'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1545422194354',
#    'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1545422194354',
#    'matches_specs': None,
#    'specs': [],
#    'mechanics': [{'id': 'ohABM4GjbC',
#      'url': 'https://www.boardgameatlas.com/mechanic/ohABM4GjbC/undefined'},
#     {'id': 'jbLrZb1xIb',
#      'url': 'https://www.boardgameatlas.com/mechanic/jbLrZb1xIb/undefined'},
#     {'id': '8PN2HE86wg',
#      'url': 'https://www.boardgameatlas.com/mechanic/8PN2HE86wg/undefined'}],
#    'categories': [{'id': '2bdFPJUvFo',
#      'url': 'https://www.boardgameatlas.com/category/2bdFPJUvFo/undefined'}],
#    'publishers': [{'id': 'rIXWSFX4sv',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/rIXWSFX4sv/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'designers': [{'id': 'KTeVFvo1uV',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/KTeVFvo1uV/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'primary_publisher': {'name': 'Winsome Games',
#     'id': 'rIXWSFX4sv',
#     'url': 'https://www.boardgameatlas.com/publisher/rIXWSFX4sv/winsome-games'},
#    'primary_designer': {},
#    'developers': [],
#    'related_to': [],
#    'artists': [],
#    'names': [],
#    'rules_url': None,
#    'official_url': ',?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#    'comment_count': 0,
#    'num_user_ratings': 4,
#    'average_user_rating': 3.5,
#    'active': True,
#    'num_user_complexity_votes': 0,
#    'average_learning_complexity': 0,
#    'average_strategy_complexity': 0,
#    'visits': 229,
#    'lists': 27,
#    'mentions': 0,
#    'links': 0,
#    'plays': 14,
#    'rank': 9999999,
#    'type': 'game',
#    'num_distributors': 0,
#    'trending_rank': 0,
#    'listing_clicks': 0,
#    'is_historical_low': False,
#    'price_text': 'Price: N/A',
#    'tags': ['1857'],
#    'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1545422194354',
#     'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1545422194354',
#     'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1545422194354',
#     'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1545422194354',
#     'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1545422194354'},
#    'description_preview': '  1857  — one of three titles in Winsome Games 2015 Essen Set — is an 18xx game set in Argentina and requires some of the components from 1830 in order to play. There are 8 companies in the game with 6 unique privates. Several of these privates continue to function if owned by a railroad when they would normally close and removed from the game. Companies also have stations on the board from the beginning of the game that block passage through those locations, even before the company floats. '},
#   {'id': '65DvpKB0IT',
#    'handle': '1822ca',
#    'url': 'https://www.boardgameatlas.com/game/65DvpKB0IT/1822ca',
#    'edit_url': 'https://www.boardgameatlas.com/game/65DvpKB0IT/edit',
#    'name': '1822CA',
#    'price': '0.00',
#    'price_ca': '0.00',
#    'price_uk': '0.00',
#    'price_au': '0.00',
#    'msrp': 0,
#    'msrps': [{'country': 'US', 'price': 0}],
#    'discount': '0.00',
#    'year_published': 2018,
#    'min_players': 3,
#    'max_players': 7,
#    'min_playtime': 360,
#    'max_playtime': 540,
#    'min_age': 12,
#    'description': '',
#    'commentary': '',
#    'faq': '',
#    'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/empty+box+thumb.jpg',
#    'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/empty+box.jpg',
#    'matches_specs': None,
#    'specs': [],
#    'mechanics': [{'id': 'AZxlPpi5oq',
#      'url': 'https://www.boardgameatlas.com/mechanic/AZxlPpi5oq/undefined'},
#     {'id': 'ohABM4GjbC',
#      'url': 'https://www.boardgameatlas.com/mechanic/ohABM4GjbC/undefined'},
#     {'id': 'jbLrZb1xIb',
#      'url': 'https://www.boardgameatlas.com/mechanic/jbLrZb1xIb/undefined'},
#     {'id': '8PN2HE86wg',
#      'url': 'https://www.boardgameatlas.com/mechanic/8PN2HE86wg/undefined'}],
#    'categories': [{'id': '2bdFPJUvFo',
#      'url': 'https://www.boardgameatlas.com/category/2bdFPJUvFo/undefined'}],
#    'publishers': [{'id': 'ZOP4wDStJq',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/ZOP4wDStJq/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'designers': [{'id': 'VQoKWjBx4G',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/VQoKWjBx4G/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}},
#     {'id': '4G68cQLZKP',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/4G68cQLZKP/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'primary_publisher': {'id': 'ZOP4wDStJq',
#     'name': 'All-Aboard Games',
#     'url': 'https://www.boardgameatlas.com/publisher/ZOP4wDStJq/allaboard-games'},
#    'primary_designer': {'id': 'VQoKWjBx4G',
#     'name': 'Robert Lecuyer',
#     'url': 'https://www.boardgameatlas.com/designer/VQoKWjBx4G/robert-lecuyer'},
#    'developers': [],
#    'related_to': [],
#    'artists': [],
#    'names': [],
#    'rules_url': None,
#    'official_url': None,
#    'comment_count': 0,
#    'num_user_ratings': 0,
#    'average_user_rating': 0,
#    'active': True,
#    'num_user_complexity_votes': 0,
#    'average_learning_complexity': 0,
#    'average_strategy_complexity': 0,
#    'visits': 204,
#    'lists': 22,
#    'mentions': 0,
#    'links': 0,
#    'plays': 4,
#    'rank': 9999999,
#    'type': 'game',
#    'num_distributors': 0,
#    'trending_rank': 0,
#    'listing_clicks': 0,
#    'is_historical_low': False,
#    'price_text': 'Price: N/A',
#    'tags': ['1822CA'],
#    'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/empty+box.jpg',
#     'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/empty+box.jpg',
#     'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/empty+box.jpg',
#     'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/empty+box.jpg',
#     'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/empty+box.jpg'},
#    'description_preview': ''},
#   {'id': 'vlaCUeyxNI',
#    'handle': '1882',
#    'url': 'https://www.boardgameatlas.com/game/vlaCUeyxNI/1882',
#    'edit_url': 'https://www.boardgameatlas.com/game/vlaCUeyxNI/edit',
#    'name': '1882: Assiniboia',
#    'price': '0.00',
#    'price_ca': '0.00',
#    'price_uk': '0.00',
#    'price_au': '0.00',
#    'msrp': 0,
#    'msrps': [{'country': 'US', 'price': 0},
#     {'country': 'CA', 'price': 0},
#     {'country': 'UK', 'price': 0}],
#    'discount': '0.00',
#    'year_published': 2019,
#    'min_players': 2,
#    'max_players': 6,
#    'min_playtime': 120,
#    'max_playtime': 180,
#    'min_age': 14,
#    'description': '',
#    'commentary': '',
#    'faq': '',
#    'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1604518351860',
#    'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1604518351860',
#    'matches_specs': None,
#    'specs': [],
#    'mechanics': [],
#    'categories': [{'id': '2bdFPJUvFo',
#      'url': 'https://www.boardgameatlas.com/category/2bdFPJUvFo/undefined'},
#     {'id': 'JwHcKqxh33',
#      'url': 'https://www.boardgameatlas.com/category/JwHcKqxh33/undefined'}],
#    'publishers': [{'id': 'ZOP4wDStJq',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/ZOP4wDStJq/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'designers': [{'id': 'BdPG85Zytq',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/BdPG85Zytq/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'primary_publisher': {'id': 'ZOP4wDStJq',
#     'name': 'All-Aboard Games',
#     'url': 'https://www.boardgameatlas.com/publisher/ZOP4wDStJq/allaboard-games'},
#    'primary_designer': {'id': 'BdPG85Zytq',
#     'name': 'Marc Voyer',
#     'url': 'https://www.boardgameatlas.com/designer/BdPG85Zytq/marc-voyer'},
#    'developers': [],
#    'related_to': [],
#    'artists': [],
#    'names': [],
#    'rules_url': None,
#    'official_url': None,
#    'comment_count': 0,
#    'num_user_ratings': 3,
#    'average_user_rating': 4.583333333333333,
#    'active': True,
#    'num_user_complexity_votes': 0,
#    'average_learning_complexity': 0,
#    'average_strategy_complexity': 0,
#    'visits': 169,
#    'lists': 60,
#    'mentions': 1,
#    'links': 0,
#    'plays': 73,
#    'rank': 9999999,
#    'type': 'game',
#    'num_distributors': 0,
#    'trending_rank': 0,
#    'listing_clicks': 0,
#    'is_historical_low': False,
#    'price_text': 'Price: N/A',
#    'tags': [],
#    'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1604518351860',
#     'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1604518351860',
#     'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1604518351860',
#     'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1604518351860',
#     'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1604518351860'},
#    'description_preview': ''},
#   {'id': 'CCVU6BS9gA',
#    'handle': '1856',
#    'url': 'https://www.boardgameatlas.com/game/CCVU6BS9gA/1856',
#    'edit_url': 'https://www.boardgameatlas.com/game/CCVU6BS9gA/edit',
#    'name': '1856',
#    'price': '0.00',
#    'price_ca': '0.00',
#    'price_uk': '0.00',
#    'price_au': '0.00',
#    'msrp': 0,
# ...
#     {'id': 'wPcKOr57ig',
#      'url': 'https://www.boardgameatlas.com/mechanic/wPcKOr57ig/undefined'},
#     {'id': '8PN2HE86wg',
#      'url': 'https://www.boardgameatlas.com/mechanic/8PN2HE86wg/undefined'}],
#    'categories': [{'id': '2bdFPJUvFo',
#      'url': 'https://www.boardgameatlas.com/category/2bdFPJUvFo/undefined'},
#     {'id': 'rrvd68LjOR',
#      'url': 'https://www.boardgameatlas.com/category/rrvd68LjOR/undefined'}],
#    'publishers': [{'id': '2gCdLkM78R',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/2gCdLkM78R/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'designers': [{'id': 'z4ZFRHDM3X',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/z4ZFRHDM3X/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'primary_publisher': {},
#    'primary_designer': {},
#    'developers': ['Josh starr'],
#    'related_to': [],
#    'artists': ['Karim chakroun'],
#    'names': [],
#    'rules_url': None,
#    'official_url': 'https://www.kickstarter.com/projects/joshuastarr/shikoku-1889?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#    'sell_sheet_url': None,
#    'store_images_url': None,
#    'comment_count': 0,
#    'num_user_ratings': 0,
#    'average_user_rating': 0,
#    'active': True,
#    'num_user_complexity_votes': 1,
#    'average_learning_complexity': 3,
#    'average_strategy_complexity': 4,
#    'visits': 50,
#    'lists': 2,
#    'mentions': 0,
#    'links': 0,
#    'plays': 0,
#    'rank': 9999999,
#    'type': 'game',
#    'num_distributors': 0,
#    'trending_rank': 0,
#    'listing_clicks': 0,
#    'is_historical_low': False,
#    'price_text': 'Price: N/A',
#    'tags': [],
#    'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1639274448082.png',
#     'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1639274448082.png',
#     'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1639274448082.png',
#     'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1639274448082.png',
#     'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1639274448082.png'},
#    'description_preview': ' This is a refresh of  1889: History of Shikoku Railways . In terms of the rules, it is the same game. However the difference in the art, graphic presentation, and overall presentation is astonishing. \r\n \xa0 \r\n Gameplay wise this remains one of the best introductions to the fascinating genre of 18xx. And this new affordable edition is a great choice for anybody wishing to see what 18xx is all about.\xa0 '},
#   {'id': 'f2t0bIbJg3',
#    'handle': '1828',
#    'url': 'https://www.boardgameatlas.com/game/f2t0bIbJg3/1828',
#    'edit_url': 'https://www.boardgameatlas.com/game/f2t0bIbJg3/edit',
#    'name': '1828',
#    'price': '0.00',
#    'price_ca': '0.00',
#    'price_uk': '0.00',
#    'price_au': '0.00',
#    'msrp': 0,
#    'msrps': [{'country': 'US', 'price': 0}],
#    'discount': '0.00',
#    'year_published': 2018,
#    'min_players': 3,
#    'max_players': 5,
#    'min_playtime': 210,
#    'max_playtime': 420,
#    'min_age': 16,
#    'description': '',
#    'commentary': '',
#    'faq': '',
#    'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1571421545969',
#    'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1571421545969',
#    'matches_specs': None,
#    'specs': [],
#    'mechanics': [],
#    'categories': [{'id': '2bdFPJUvFo',
#      'url': 'https://www.boardgameatlas.com/category/2bdFPJUvFo/undefined'}],
#    'publishers': [],
#    'designers': [{'id': 'sYv4f7yHPj',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/sYv4f7yHPj/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'primary_designer': {'name': 'J. C. Lawrence',
#     'id': 'sYv4f7yHPj',
#     'url': 'https://www.boardgameatlas.com/designer/sYv4f7yHPj/j-c-lawrence'},
#    'developers': [],
#    'related_to': [],
#    'artists': ['J. C. Lawrence'],
#    'names': [],
#    'rules_url': None,
#    'official_url': ',?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#    'comment_count': 0,
#    'num_user_ratings': 1,
#    'average_user_rating': 4,
#    'active': True,
#    'num_user_complexity_votes': 0,
#    'average_learning_complexity': 0,
#    'average_strategy_complexity': 0,
#    'visits': 49,
#    'lists': 16,
#    'mentions': 0,
#    'links': 0,
#    'plays': 29,
#    'rank': 9999999,
#    'type': 'game',
#    'num_distributors': 0,
#    'trending_rank': 0,
#    'listing_clicks': 0,
#    'is_historical_low': False,
#    'price_text': 'Price: N/A',
#    'tags': ['1828'],
#    'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1571421545969',
#     'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1571421545969',
#     'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1571421545969',
#     'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1571421545969',
#     'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1571421545969'},
#    'description_preview': ''},
#   {'id': 'EBmYf5NVzC',
#    'handle': '1870',
#    'url': 'https://www.boardgameatlas.com/game/EBmYf5NVzC/1870',
#    'edit_url': 'https://www.boardgameatlas.com/game/EBmYf5NVzC/edit',
#    'name': '1870',
#    'price': '626.58',
#    'price_ca': '0.00',
#    'price_uk': '0.00',
#    'price_au': '0.00',
#    'msrp': 0,
#    'msrps': [{'country': 'US', 'price': 0}],
#    'discount': '0.00',
#    'year_published': 1978,
#    'min_players': 2,
#    'max_players': 2,
#    'min_playtime': 180,
#    'max_playtime': 180,
#    'min_age': 12,
#    'description': '<p>This extension of the 18xx game takes players to the trans- Mississippi Valley of Midwestern America. 1870 combines the successful 18xx system with a new geographic venue and new custom rules while still allowing players to build railroad and enter into share speculation. The ability to engage in the infamous abuses of corporate power only add to the fun. For 3 to 7 players ages 16 and up.</p>',
#    'commentary': '',
#    'faq': '',
#    'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559257366134-41A07MK25WL.jpg',
#    'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559257366134-41A07MK25WL.jpg',
#    'matches_specs': None,
#    'specs': [],
#    'mechanics': [],
#    'categories': [{'id': '2bdFPJUvFo',
#      'url': 'https://www.boardgameatlas.com/category/2bdFPJUvFo/undefined'}],
#    'publishers': [{'id': '7GTti1NuCH',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/7GTti1NuCH/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'designers': [{'id': 'LBjFNBDqNx',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/LBjFNBDqNx/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'primary_publisher': {'name': 'Mayfair Games',
#     'id': '7GTti1NuCH',
#     'url': 'https://www.boardgameatlas.com/publisher/7GTti1NuCH/mayfair-games'},
#    'primary_designer': {'name': 'Jean-Pierre Défieux',
#     'id': 'LBjFNBDqNx',
#     'url': 'https://www.boardgameatlas.com/designer/LBjFNBDqNx/jeanpierre-dfieux'},
#    'developers': [],
#    'related_to': [],
#    'artists': [],
#    'names': [],
#    'rules_url': None,
#    'amazon_rank': 2080371,
#    'official_url': None,
#    'comment_count': 0,
#    'num_user_ratings': 0,
#    'average_user_rating': 0,
#    'historical_low_prices': [{'country': 'CA',
#      'date': '2021-12-07T12:19:23.575Z',
#      'price': 586.18,
#      'isLow': True},
#     {'country': 'US',
#      'date': '2022-02-12T20:58:13.402Z',
#      'price': 626.58,
#      'isLow': True}],
#    'active': True,
#    'num_user_complexity_votes': 0,
#    'average_learning_complexity': 0,
#    'average_strategy_complexity': 0,
#    'visits': 41,
#    'lists': 1,
#    'mentions': 0,
#    'links': 0,
#    'plays': 0,
#    'rank': 9999999,
#    'type': 'game',
#    'num_distributors': 0,
#    'trending_rank': 0,
#    'listing_clicks': 0,
#    'is_historical_low': True,
#    'price_text': '$626.58',
#    'tags': [],
#    'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1559257366134-41A07MK25WL.jpg',
#     'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1559257366134-41A07MK25WL.jpg',
#     'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1559257366134-41A07MK25WL.jpg',
#     'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1559257366134-41A07MK25WL.jpg',
#     'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559257366134-41A07MK25WL.jpg'},
#    'description_preview': ' This extension of the 18xx game takes players to the trans- Mississippi Valley of Midwestern America. 1870 combines the successful 18xx system with a new geographic venue and new custom rules while still allowing players to build railroad and enter into share speculation. The ability to engage in the infamous abuses of corporate power only add to the fun. For 3 to 7 players ages 16 and up. '},
#   {'id': 'ptpfJSjdrm',
#    'handle': '1834',
#    'url': 'https://www.boardgameatlas.com/game/ptpfJSjdrm/1834',
#    'edit_url': 'https://www.boardgameatlas.com/game/ptpfJSjdrm/edit',
#    'name': '1834',
#    'price': '0.00',
#    'price_ca': '0.00',
#    'price_uk': '0.00',
#    'price_au': '0.00',
#    'msrp': 0,
#    'msrps': [{'country': 'US', 'price': 0}],
#    'discount': '0.00',
#    'year_published': 2018,
#    'min_players': 3,
#    'max_players': 5,
#    'min_playtime': 120,
#    'max_playtime': 240,
#    'min_age': None,
#    'description': "<p>'Eddie Robbins' (John Bohrer)'s <strong>1834</strong> is an 18xx game set in one of the earliest and most important locations in the development of railroads: Belgium &amp; Luxembourg. Providing service to Antwerp, linking international markets, fostering the steel industry in Luxembourg and obviating the Albert Canal are important features to this game. The late appearance of electrified railways has a big impact.</p>\r\n<p>For 3-5 players, one needs a copy of the Avalon Hill 1830 game to provide the trains and tiles, although 4 special tiles are provided with 1834. The player with the most money wins the game.</p>",
#    'commentary': '',
#    'faq': '',
#    'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1548458638391',
#    'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1548458638391',
#    'matches_specs': None,
#    'specs': [],
#    'mechanics': [],
#    'categories': [{'id': '2bdFPJUvFo',
#      'url': 'https://www.boardgameatlas.com/category/2bdFPJUvFo/undefined'}],
#    'publishers': [{'id': 'rIXWSFX4sv',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/publisher/rIXWSFX4sv/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'designers': [{'id': 'KTeVFvo1uV',
#      'num_games': None,
#      'score': 9999999,
#      'game': {},
#      'url': 'https://www.boardgameatlas.com/designer/KTeVFvo1uV/undefined',
#      'images': {'thumb': None,
#       'small': None,
#       'medium': None,
#       'large': None,
#       'original': None}}],
#    'primary_publisher': {'name': 'Winsome Games',
#     'id': 'rIXWSFX4sv',
#     'url': 'https://www.boardgameatlas.com/publisher/rIXWSFX4sv/winsome-games'},
#    'primary_designer': {},
#    'developers': [],
#    'related_to': [],
#    'artists': [],
#    'names': [],
#    'rules_url': None,
#    'official_url': ',?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#    'comment_count': 0,
#    'num_user_ratings': 3,
#    'average_user_rating': 3.6666666666666665,
#    'active': True,
#    'num_user_complexity_votes': 0,
#    'average_learning_complexity': 0,
#    'average_strategy_complexity': 0,
#    'visits': 38,
#    'lists': 17,
#    'mentions': 0,
#    'links': 0,
#    'plays': 3,
#    'rank': 9999999,
#    'type': 'game',
#    'num_distributors': 0,
#    'trending_rank': 0,
#    'listing_clicks': 0,
#    'is_historical_low': False,
#    'price_text': 'Price: N/A',
#    'tags': ['1834'],
#    'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1548458638391',
#     'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1548458638391',
#     'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1548458638391',
#     'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1548458638391',
#     'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1548458638391'},
#    'description_preview': " 'Eddie Robbins' (John Bohrer)'s  1834  is an 18xx game set in one of the earliest and most important locations in the development of railroads: Belgium & Luxembourg. Providing service to Antwerp, linking international markets, fostering the steel industry in Luxembourg and obviating the Albert Canal are important features to this game. The late appearance of electrified railways has a big impact. \r\n For 3-5 players, one needs a copy of the Avalon Hill 1830 game to provide the trains and tiles, although 4 special tiles are provided with 1834. The player with the most money wins the game. "},
#   {'id': 'd74Pz3XA4M',
#    'handle': '18-los-angeles',
#    'url': 'https://www.boardgameatlas.com/game/d74Pz3XA4M/18-los-angeles',
#    'edit_url': 'https://www.boardgameatlas.com/game/d74Pz3XA4M/edit',
#    'name': '18 Los Angeles',
#    'price': '0.00',
#    'price_ca': '0.00',
#    'price_uk': '0.00',
#    'price_au': '0.00',
#    'msrp': 0,
#    'msrps': [{'country': 'US', 'price': 0}],
#    'discount': '0.00',
#    'year_published': 2020,
#    'min_players': 2,
#    'max_players': 5,
#    'min_playtime': None,
#    'max_playtime': None,
#    'min_age': None,
#    'description': '',
#    'commentary': '',
#    'faq': '',
#    'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1595255678029',
#    'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1595255678029',
#    'matches_specs': None,
#    'specs': [],
#    'mechanics': [{'id': 'qCXa8MX0wk',
#      'url': 'https://www.boardgameatlas.com/mechanic/qCXa8MX0wk/undefined'}],
#    'categories': [{'id': '2bdFPJUvFo',
#      'url': 'https://www.boardgameatlas.com/category/2bdFPJUvFo/undefined'}],
#    'publishers': [],
#    'designers': [],
#    'primary_publisher': {},
#    'primary_designer': {},
#    'developers': [],
#    'related_to': [],
#    'artists': [],
#    'names': [],
#    'rules_url': None,
#    'official_url': None,
#    'comment_count': 0,
#    'num_user_ratings': 1,
#    'average_user_rating': 3.75,
#    'active': True,
#    'num_user_complexity_votes': 0,
#    'average_learning_complexity': 0,
#    'average_strategy_complexity': 0,
#    'visits': 17,
#    'lists': 8,
#    'mentions': 0,
#    'links': 0,
#    'plays': 12,
#    'rank': 9999999,
#    'type': 'game',
#    'num_distributors': 0,
#    'trending_rank': 0,
#    'listing_clicks': 0,
#    'is_historical_low': False,
#    'price_text': 'Price: N/A',
#    'tags': ['18 Los Angeles'],
#    'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1595255678029',
#     'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1595255678029',
#     'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1595255678029',
#     'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1595255678029',
#     'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1595255678029'},
#    'description_preview': ''}],
#  'count': 24}

# %%
# Get board games
categ_df = pd.DataFrame()
for category_id in categ_ids:
    next_categ_url = 'https://api.boardgameatlas.com/api/search?client_id=6MXavgYBke&limit=100&categories={}'.format(category_id)
    next_response = requests.get(next_categ_url)
    next_games_dict = json.loads(next_response.text)
    categ_df = categ_df.append(pd.DataFrame(next_games_dict['games']))
    time.sleep(1)
    if next_games_dict['count'] > 1000:
        for hundred in list(range(1,11)):
            limit = 100 * hundred
            next_categ_url = 'https://api.boardgameatlas.com/api/search?client_id=6MXavgYBke&limit=100&categories={}&skip={}'.format(category_id , limit)
            next_response = requests.get(next_categ_url)
            next_games_dict = json.loads(next_response.text)
            categ_df = categ_df.append(pd.DataFrame(next_games_dict['games']))
            time.sleep(1)
    elif next_games_dict['count'] > 100:
        for hundred in list(range(1,(math.ceil(next_games_dict['count'] / 100)))):
            limit = 100 * hundred
            next_categ_url = 'https://api.boardgameatlas.com/api/search?client_id=6MXavgYBke&limit=100&categories={}&skip={}'.format(category_id , limit)
            next_response = requests.get(next_categ_url)
            next_games_dict = json.loads(next_response.text)
            categ_df = categ_df.append(pd.DataFrame(next_games_dict['games']))
            time.sleep(1)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
# Save dataset part
categ_df_name = categ_df[['name', 'id']]
categ_df_name.to_csv("categ_df_name.csv", sep=';' , quotechar='"')

# %%
# Export data
categ_df.to_csv("categ_df.csv", sep=';' , quotechar='"')

# %%
# Feature list
categ_df.dtypes
# Out:
# active                            bool
# amazon_rank                    float64
# artists                         object
# availability_status             object
# average_learning_complexity    float64
# average_strategy_complexity    float64
# average_user_rating            float64
# categories                      object
# comment_count                    int64
# commentary                      object
# cs_rating                      float64
# description                     object
# description_preview             object
# designers                       object
# developers                      object
# discount                        object
# distributors                    object
# edit_url                        object
# faq                             object
# handle                          object
# historical_low_prices           object
# id                              object
# image_url                       object
# images                          object
# is_historical_low                 bool
# isbn                            object
# links                            int64
# listing_clicks                   int64
# lists                            int64
# matches_specs                   object
#                                 ...
# price                           object
# price_au                        object
# price_ca                        object
# price_text                      object
# price_uk                        object
# primary_designer                object
# primary_publisher               object
# publishers                      object
# rank                             int64
# related_to                      object
# rules_url                       object
# sell_sheet_url                  object
# size_depth                     float64
# size_height                    float64
# size_units                      object
# size_width                     float64
# sku                             object
# specs                           object
# store_images_url                object
# tags                            object
# thumb_url                       object
# trending_rank                    int64
# type                            object
# upc                             object
# url                             object
# video_links                     object
# visits                           int64
# weight_amount                  float64
# weight_units                    object
# year_published                 float64
# Length: 77, dtype: object

# %%
# Check number of nulls
categ_df.isnull().sum()
# Out:
# active                             0
# amazon_rank                    11353
# artists                            0
# availability_status            14311
# average_learning_complexity        0
# average_strategy_complexity        0
# average_user_rating                0
# categories                         0
# comment_count                      0
# commentary                         0
# cs_rating                      13452
# description                        0
# description_preview                0
# designers                          0
# developers                         0
# discount                           0
# distributors                    9913
# edit_url                           0
# faq                                0
# handle                             0
# historical_low_prices           4625
# id                                 0
# image_url                          0
# images                             0
# is_historical_low                  0
# isbn                           14311
# links                              0
# listing_clicks                     0
# lists                              0
# matches_specs                  15010
#                                ...
# price                              0
# price_au                           0
# price_ca                           0
# price_text                         0
# price_uk                           0
# primary_designer                 875
# primary_publisher                768
# publishers                         0
# rank                               0
# related_to                         0
# rules_url                      12390
# sell_sheet_url                 15248
# size_depth                     14227
# size_height                    13919
# size_units                     14439
# size_width                     15060
# sku                            11804
# specs                              0
# store_images_url               15234
# tags                               0
# thumb_url                          0
# trending_rank                      0
# type                               2
# upc                            11811
# url                                0
# video_links                    14392
# visits                             0
# weight_amount                  14327
# weight_units                   14465
# year_published                  2118
# Length: 77, dtype: int64

# %%
# Check dataset
categ_df.head()
# Out:
#    active  amazon_rank                                            artists  \
# 0    True     559911.0  [Mike Atkinson, Jared Blando, Charles Kibler, ...
# 1    True          NaN                                      [Mike Hutton]
# 2    True          NaN                              [Brigette Indelicato]
# 3    True     473334.0                                    [Klemens Franz]
# 4    True          NaN                                                 []
#
#   availability_status  average_learning_complexity  \
# 0                 NaN                          3.0
# 1                 NaN                          0.0
# 2                 NaN                          3.0
# 3                 NaN                          0.0
# 4                 NaN                          0.0
#
#    average_strategy_complexity  average_user_rating  \
# 0                          4.5             4.006944
# 1                          0.0             4.111111
# 2                          4.0             4.454545
# 3                          0.0             4.000000
# 4                          0.0             4.200000
#
#                                           categories  comment_count  \
# 0  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
# 1  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
# 2  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
# 3  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
# 4  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
#
#   commentary  ...                                          thumb_url  \
# 0             ...  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 1             ...  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 2             ...  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 3             ...  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 4             ...  https://s3-us-west-1.amazonaws.com/5cc.images/...
#
#   trending_rank  type           upc  \
# 0             0  game           NaN
# 1             0  game  817054011704
# 2             0  game           NaN
# 3             0  game           NaN
# 4             0  game           NaN
#
#                                                  url video_links visits  \
# 0  https://www.boardgameatlas.com/game/o6knI5ct0u...         NaN   1869
# 1  https://www.boardgameatlas.com/game/uEPtE5OOOU...         NaN   1048
# 2  https://www.boardgameatlas.com/game/Krn8i8C0fI...         NaN    856
# 3  https://www.boardgameatlas.com/game/eJuGpFzljd...         NaN    498
# 4  https://www.boardgameatlas.com/game/IKKs90JOkr...         NaN    367
#
#   weight_amount weight_units year_published
# 0           NaN          NaN         1986.0
# 1           NaN          NaN         2013.0
# 2           NaN          NaN         2020.0
# 3           NaN          NaN         2016.0
# 4           NaN          NaN         2016.0
#
# [5 rows x 77 columns]

# %%
# Keep only useful fields
categ_df_short = categ_df.loc[:, categ_df.columns.isin([
'average_learning_complexity',
'average_strategy_complexity',
'average_user_rating',
'categories',
'comment_count',
'price',
'price_text',
'rank',
'year_published'    
])]

# %%
categ_df_short.isnull().sum()
# Out:
# average_learning_complexity       0
# average_strategy_complexity       0
# average_user_rating               0
# categories                        0
# comment_count                     0
# price                             0
# price_text                        0
# rank                              0
# year_published                 2119
# dtype: int64

# %%
len(categ_df)
# Out:
# 15270

# %%
# Out:
#    active  amazon_rank                                            artists  \
# 0    True     559911.0  [Mike Atkinson, Jared Blando, Charles Kibler, ...
# 1    True          NaN                                      [Mike Hutton]
# 2    True          NaN                              [Brigette Indelicato]
# 3    True     473334.0                                    [Klemens Franz]
# 4    True          NaN                                                 []
#
#   availability_status  average_learning_complexity  \
# 0                 NaN                          3.0
# 1                 NaN                          0.0
# 2                 NaN                          3.0
# 3                 NaN                          0.0
# 4                 NaN                          0.0
#
#    average_strategy_complexity  average_user_rating  \
# 0                          4.5             4.006944
# 1                          0.0             4.111111
# 2                          4.0             4.454545
# 3                          0.0             4.000000
# 4                          0.0             4.200000
#
#                                           categories  comment_count  \
# 0  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
# 1  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
# 2  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
# 3  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
# 4  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
#
#   commentary  ...                                          thumb_url  \
# 0             ...  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 1             ...  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 2             ...  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 3             ...  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 4             ...  https://s3-us-west-1.amazonaws.com/5cc.images/...
#
#   trending_rank  type           upc  \
# 0             0  game           NaN
# 1             0  game  817054011704
# 2             0  game           NaN
# 3             0  game           NaN
# 4             0  game           NaN
#
#                                                  url video_links visits  \
# 0  https://www.boardgameatlas.com/game/o6knI5ct0u...         NaN   1869
# 1  https://www.boardgameatlas.com/game/uEPtE5OOOU...         NaN   1048
# 2  https://www.boardgameatlas.com/game/Krn8i8C0fI...         NaN    856
# 3  https://www.boardgameatlas.com/game/eJuGpFzljd...         NaN    498
# 4  https://www.boardgameatlas.com/game/IKKs90JOkr...         NaN    367
#
#   weight_amount weight_units year_published
# 0           NaN          NaN         1986.0
# 1           NaN          NaN         2013.0
# 2           NaN          NaN         2020.0
# 3           NaN          NaN         2016.0
# 4           NaN          NaN         2016.0
#
# [5 rows x 77 columns]

# %%
# Number of unique board games
len(categ_df['name'].unique())
# Out:
# 7592

# %%
# Number of unique board games
sum(categ_df.duplicated(subset=['name', 'year_published']))
# Out:
# 7647

# %%
sum(categ_df.duplicated(subset=['name']))
# Out:
# 7678

# %%
# Remove duplicates
no_duplicate_categ_df = categ_df[~categ_df.duplicated(subset=['name'])]

# %%
len(no_duplicate_categ_df)
# Out:
# 7592

# %%
# Lowercase name
no_duplicate_categ_df['name_lower']=no_duplicate_categ_df['name'].str.lower()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
no_duplicate_categ_df.head()
# Out:
#    active  amazon_rank                                            artists  \
# 0    True     559911.0  [Mike Atkinson, Jared Blando, Charles Kibler, ...
# 1    True          NaN                                      [Mike Hutton]
# 2    True          NaN                              [Brigette Indelicato]
# 3    True     473334.0                                    [Klemens Franz]
# 4    True          NaN                                                 []
#
#   availability_status  average_learning_complexity  \
# 0                 NaN                          3.0
# 1                 NaN                          0.0
# 2                 NaN                          3.0
# 3                 NaN                          0.0
# 4                 NaN                          0.0
#
#    average_strategy_complexity  average_user_rating  \
# 0                          4.5             4.006944
# 1                          0.0             4.111111
# 2                          4.0             4.454545
# 3                          0.0             4.000000
# 4                          0.0             4.200000
#
#                                           categories  comment_count  \
# 0  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
# 1  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
# 2  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
# 3  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
# 4  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
#
#   commentary  ...  trending_rank  type           upc  \
# 0             ...              0  game           NaN
# 1             ...              0  game  817054011704
# 2             ...              0  game           NaN
# 3             ...              0  game           NaN
# 4             ...              0  game           NaN
#
#                                                  url video_links visits  \
# 0  https://www.boardgameatlas.com/game/o6knI5ct0u...         NaN   1869
# 1  https://www.boardgameatlas.com/game/uEPtE5OOOU...         NaN   1048
# 2  https://www.boardgameatlas.com/game/Krn8i8C0fI...         NaN    856
# 3  https://www.boardgameatlas.com/game/eJuGpFzljd...         NaN    498
# 4  https://www.boardgameatlas.com/game/IKKs90JOkr...         NaN    367
#
#   weight_amount weight_units year_published  \
# 0           NaN          NaN         1986.0
# 1           NaN          NaN         2013.0
# 2           NaN          NaN         2020.0
# 3           NaN          NaN         2016.0
# 4           NaN          NaN         2016.0
#
#                                     name_lower
# 0               1830: railways & robber barons
# 1  1862: railway mania in the eastern counties
# 2                                 18chesapeake
# 3                                  1844 / 1854
# 4          1822: the railways of great britain
#
# [5 rows x 78 columns]

# %%
no_duplicate_categ_df['name'].head()
# Out:
# 0                 1830: Railways & Robber Barons
# 1    1862: Railway Mania in the Eastern Counties
# 2                                   18Chesapeake
# 3                                    1844 / 1854
# 4            1822: The Railways of Great Britain
# Name: name, dtype: object

# %% [markdown]
# **III. Join**

# %%
united_df = pd.merge(board_games_raw, no_duplicate_categ_df, how='inner', left_on='name_lower', right_on='name_lower')

# %%
len(united_df)
# Out:
# 1333

# %%
board_games_raw['name'].head()
# Out:
# 0        Die Macher
# 1      Dragonmaster
# 2           Samurai
# 3    Tal der Könige
# 4           Acquire
# Name: name, dtype: object

# %%
united_df = pd.merge(board_games_raw, no_duplicate_categ_df, how='left', left_on='name', right_on='name')

# %%
len(united_df)
# Out:
# 10532

# %%
len(united_df) - united_df['id'].isnull().sum()
# Out:
# 1266

# %%
united_df['id'].isnull().sum()
# Out:
# 9266

# %%
pop_df = pd.DataFrame()
for offset in list(range(0,11)):
    pop_url = 'https://api.boardgameatlas.com/api/search?limit=100&client_id=6MXavgYBke&skip={}'.format(num*100)
    pop_response = requests.get(pop_url)
    pop_dict = json.loads(pop_response.text)
    pop_df = pop_df.append(pd.DataFrame(pop_dict['games']))
    time.sleep(1)

# %%
len(pop_df)
# Out:
# 1100

# %%
len(no_duplicate_categ_df)
# Out:
# 7421

# %%
combined_df = no_duplicate_categ_df.append(pop_df)
len(combined_df)
# Out:
# 8521

# %%
combined_df = combined_df[~combined_df.duplicated(subset=['name'])]
len(combined_df)
# Out:
# 7475

# %%
united_df = pd.merge(board_games_raw, combined_df, how='left', left_on='name', right_on='name')
print(len(united_df))
len(united_df) - united_df['id'].isnull().sum()
# Out:
# 10532
# 1301
