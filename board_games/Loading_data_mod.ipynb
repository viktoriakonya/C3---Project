# %% [markdown]
# **Import libraries**

# %%
import pandas as pd
import requests
import json
import time
import math

# %% [markdown]
# ## **I. Data from tidyTuesday**

# %% [markdown]
# ####  1. Import and check data

# %%
# Import and check data
board_games_raw = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2019/2019-03-12/board_games.csv")

# %%
# Check data
board_games_raw.head()
# Out:
#    game_id                                        description  \
# 0        1  Die Macher is a game about seven sequential po...
# 1        2  Dragonmaster is a trick-taking card game based...
# 2        3  Part of the Knizia tile-laying trilogy, Samura...
# 3        4  When you see the triangular box and the luxuri...
# 4        5  In Acquire, each player strategically invests ...
#
#                                           image  max_players  max_playtime  \
# 0   //cf.geekdo-images.com/images/pic159509.jpg            5           240
# 1   //cf.geekdo-images.com/images/pic184174.jpg            4            30
# 2  //cf.geekdo-images.com/images/pic3211873.jpg            4            60
# 3   //cf.geekdo-images.com/images/pic285299.jpg            4            60
# 4   //cf.geekdo-images.com/images/pic342163.jpg            6            90
#
#    min_age  min_players  min_playtime            name  playing_time  \
# 0       14            3           240      Die Macher           240
# 1       12            3            30    Dragonmaster            30
# 2       10            2            30         Samurai            60
# 3       12            2            60  Tal der Könige            60
# 4       12            3            90         Acquire            90
#
#                                         thumbnail  year_published  \
# 0   //cf.geekdo-images.com/images/pic159509_t.jpg            1986
# 1   //cf.geekdo-images.com/images/pic184174_t.jpg            1981
# 2  //cf.geekdo-images.com/images/pic3211873_t.jpg            1998
# 3   //cf.geekdo-images.com/images/pic285299_t.jpg            1992
# 4   //cf.geekdo-images.com/images/pic342163_t.jpg            1964
#
#                         artist                        category compilation  \
# 0          Marcus Gschwendtner  Economic,Negotiation,Political         NaN
# 1                   Bob Pepper               Card Game,Fantasy         NaN
# 2              Franz Vohwinkel      Abstract Strategy,Medieval         NaN
# 3                          NaN                         Ancient         NaN
# 4  Scott Okumura,Peter Whitley                        Economic         NaN
#
#                 designer expansion  \
# 0     Karl-Heinz Schmiel       NaN
# 1  G. W. "Jerry" D'Arcey       NaN
# 2          Reiner Knizia       NaN
# 3      Christian Beierer       NaN
# 4            Sid Sackson       NaN
#
#                                               family  \
# 0         Country: Germany,Valley Games Classic Line
# 1                                   Animals: Dragons
# 2  Asian Theme,Country: Japan,Knizia tile-laying ...
# 3             Country: Egypt,Promotional Board Games
# 4                                3M Bookshelf Series
#
#                                             mechanic  \
# 0  Area Control / Area Influence,Auction/Bidding,...
# 1                                       Trick-taking
# 2  Area Control / Area Influence,Hand Management,...
# 3  Action Point Allowance System,Area Control / A...
# 4       Hand Management,Stock Holding,Tile Placement
#
#                                            publisher  average_rating  \
# 0  Hans im Glück Verlags-GmbH,Moskito Spiele,Vall...         7.66508
# 1                           E.S. Lowe,Milton Bradley         6.60815
# 2  999 Games,ABACUSSPIELE,Astrel Games,Ceilikan J...         7.44119
# 3                                             KOSMOS         6.60675
# 4  3M,Avalon Hill,Avalon Hill (Hasbro),Dujardin,G...         7.35830
#
#    users_rated
# 0         4498
# 1          478
# 2        12019
# 3          314
# 4        15195

# %%
len(board_games_raw)
# Out:
# 10532

# %% [markdown]
# #### 2. Remove duplicates

# %%
# Number of duplicate board games
sum(board_games_raw.duplicated(subset=['name']))
# Out:
# 175

# %%
# Number of duplicate board games
sum(board_games_raw.duplicated(subset=['name', 'year_published']))
# Out:
# 2

# %%
# Remove duplicates for name + year_published
board_games_raw = board_games_raw[~board_games_raw.duplicated(subset=['name', 'year_published'])]

# %%
len(board_games_raw)
# Out:
# 10530

# %% [markdown]
# #### 3. Keep only the needed fields

# %%
# Check number of nulls
board_games_raw.isnull().sum()
# Out:
# game_id               0
# description           0
# image                 1
# max_players           0
# max_playtime          0
# min_age               0
# min_players           0
# min_playtime          0
# name                  0
# playing_time          0
# thumbnail             1
# year_published        0
# artist             2773
# category             94
# compilation       10120
# designer            126
# expansion          7778
# family             2808
# mechanic            949
# publisher             3
# average_rating        0
# users_rated           0
# dtype: int64

# %%
# Feature list
board_games_raw.dtypes
# Out:
# game_id             int64
# description        object
# image              object
# max_players         int64
# max_playtime        int64
# min_age             int64
# min_players         int64
# min_playtime        int64
# name               object
# playing_time        int64
# thumbnail          object
# year_published      int64
# artist             object
# category           object
# compilation        object
# designer           object
# expansion          object
# family             object
# mechanic           object
# publisher          object
# average_rating    float64
# users_rated         int64
# dtype: object

# %%
# Remove fields with high null rate
board_games_raw = board_games_raw.loc[:, ~board_games_raw.columns.isin(['image', 'thumbnail', 'compilation', 'expansion'])]

# %% [markdown]
# #### 4. Data cleaning

# %%
# Lowercase name
board_games_raw['name_lower']=board_games_raw['name'].str.lower()

# %%
# Todo: make list of family, mechanic, publisher like below but here we need to keep it as a sting to save it as csv
# board_games_raw['family_split']=board_games_raw['family'].str.split(',')
# board_games_raw['family_split'][0][0]

# %% [markdown]
# #### 5. Save dataset

# %%
board_games_raw.head()
# Out:
#    game_id                                        description  max_players  \
# 0        1  Die Macher is a game about seven sequential po...            5
# 1        2  Dragonmaster is a trick-taking card game based...            4
# 2        3  Part of the Knizia tile-laying trilogy, Samura...            4
# 3        4  When you see the triangular box and the luxuri...            4
# 4        5  In Acquire, each player strategically invests ...            6
#
#    max_playtime  min_age  min_players  min_playtime            name  \
# 0           240       14            3           240      Die Macher
# 1            30       12            3            30    Dragonmaster
# 2            60       10            2            30         Samurai
# 3            60       12            2            60  Tal der Könige
# 4            90       12            3            90         Acquire
#
#    playing_time  year_published                       artist  \
# 0           240            1986          Marcus Gschwendtner
# 1            30            1981                   Bob Pepper
# 2            60            1998              Franz Vohwinkel
# 3            60            1992                          NaN
# 4            90            1964  Scott Okumura,Peter Whitley
#
#                          category               designer  \
# 0  Economic,Negotiation,Political     Karl-Heinz Schmiel
# 1               Card Game,Fantasy  G. W. "Jerry" D'Arcey
# 2      Abstract Strategy,Medieval          Reiner Knizia
# 3                         Ancient      Christian Beierer
# 4                        Economic            Sid Sackson
#
#                                               family  \
# 0         Country: Germany,Valley Games Classic Line
# 1                                   Animals: Dragons
# 2  Asian Theme,Country: Japan,Knizia tile-laying ...
# 3             Country: Egypt,Promotional Board Games
# 4                                3M Bookshelf Series
#
#                                             mechanic  \
# 0  Area Control / Area Influence,Auction/Bidding,...
# 1                                       Trick-taking
# 2  Area Control / Area Influence,Hand Management,...
# 3  Action Point Allowance System,Area Control / A...
# 4       Hand Management,Stock Holding,Tile Placement
#
#                                            publisher  average_rating  \
# 0  Hans im Glück Verlags-GmbH,Moskito Spiele,Vall...         7.66508
# 1                           E.S. Lowe,Milton Bradley         6.60815
# 2  999 Games,ABACUSSPIELE,Astrel Games,Ceilikan J...         7.44119
# 3                                             KOSMOS         6.60675
# 4  3M,Avalon Hill,Avalon Hill (Hasbro),Dujardin,G...         7.35830
#
#    users_rated      name_lower
# 0         4498      die macher
# 1          478    dragonmaster
# 2        12019         samurai
# 3          314  tal der könige
# 4        15195         acquire

# %%
# Save dataset 
board_games_raw.to_csv("board_games_raw.csv", sep=';' , quotechar='"')

# %% [markdown]
# ## **II. Call API**

# %% [markdown]
# #### 1. Get list of board game categories

# %%
# Get category list - Sample
categ_url = 'https://api.boardgameatlas.com/api/game/categories?client_id=6MXavgYBke'
categ_response = requests.get(categ_url)
categ_dict = json.loads(categ_response.text)
list(categ_dict.values())[0][0]
# Out:
# {'id': '2bdFPJUvFo',
#  'name': '18XX',
#  'url': 'https://www.boardgameatlas.com/category/2bdFPJUvFo/18xx'}

# %%
# Get category ids
categ_ids = []
for cat_num in list(range(0,len(categ_dict['categories']))):
    categ_ids.append(categ_dict['categories'][cat_num]['id'])
categ_ids[1:15]
# Out:
# ['85OKv8p5Ow',
#  'hBqZ3Ar4RJ',
#  'KUBCKBkGxV',
#  'DjAhqEHOD0',
#  '20iDvpbh7A',
#  'tJxatX2ZbW',
#  'nWDac9tQzt',
#  'dghLhwyxVb',
#  '4mOtRRwSoj',
#  'a8NM5cugJX',
#  'MWoxgHrOJD',
#  'eFaACC6y2c',
#  'CBboNLI1Uj',
#  'k0dglq5j6N']

# %%
# Number of categories
len(categ_ids)
# Out:
# 143

# %% [markdown]
# #### 2. Request board game data using the category ids

# %%
# Sample request
categ_url = 'https://api.boardgameatlas.com/api/search?client_id=6MXavgYBke&limit=100&categories=2bdFPJUvFo'
response = requests.get(categ_url)
games_dict = json.loads(response.text)
list(games_dict.values())[0][0]
# Out:
# {'id': 'o6knI5ct0u',
#  'handle': 'mayfair-games-1830-railways-and-robber-barons--north-east-us',
#  'url': 'https://www.boardgameatlas.com/game/o6knI5ct0u/mayfair-games-1830-railways-and-robber-barons--north-east-us',
#  'edit_url': 'https://www.boardgameatlas.com/game/o6knI5ct0u/edit',
#  'name': '1830: Railways & Robber Barons',
#  'price': '55.99',
#  'price_ca': '74.99',
#  'price_uk': '0.00',
#  'price_au': '89.95',
#  'msrp': 69.99,
#  'msrps': [{'country': 'US', 'price': 69.99}],
#  'discount': '0.20',
#  'year_published': 1986,
#  'min_players': 2,
#  'max_players': 7,
#  'min_playtime': 180,
#  'max_playtime': 360,
#  'min_age': 14,
#  'description': "<p>1830. It is the dawn of the &quot;Age of Railroading&quot; in America. You're a wealthy investor and speculator betting that the new technology will revolutionize transport. Commerce will no longer depend on rutted roads and slow canals. Instead, it will ride the rails on swift, powerful &quot;Iron Horses.&quot;</p>\r\n<p><strong>1830</strong> is an acclaimed railroad investment and building game covering the years 1830 to present. You and your fellow players become the stockholders of America's first railroad corporations. Since the largest shareholder becomes president, you compete for control of the strongest firms. As president, generate revenue by building track and buying and operating trains-regardless of shareholders' needs. Meanwhile, you pay heed to the volatile stock market. You strive to invest in flourishing companies in order to earn healthy dividends. You try to buy stock in corporations that are rising in value, collect strong, and sell before the stock values drop.</p>\r\n<p>Get ready to be a railroad baron. Start investing and building. Become America's first great rail tycoon!</p>\r\n<p>The 2011 version of <em>1830</em> was published by Mayfair Games in partnership with Lookout Games of Germany. This publication was developed under license from Francis Tresham in co-operation with Bruce Shelley (the original <em>1830</em> developer). This version contains rules and components for Francis Tresham's original classic design, a faster-playing basic game, and new variants from some of the world's best railroad game developers.</p>",
#  'commentary': '',
#  'faq': '',
#  'thumb_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559257858925-51BztJ2q4WL.jpg',
#  'image_url': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559257858925-51BztJ2q4WL.jpg',
#  'matches_specs': None,
#  'specs': [],
#  'mechanics': [{'id': 'AZxlPpi5oq',
#    'url': 'https://www.boardgameatlas.com/mechanic/AZxlPpi5oq/undefined'},
#   {'id': 'issXRWXSLg',
#    'url': 'https://www.boardgameatlas.com/mechanic/issXRWXSLg/undefined'},
#   {'id': 'BeD8NYAaSU',
#    'url': 'https://www.boardgameatlas.com/mechanic/BeD8NYAaSU/undefined'},
#   {'id': 'ohABM4GjbC',
#    'url': 'https://www.boardgameatlas.com/mechanic/ohABM4GjbC/undefined'},
#   {'id': 'jbLrZb1xIb',
#    'url': 'https://www.boardgameatlas.com/mechanic/jbLrZb1xIb/undefined'},
#   {'id': '8PN2HE86wg',
#    'url': 'https://www.boardgameatlas.com/mechanic/8PN2HE86wg/undefined'}],
#  'categories': [{'id': '2bdFPJUvFo',
#    'url': 'https://www.boardgameatlas.com/category/2bdFPJUvFo/undefined'},
#   {'id': 'N0TkEGfEsF',
#    'url': 'https://www.boardgameatlas.com/category/N0TkEGfEsF/undefined'},
#   {'id': 'JwHcKqxh33',
#    'url': 'https://www.boardgameatlas.com/category/JwHcKqxh33/undefined'},
#   {'id': 'CWYOF9xu7O',
#    'url': 'https://www.boardgameatlas.com/category/CWYOF9xu7O/undefined'}],
#  'publishers': [{'id': 'w1jOf2uAOD',
#    'num_games': None,
#    'score': 9999999,
#    'game': {},
#    'url': 'https://www.boardgameatlas.com/publisher/w1jOf2uAOD/undefined',
#    'images': {'thumb': None,
#     'small': None,
#     'medium': None,
#     'large': None,
#     'original': None}},
#   {'id': 'r2R8bUHIRD',
#    'num_games': None,
#    'score': 9999999,
#    'game': {},
#    'url': 'https://www.boardgameatlas.com/publisher/r2R8bUHIRD/undefined',
#    'images': {'thumb': None,
#     'small': None,
#     'medium': None,
#     'large': None,
#     'original': None}},
#   {'id': 'oQcGa4viSd',
#    'num_games': None,
#    'score': 9999999,
#    'game': {},
#    'url': 'https://www.boardgameatlas.com/publisher/oQcGa4viSd/undefined',
#    'images': {'thumb': None,
#     'small': None,
#     'medium': None,
#     'large': None,
#     'original': None}},
#   {'id': '7GTti1NuCH',
#    'num_games': None,
#    'score': 9999999,
#    'game': {},
#    'url': 'https://www.boardgameatlas.com/publisher/7GTti1NuCH/undefined',
#    'images': {'thumb': None,
#     'small': None,
#     'medium': None,
#     'large': None,
#     'original': None}},
#   {'id': 'j3lCGDByb2',
#    'num_games': None,
#    'score': 9999999,
#    'game': {},
#    'url': 'https://www.boardgameatlas.com/publisher/j3lCGDByb2/undefined',
#    'images': {'thumb': None,
#     'small': None,
#     'medium': None,
#     'large': None,
#     'original': None}}],
#  'designers': [{'id': 'RpZJ6vqsPR',
#    'num_games': None,
#    'score': 9999999,
#    'game': {},
#    'url': 'https://www.boardgameatlas.com/designer/RpZJ6vqsPR/undefined',
#    'images': {'thumb': None,
#     'small': None,
#     'medium': None,
#     'large': None,
#     'original': None}}],
#  'primary_publisher': {'id': 'w1jOf2uAOD',
#   'name': 'The Avalon Hill Game Co',
#   'url': 'https://www.boardgameatlas.com/publisher/w1jOf2uAOD/the-avalon-hill-game-co'},
#  'primary_designer': {'id': 'RpZJ6vqsPR',
#   'name': 'Francis Tresham',
#   'url': 'https://www.boardgameatlas.com/designer/RpZJ6vqsPR/francis-tresham'},
#  'developers': [],
#  'related_to': [],
#  'artists': ['Mike Atkinson',
#   'Jared Blando',
#   'Charles Kibler',
#   'James Talbot',
#   'Mark Zug'],
#  'names': [],
#  'rules_url': 'https://lookout-spiele.de/wp-content/uploads/1830_Spielregeln_EN_WEB.pdf',
#  'amazon_rank': 559911,
#  'official_url': 'http://www.mayfairgames.com/products/1830-north-east-us?utm_source=boardgameatlas.com&utm_medium=search&utm_campaign=bga_ads',
#  'sell_sheet_url': None,
#  'store_images_url': None,
#  'comment_count': 0,
#  'num_user_ratings': 36,
#  'average_user_rating': 4.006944444444444,
#  'historical_low_prices': [{'country': 'UK',
#    'date': '2021-12-18T12:07:52.735Z',
#    'price': 50.15,
#    'isLow': False},
#   {'country': 'AU',
#    'date': '2022-01-18T12:30:39.425Z',
#    'price': 89.95,
#    'isLow': False},
#   {'country': 'CA',
#    'date': '2022-03-08T15:27:32.086Z',
#    'price': 74.99,
#    'isLow': False},
#   {'country': 'US',
#    'date': '2022-03-16T09:34:50.524Z',
#    'price': 55.99,
#    'isLow': False}],
#  'active': True,
#  'num_user_complexity_votes': 2,
#  'average_learning_complexity': 3,
#  'average_strategy_complexity': 4.5,
#  'visits': 1894,
#  'lists': 273,
#  'mentions': 3,
#  'links': 0,
#  'plays': 240,
#  'rank': 874,
#  'type': 'game',
#  'num_distributors': 1,
#  'trending_rank': 97,
#  'listing_clicks': 0,
#  'is_historical_low': False,
#  'players': '2-7',
#  'playtime': '180-360',
#  'msrp_text': '$69.99',
#  'price_text': '$55.99',
#  'tags': ["1830: Ferrovie e Capitani d'Industria",
#   '1830: Schienenleger & Spekulanten',
#   '1830: The Game of Railroads and Robber Barons',
#   '1830 Revised Edition',
#   '1830 Railways Robber Barons Revised Edition',
#   '1830 (Revised Edition) [Pre-Order]',
#   '1830 Revised Edition Dent Ding',
#   '1830 Railways and Robber Barons',
#   '1830 Railways Robber Barons',
#   '1830: Railways & Robber Barons (Lookout Games Edition)',
#   '1830',
#   '1830 The Game of Railroads and Robber Barons'],
#  'images': {'thumb': 'https://d2k4q26owzy373.cloudfront.net/40x40/games/uploaded/1559257858925-51BztJ2q4WL.jpg',
#   'small': 'https://d2k4q26owzy373.cloudfront.net/150x150/games/uploaded/1559257858925-51BztJ2q4WL.jpg',
#   'medium': 'https://d2k4q26owzy373.cloudfront.net/350x350/games/uploaded/1559257858925-51BztJ2q4WL.jpg',
#   'large': 'https://d2k4q26owzy373.cloudfront.net/700x700/games/uploaded/1559257858925-51BztJ2q4WL.jpg',
#   'original': 'https://s3-us-west-1.amazonaws.com/5cc.images/games/uploaded/1559257858925-51BztJ2q4WL.jpg'},
#  'description_preview': ' 1830. It is the dawn of the "Age of Railroading" in America. You\'re a wealthy investor and speculator betting that the new technology will revolutionize transport. Commerce will no longer depend on rutted roads and slow canals. Instead, it will ride the rails on swift, powerful "Iron Horses." \r\n  1830  is an acclaimed railroad investment and building game covering the years 1830 to present. You and your fellow players become the stockholders of America\'s first railroad corporations. Since the largest shareholder becomes president, you compete for control of the strongest firms. As president, generate revenue by building track and buying and operating trains-regardless of shareholders\' needs. Meanwhile, you pay heed to the volatile stock market. You strive to invest in flourishing companies in order to earn healthy dividends. You try to buy stock in corporations that are rising in value, collect strong, and sell before the stock values drop. \r\n Get ready to be a railroad baron. Start investing and building. Become America\'s first great rail tycoon! \r\n The 2011 version of  1830  was published by Mayfair Games in partnership with Lookout Games of Germany. This publication was developed under license from Francis Tresham in co-operation with Bruce Shelley (the original  1830  developer). This version contains rules and components for Francis Tresham\'s original classic design, a faster-playing basic game, and new variants from some of the world\'s best railroad game developers. '}

# %%
# Get board games
categ_df = pd.DataFrame()
for category_id in categ_ids:
    next_categ_url = 'https://api.boardgameatlas.com/api/search?client_id=6MXavgYBke&limit=100&categories={}'.format(category_id)
    next_response = requests.get(next_categ_url)
    next_games_dict = json.loads(next_response.text)
    categ_df = categ_df.append(pd.DataFrame(next_games_dict['games']))
    time.sleep(1)
    if next_games_dict['count'] > 1000:
        for hundred in list(range(1,11)):
            limit = 100 * hundred
            next_categ_url = 'https://api.boardgameatlas.com/api/search?client_id=6MXavgYBke&limit=100&categories={}&skip={}'.format(category_id , limit)
            next_response = requests.get(next_categ_url)
            next_games_dict = json.loads(next_response.text)
            categ_df = categ_df.append(pd.DataFrame(next_games_dict['games']))
            time.sleep(1)
    elif next_games_dict['count'] > 100:
        for hundred in list(range(1,(math.ceil(next_games_dict['count'] / 100)))):
            limit = 100 * hundred
            next_categ_url = 'https://api.boardgameatlas.com/api/search?client_id=6MXavgYBke&limit=100&categories={}&skip={}'.format(category_id , limit)
            next_response = requests.get(next_categ_url)
            next_games_dict = json.loads(next_response.text)
            categ_df = categ_df.append(pd.DataFrame(next_games_dict['games']))
            time.sleep(1)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
pd.options.display.max_columns = None
display(categ_df.head())
# Out:
#    active  amazon_rank                                            artists  \
# 0    True     559911.0  [Mike Atkinson, Jared Blando, Charles Kibler, ...
# 1    True     125448.0  [Chris Lawson, Rodger B. MacGowan, Kurt Miller...
# 2    True          NaN                                      [Mike Hutton]
# 3    True          NaN                              [Brigette Indelicato]
# 4    True     473334.0                                    [Klemens Franz]
#
#   availability_status  average_learning_complexity  \
# 0                 NaN                          3.0
# 1                 NaN                          4.0
# 2                 NaN                          0.0
# 3                 NaN                          3.0
# 4                 NaN                          0.0
#
#    average_strategy_complexity  average_user_rating  \
# 0                          4.5             4.006944
# 1                          4.0             3.885135
# 2                          0.0             4.111111
# 3                          4.0             4.454545
# 4                          0.0             4.000000
#
#                                           categories  comment_count  \
# 0  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
# 1  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
# 2  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
# 3  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
# 4  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
#
#   commentary  cs_rating                                        description  \
# 0                   NaN  <p>1830. It is the dawn of the &quot;Age of Ra...
# 1                   NaN  <p>1846 - the midwest railroad boom has gone b...
# 2                   NaN  <p>1862: Railway Mania in the Eastern Counties...
# 3                   NaN  <p>18Chesapeake is a member of the <a href="ht...
# 4                   NaN  <p>The railway history of both Switzerland and...
#
#                                  description_preview  \
# 0   1830. It is the dawn of the "Age of Railroadi...
# 1   1846 - the midwest railroad boom has gone bus...
# 2   1862: Railway Mania in the Eastern Counties i...
# 3   18Chesapeake is a member of the  18xx  series...
# 4   The railway history of both Switzerland and A...
#
#                                            designers developers discount  \
# 0  [{'id': 'RpZJ6vqsPR', 'num_games': None, 'scor...         []     0.20
# 1  [{'id': 'CeUZNYVdQj', 'num_games': None, 'scor...         []     0.32
# 2  [{'id': 'xMrDEmBdTo', 'num_games': None, 'scor...         []     0.27
# 3  [{'id': 'fN0XCgUAPZ', 'num_games': None, 'scor...         []     0.00
# 4  [{'id': 'gFwNqit3MM', 'num_games': None, 'scor...         []     0.26
#
#                                             edit_url faq  \
# 0  https://www.boardgameatlas.com/game/o6knI5ct0u...
# 1  https://www.boardgameatlas.com/game/eSCVHuUFPs...
# 2  https://www.boardgameatlas.com/game/uEPtE5OOOU...
# 3  https://www.boardgameatlas.com/game/Krn8i8C0fI...
# 4  https://www.boardgameatlas.com/game/eJuGpFzljd...
#
#                                               handle  \
# 0  mayfair-games-1830-railways-and-robber-barons-...
# 1                      1846-the-race-for-the-midwest
# 2         1862-railway-mania-in-the-eastern-counties
# 3                                       18chesapeake
# 4          184454-switzerland-and-austria-board-game
#
#                                historical_low_prices          id  \
# 0  [{'country': 'UK', 'date': '2021-12-18T12:07:5...  o6knI5ct0u
# 1  [{'country': 'UK', 'date': '2021-12-14T18:14:1...  eSCVHuUFPs
# 2  [{'country': 'UK', 'date': '2021-12-11T11:48:1...  uEPtE5OOOU
# 3  [{'country': 'US', 'date': '2022-02-08T01:34:2...  Krn8i8C0fI
# 4  [{'country': 'UK', 'date': '2021-12-03T08:56:5...  eJuGpFzljd
#
#                                            image_url  \
# 0  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 1  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 2  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 3  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 4  https://s3-us-west-1.amazonaws.com/5cc.images/...
#
#                                               images  is_historical_low isbn  \
# 0  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...              False  NaN
# 1  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...              False  NaN
# 2  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...              False  NaN
# 3  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...              False  NaN
# 4  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...              False  NaN
#
#    links  listing_clicks  lists matches_specs  max_players  max_playtime  \
# 0      0               0    273          None          7.0         360.0
# 1      0               0    226          None          5.0         240.0
# 2      1               0    120          None          8.0         300.0
# 3      0               0    171          None          6.0         180.0
# 4      0               0     51          None          7.0         300.0
#
#                                            mechanics  mentions  min_age  \
# 0  [{'id': 'AZxlPpi5oq', 'url': 'https://www.boar...         3     14.0
# 1  [{'id': 'AZxlPpi5oq', 'url': 'https://www.boar...         1     14.0
# 2  [{'id': 'qCXa8MX0wk', 'url': 'https://www.boar...        13     12.0
# 3  [{'id': 'AZxlPpi5oq', 'url': 'https://www.boar...         1     13.0
# 4  [{'id': 'ohABM4GjbC', 'url': 'https://www.boar...         0     12.0
#
#    min_players  min_playtime   msrp msrp_text  \
# 0          2.0         180.0  69.99    $69.99
# 1          3.0         240.0     69    $69.00
# 2          1.0         300.0     79    $79.00
# 3          2.0         180.0     89    $89.00
# 4          3.0         300.0  94.99    $94.99
#
#                                                msrps  \
# 0                [{'country': 'US', 'price': 69.99}]
# 1  [{'country': 'US', 'price': 69}, {'country': '...
# 2                   [{'country': 'US', 'price': 79}]
# 3  [{'country': 'US', 'price': 89}, {'country': '...
# 4  [{'country': 'UK', 'price': 87.99}, {'country'...
#
#                                           name names  num_distributors  \
# 0               1830: Railways & Robber Barons    []                 1
# 1               1846: The Race for the Midwest    []                 3
# 2  1862: Railway Mania in the Eastern Counties    []                 2
# 3                                 18Chesapeake    []                 0
# 4                                  1844 / 1854    []                 0
#
#    num_user_complexity_votes  num_user_ratings  \
# 0                          2                36
# 1                          1                37
# 2                          0                 9
# 3                          1                11
# 4                          0                 6
#
#                                         official_url players  plays playtime  \
# 0  http://www.mayfairgames.com/products/1830-nort...     2-7    240  180-360
# 1  https://www.gmtgames.com/p-847-1846-the-race-t...     3-5    313      240
# 2  https://www.gmtgames.com/p-692-1862-railway-ma...     1-8     70      300
# 3  https://all-aboardgames.com/products/us-only-1...     2-6    158      180
# 4                                               None     3-7      5      300
#
#    price price_au price_ca  price_text price_uk  \
# 0  55.99    89.95    74.99      $55.99     0.00
# 1  46.99     0.00    67.95      $46.99     0.00
# 2  57.99   127.99    79.95      $57.99     0.00
# 3   0.00     0.00     0.00  Price: N/A     0.00
# 4  69.99     0.00   112.95      $69.99     0.00
#
#                                     primary_designer  \
# 0  {'id': 'RpZJ6vqsPR', 'name': 'Francis Tresham'...
# 1  {'id': 'CeUZNYVdQj', 'name': 'Thomas Lehmann',...
# 2  {'name': 'Mike Hutton', 'id': 'xMrDEmBdTo', 'u...
# 3  {'id': 'fN0XCgUAPZ', 'name': 'Scott Petersen',...
# 4  {'name': 'Helmut Ohley', 'id': 'gFwNqit3MM', '...
#
#                                    primary_publisher  \
# 0  {'id': 'w1jOf2uAOD', 'name': 'The Avalon Hill ...
# 1  {'id': 'VKIPDDgZ2X', 'name': 'Deep Thought Gam...
# 2  {'name': 'GMT Games', 'id': 'd5oY0duBgG', 'url...
# 3  {'id': 'ZOP4wDStJq', 'name': 'All-Aboard Games...
# 4  {'name': 'Mayfair Games', 'id': '7GTti1NuCH', ...
#
#                                           publishers     rank related_to  \
# 0  [{'id': 'w1jOf2uAOD', 'num_games': None, 'scor...      874         []
# 1  [{'id': 'VKIPDDgZ2X', 'num_games': None, 'scor...      927         []
# 2  [{'id': 'd5oY0duBgG', 'num_games': None, 'scor...  9999999         []
# 3  [{'id': 'ZOP4wDStJq', 'num_games': None, 'scor...  9999999         []
# 4  [{'id': '7GTti1NuCH', 'num_games': None, 'scor...  9999999         []
#
#                                            rules_url sell_sheet_url  \
# 0  https://lookout-spiele.de/wp-content/uploads/1...            NaN
# 1  https://s3-us-west-2.amazonaws.com/gmtwebsitea...            NaN
# 2  https://gmtwebsiteassets.s3-us-west-2.amazonaw...            NaN
# 3                                               None            NaN
# 4                                               None            NaN
#
#    size_depth  size_height size_units  size_width      sku  \
# 0         NaN          NaN        NaN         NaN      NaN
# 1         NaN          NaN        NaN         NaN  GMT1605
# 2         3.0          9.0        NaN         NaN  GMT1904
# 3         NaN          NaN        NaN         NaN      NaN
# 4         NaN          NaN        NaN         NaN      NaN
#
#                                          sku_objects  \
# 0                                                NaN
# 1  [{'name': 'Noble Knight Games', 'sku': '214918...
# 2  [{'name': 'Noble Knight Games', 'sku': '214919...
# 3                                                NaN
# 4                                                NaN
#
#                        skus specs store_images_url  \
# 0                       NaN    []              NaN
# 1  [2149184041, 2149209107]    []              NaN
# 2              [2149191519]    []              NaN
# 3                       NaN    []              NaN
# 4                       NaN    []              NaN
#
#                                                 tags  \
# 0  [1830: Ferrovie e Capitani d'Industria, 1830: ...
# 1  [1846 The Race to the Midwest Printing, 1846: ...
# 2  [1862: Railway Mania in the Eastern Counties, ...
# 3                                     [18Chesapeake]
# 4  [1844/1854 Switzerland/Austria, 1844/1854, 184...
#
#                                            thumb_url  trending_rank  type  \
# 0  https://s3-us-west-1.amazonaws.com/5cc.images/...             98  game
# 1  https://s3-us-west-1.amazonaws.com/5cc.images/...              0  game
# 2  https://s3-us-west-1.amazonaws.com/5cc.images/...              0  game
# 3  https://s3-us-west-1.amazonaws.com/5cc.images/...              0  game
# 4  https://s3-us-west-1.amazonaws.com/5cc.images/...              0  game
#
#             upc                                                url  \
# 0           NaN  https://www.boardgameatlas.com/game/o6knI5ct0u...
# 1  817054011155  https://www.boardgameatlas.com/game/eSCVHuUFPs...
# 2  817054011704  https://www.boardgameatlas.com/game/uEPtE5OOOU...
# 3           NaN  https://www.boardgameatlas.com/game/Krn8i8C0fI...
# 4           NaN  https://www.boardgameatlas.com/game/eJuGpFzljd...
#
#   video_links  visits  weight_amount weight_units  year_published
# 0         NaN    1894            NaN          NaN          1986.0
# 1         NaN    1072            NaN          NaN          2005.0
# 2         NaN    1053            NaN          NaN          2013.0
# 3         NaN     862            NaN          NaN          2020.0
# 4         NaN     500            NaN          NaN          2016.0

# %%
# Number of games 
len(categ_df)
# Out:
# 15699

# %%
# Feature list
categ_df.dtypes
# Out:
# active                            bool
# amazon_rank                    float64
# artists                         object
# availability_status             object
# average_learning_complexity    float64
# average_strategy_complexity    float64
# average_user_rating            float64
# categories                      object
# comment_count                    int64
# commentary                      object
# cs_rating                      float64
# description                     object
# description_preview             object
# designers                       object
# developers                      object
# discount                        object
# edit_url                        object
# faq                             object
# handle                          object
# historical_low_prices           object
# id                              object
# image_url                       object
# images                          object
# is_historical_low                 bool
# isbn                            object
# links                            int64
# listing_clicks                   int64
# lists                            int64
# matches_specs                   object
# max_players                    float64
#                                 ...
# price_ca                        object
# price_text                      object
# price_uk                        object
# primary_designer                object
# primary_publisher               object
# publishers                      object
# rank                             int64
# related_to                      object
# rules_url                       object
# sell_sheet_url                  object
# size_depth                     float64
# size_height                    float64
# size_units                      object
# size_width                     float64
# sku                             object
# sku_objects                     object
# skus                            object
# specs                           object
# store_images_url                object
# tags                            object
# thumb_url                       object
# trending_rank                    int64
# type                            object
# upc                             object
# url                             object
# video_links                     object
# visits                           int64
# weight_amount                  float64
# weight_units                    object
# year_published                 float64
# Length: 80, dtype: object

# %% [markdown]
# #### 3. Keep only the needed fields

# %%
# Keep only useful fields
categ_df_short = categ_df.loc[:, categ_df.columns.isin([
    'artists',
    'average_learning_complexity',
    'average_strategy_complexity',
    'average_user_rating',
    'categories',
    'comment_count',
    'description',
    'description_preview',
    'designers',
    'discount',
    'id',
    'is_historical_low',
    'listing_clicks',
    'max_players',
    'max_playtime',
    'min_age',
    'min_players',
    'min_playtime',
    'name',
    'num_user_ratings',
    'players',
    'plays',
    'playtime',
    'price',
    'price_au',
    'price_ca',
    'price_uk',
    'primary_publisher',
    'publishers',
    'visits',
    'year_published'  
])]

# %%
categ_df_short.isnull().sum()
# Out:
# artists                           0
# average_learning_complexity       0
# average_strategy_complexity       0
# average_user_rating               0
# categories                        0
# comment_count                     0
# description                       0
# description_preview               0
# designers                         0
# discount                          0
# id                                0
# is_historical_low                 0
# listing_clicks                    0
# max_players                    1361
# max_playtime                   1915
# min_age                        2082
# min_players                    1361
# min_playtime                   1912
# msrp                              0
# name                              0
# num_user_ratings                  0
# players                        1396
# plays                             0
# playtime                       2073
# price                             0
# price_au                          0
# price_ca                          0
# price_uk                          0
# primary_publisher               761
# publishers                        0
# visits                            0
# year_published                 2111
# dtype: int64

# %% [markdown]
# #### 4. Data cleaning

# %%
# Join lists / dictionaries to string
categ_df_short['artists_mod'] = ''.join(str(e) for e in categ_df_short['artists'])
categ_df_short['primary_publisher_mod'] = ''.join(str(e) for e in categ_df_short['primary_publisher'])
categ_df_short['categories_mod'] = ''.join(str(e) for e in categ_df_short['categories'])
categ_df_short['designers_mod'] = ''.join(str(e) for e in categ_df_short['designers'])
categ_df_short['publishers_mod'] = ''.join(str(e) for e in categ_df_short['publishers'])
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Lowercase name
categ_df_short['name_lower']=categ_df_short['name'].str.lower()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Remove original fields
categ_df_short = categ_df_short.loc[:, ~categ_df_short.columns.isin(['artists', 'primary_publisher', 'categories', 'designers', 'publishers'])]

# %%
# Feature list
categ_df_short.dtypes
# Out:
# average_learning_complexity    float64
# average_strategy_complexity    float64
# average_user_rating            float64
# comment_count                    int64
# description                     object
# description_preview             object
# discount                        object
# id                              object
# is_historical_low                 bool
# listing_clicks                   int64
# max_players                    float64
# max_playtime                   float64
# min_age                        float64
# min_players                    float64
# min_playtime                   float64
# msrp                            object
# name                            object
# num_user_ratings                 int64
# players                         object
# plays                            int64
# playtime                        object
# price                           object
# price_au                        object
# price_ca                        object
# price_uk                        object
# visits                           int64
# year_published                 float64
# artists_mod                     object
# primary_publisher_mod           object
# categories_mod                  object
# designers_mod                   object
# publishers_mod                  object
# name_lower                      object
# dtype: object

# %%
categ_df_short.head()
# Out:
#    average_learning_complexity  average_strategy_complexity  \
# 0                          3.0                          4.5
# 1                          4.0                          4.0
# 2                          0.0                          0.0
# 3                          3.0                          4.0
# 4                          0.0                          0.0
#
#    average_user_rating  comment_count  \
# 0             4.006944              0
# 1             3.885135              0
# 2             4.111111              0
# 3             4.454545              0
# 4             4.000000              0
#
#                                          description  \
# 0  <p>1830. It is the dawn of the &quot;Age of Ra...
# 1  <p>1846 - the midwest railroad boom has gone b...
# 2  <p>1862: Railway Mania in the Eastern Counties...
# 3  <p>18Chesapeake is a member of the <a href="ht...
# 4  <p>The railway history of both Switzerland and...
#
#                                  description_preview discount          id  \
# 0   1830. It is the dawn of the "Age of Railroadi...     0.20  o6knI5ct0u
# 1   1846 - the midwest railroad boom has gone bus...     0.32  eSCVHuUFPs
# 2   1862: Railway Mania in the Eastern Counties i...     0.27  uEPtE5OOOU
# 3   18Chesapeake is a member of the  18xx  series...     0.00  Krn8i8C0fI
# 4   The railway history of both Switzerland and A...     0.26  eJuGpFzljd
#
#    is_historical_low  listing_clicks  max_players  max_playtime  min_age  \
# 0              False               0          7.0         360.0     14.0
# 1              False               0          5.0         240.0     14.0
# 2              False               0          8.0         300.0     12.0
# 3              False               0          6.0         180.0     13.0
# 4              False               0          7.0         300.0     12.0
#
#    min_players  min_playtime   msrp  \
# 0          2.0         180.0  69.99
# 1          3.0         240.0     69
# 2          1.0         300.0     79
# 3          2.0         180.0     89
# 4          3.0         300.0  94.99
#
#                                           name  num_user_ratings players  \
# 0               1830: Railways & Robber Barons                36     2-7
# 1               1846: The Race for the Midwest                37     3-5
# 2  1862: Railway Mania in the Eastern Counties                 9     1-8
# 3                                 18Chesapeake                11     2-6
# 4                                  1844 / 1854                 6     3-7
#
#    plays playtime  price price_au price_ca price_uk  visits  year_published  \
# 0    240  180-360  55.99    89.95    74.99     0.00    1894          1986.0
# 1    313      240  46.99     0.00    67.95     0.00    1072          2005.0
# 2     70      300  57.99   127.99    79.95     0.00    1053          2013.0
# 3    158      180   0.00     0.00     0.00     0.00     862          2020.0
# 4      5      300  69.99     0.00   112.95     0.00     500          2016.0
#
#                                          artists_mod  \
# 0  ['Mike Atkinson', 'Jared Blando', 'Charles Kib...
# 1  ['Mike Atkinson', 'Jared Blando', 'Charles Kib...
# 2  ['Mike Atkinson', 'Jared Blando', 'Charles Kib...
# 3  ['Mike Atkinson', 'Jared Blando', 'Charles Kib...
# 4  ['Mike Atkinson', 'Jared Blando', 'Charles Kib...
#
#                                primary_publisher_mod  \
# 0  {'id': 'w1jOf2uAOD', 'name': 'The Avalon Hill ...
# 1  {'id': 'w1jOf2uAOD', 'name': 'The Avalon Hill ...
# 2  {'id': 'w1jOf2uAOD', 'name': 'The Avalon Hill ...
# 3  {'id': 'w1jOf2uAOD', 'name': 'The Avalon Hill ...
# 4  {'id': 'w1jOf2uAOD', 'name': 'The Avalon Hill ...
#
#                                       categories_mod  \
# 0  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...
# 1  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...
# 2  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...
# 3  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...
# 4  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...
#
#                                        designers_mod  \
# 0  [{'id': 'RpZJ6vqsPR', 'num_games': None, 'scor...
# 1  [{'id': 'RpZJ6vqsPR', 'num_games': None, 'scor...
# 2  [{'id': 'RpZJ6vqsPR', 'num_games': None, 'scor...
# 3  [{'id': 'RpZJ6vqsPR', 'num_games': None, 'scor...
# 4  [{'id': 'RpZJ6vqsPR', 'num_games': None, 'scor...
#
#                                       publishers_mod  \
# 0  [{'id': 'w1jOf2uAOD', 'num_games': None, 'scor...
# 1  [{'id': 'w1jOf2uAOD', 'num_games': None, 'scor...
# 2  [{'id': 'w1jOf2uAOD', 'num_games': None, 'scor...
# 3  [{'id': 'w1jOf2uAOD', 'num_games': None, 'scor...
# 4  [{'id': 'w1jOf2uAOD', 'num_games': None, 'scor...
#
#                                     name_lower
# 0               1830: railways & robber barons
# 1               1846: the race for the midwest
# 2  1862: railway mania in the eastern counties
# 3                                 18chesapeake
# 4                                  1844 / 1854

# %% [markdown]
# #### 5. Remove duplicates

# %%
# Number of duplicate board games
sum(categ_df_short.duplicated(subset=['name', 'year_published']))
# Out:
# 7946

# %%
# Number of duplicate board games
sum(categ_df_short.duplicated(subset=['name']))
# Out:
# 7977

# %%
# Remove duplicates
no_duplicate_categ_df = categ_df[~categ_df.duplicated(subset=['name', 'year_published'])]

# %%
len(no_duplicate_categ_df)
# Out:
# 7753

# %%
no_duplicate_categ_df.head()
# Out:
#    active  amazon_rank                                            artists  \
# 0    True     559911.0  [Mike Atkinson, Jared Blando, Charles Kibler, ...
# 1    True     125448.0  [Chris Lawson, Rodger B. MacGowan, Kurt Miller...
# 2    True          NaN                                      [Mike Hutton]
# 3    True          NaN                              [Brigette Indelicato]
# 4    True     473334.0                                    [Klemens Franz]
#
#   availability_status  average_learning_complexity  \
# 0                 NaN                          3.0
# 1                 NaN                          4.0
# 2                 NaN                          0.0
# 3                 NaN                          3.0
# 4                 NaN                          0.0
#
#    average_strategy_complexity  average_user_rating  \
# 0                          4.5             4.006944
# 1                          4.0             3.885135
# 2                          0.0             4.111111
# 3                          4.0             4.454545
# 4                          0.0             4.000000
#
#                                           categories  comment_count  \
# 0  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
# 1  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
# 2  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
# 3  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
# 4  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...              0
#
#   commentary  cs_rating                                        description  \
# 0                   NaN  <p>1830. It is the dawn of the &quot;Age of Ra...
# 1                   NaN  <p>1846 - the midwest railroad boom has gone b...
# 2                   NaN  <p>1862: Railway Mania in the Eastern Counties...
# 3                   NaN  <p>18Chesapeake is a member of the <a href="ht...
# 4                   NaN  <p>The railway history of both Switzerland and...
#
#                                  description_preview  \
# 0   1830. It is the dawn of the "Age of Railroadi...
# 1   1846 - the midwest railroad boom has gone bus...
# 2   1862: Railway Mania in the Eastern Counties i...
# 3   18Chesapeake is a member of the  18xx  series...
# 4   The railway history of both Switzerland and A...
#
#                                            designers developers discount  \
# 0  [{'id': 'RpZJ6vqsPR', 'num_games': None, 'scor...         []     0.20
# 1  [{'id': 'CeUZNYVdQj', 'num_games': None, 'scor...         []     0.32
# 2  [{'id': 'xMrDEmBdTo', 'num_games': None, 'scor...         []     0.27
# 3  [{'id': 'fN0XCgUAPZ', 'num_games': None, 'scor...         []     0.00
# 4  [{'id': 'gFwNqit3MM', 'num_games': None, 'scor...         []     0.26
#
#                                             edit_url faq  \
# 0  https://www.boardgameatlas.com/game/o6knI5ct0u...
# 1  https://www.boardgameatlas.com/game/eSCVHuUFPs...
# 2  https://www.boardgameatlas.com/game/uEPtE5OOOU...
# 3  https://www.boardgameatlas.com/game/Krn8i8C0fI...
# 4  https://www.boardgameatlas.com/game/eJuGpFzljd...
#
#                                               handle  \
# 0  mayfair-games-1830-railways-and-robber-barons-...
# 1                      1846-the-race-for-the-midwest
# 2         1862-railway-mania-in-the-eastern-counties
# 3                                       18chesapeake
# 4          184454-switzerland-and-austria-board-game
#
#                                historical_low_prices          id  \
# 0  [{'country': 'UK', 'date': '2021-12-18T12:07:5...  o6knI5ct0u
# 1  [{'country': 'UK', 'date': '2021-12-14T18:14:1...  eSCVHuUFPs
# 2  [{'country': 'UK', 'date': '2021-12-11T11:48:1...  uEPtE5OOOU
# 3  [{'country': 'US', 'date': '2022-02-08T01:34:2...  Krn8i8C0fI
# 4  [{'country': 'UK', 'date': '2021-12-03T08:56:5...  eJuGpFzljd
#
#                                            image_url  \
# 0  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 1  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 2  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 3  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 4  https://s3-us-west-1.amazonaws.com/5cc.images/...
#
#                                               images  is_historical_low isbn  \
# 0  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...              False  NaN
# 1  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...              False  NaN
# 2  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...              False  NaN
# 3  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...              False  NaN
# 4  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...              False  NaN
#
#    links  listing_clicks  lists matches_specs  max_players  max_playtime  \
# 0      0               0    273          None          7.0         360.0
# 1      0               0    226          None          5.0         240.0
# 2      1               0    120          None          8.0         300.0
# 3      0               0    171          None          6.0         180.0
# 4      0               0     51          None          7.0         300.0
#
#                                            mechanics  mentions  min_age  \
# 0  [{'id': 'AZxlPpi5oq', 'url': 'https://www.boar...         3     14.0
# 1  [{'id': 'AZxlPpi5oq', 'url': 'https://www.boar...         1     14.0
# 2  [{'id': 'qCXa8MX0wk', 'url': 'https://www.boar...        13     12.0
# 3  [{'id': 'AZxlPpi5oq', 'url': 'https://www.boar...         1     13.0
# 4  [{'id': 'ohABM4GjbC', 'url': 'https://www.boar...         0     12.0
#
#    min_players  min_playtime   msrp msrp_text  \
# 0          2.0         180.0  69.99    $69.99
# 1          3.0         240.0     69    $69.00
# 2          1.0         300.0     79    $79.00
# 3          2.0         180.0     89    $89.00
# 4          3.0         300.0  94.99    $94.99
#
#                                                msrps  \
# 0                [{'country': 'US', 'price': 69.99}]
# 1  [{'country': 'US', 'price': 69}, {'country': '...
# 2                   [{'country': 'US', 'price': 79}]
# 3  [{'country': 'US', 'price': 89}, {'country': '...
# 4  [{'country': 'UK', 'price': 87.99}, {'country'...
#
#                                           name names  num_distributors  \
# 0               1830: Railways & Robber Barons    []                 1
# 1               1846: The Race for the Midwest    []                 3
# 2  1862: Railway Mania in the Eastern Counties    []                 2
# 3                                 18Chesapeake    []                 0
# 4                                  1844 / 1854    []                 0
#
#    num_user_complexity_votes  num_user_ratings  \
# 0                          2                36
# 1                          1                37
# 2                          0                 9
# 3                          1                11
# 4                          0                 6
#
#                                         official_url players  plays playtime  \
# 0  http://www.mayfairgames.com/products/1830-nort...     2-7    240  180-360
# 1  https://www.gmtgames.com/p-847-1846-the-race-t...     3-5    313      240
# 2  https://www.gmtgames.com/p-692-1862-railway-ma...     1-8     70      300
# 3  https://all-aboardgames.com/products/us-only-1...     2-6    158      180
# 4                                               None     3-7      5      300
#
#    price price_au price_ca  price_text price_uk  \
# 0  55.99    89.95    74.99      $55.99     0.00
# 1  46.99     0.00    67.95      $46.99     0.00
# 2  57.99   127.99    79.95      $57.99     0.00
# 3   0.00     0.00     0.00  Price: N/A     0.00
# 4  69.99     0.00   112.95      $69.99     0.00
#
#                                     primary_designer  \
# 0  {'id': 'RpZJ6vqsPR', 'name': 'Francis Tresham'...
# 1  {'id': 'CeUZNYVdQj', 'name': 'Thomas Lehmann',...
# 2  {'name': 'Mike Hutton', 'id': 'xMrDEmBdTo', 'u...
# 3  {'id': 'fN0XCgUAPZ', 'name': 'Scott Petersen',...
# 4  {'name': 'Helmut Ohley', 'id': 'gFwNqit3MM', '...
#
#                                    primary_publisher  \
# 0  {'id': 'w1jOf2uAOD', 'name': 'The Avalon Hill ...
# 1  {'id': 'VKIPDDgZ2X', 'name': 'Deep Thought Gam...
# 2  {'name': 'GMT Games', 'id': 'd5oY0duBgG', 'url...
# 3  {'id': 'ZOP4wDStJq', 'name': 'All-Aboard Games...
# 4  {'name': 'Mayfair Games', 'id': '7GTti1NuCH', ...
#
#                                           publishers     rank related_to  \
# 0  [{'id': 'w1jOf2uAOD', 'num_games': None, 'scor...      874         []
# 1  [{'id': 'VKIPDDgZ2X', 'num_games': None, 'scor...      927         []
# 2  [{'id': 'd5oY0duBgG', 'num_games': None, 'scor...  9999999         []
# 3  [{'id': 'ZOP4wDStJq', 'num_games': None, 'scor...  9999999         []
# 4  [{'id': '7GTti1NuCH', 'num_games': None, 'scor...  9999999         []
#
#                                            rules_url sell_sheet_url  \
# 0  https://lookout-spiele.de/wp-content/uploads/1...            NaN
# 1  https://s3-us-west-2.amazonaws.com/gmtwebsitea...            NaN
# 2  https://gmtwebsiteassets.s3-us-west-2.amazonaw...            NaN
# 3                                               None            NaN
# 4                                               None            NaN
#
#    size_depth  size_height size_units  size_width      sku  \
# 0         NaN          NaN        NaN         NaN      NaN
# 1         NaN          NaN        NaN         NaN  GMT1605
# 2         3.0          9.0        NaN         NaN  GMT1904
# 3         NaN          NaN        NaN         NaN      NaN
# 4         NaN          NaN        NaN         NaN      NaN
#
#                                          sku_objects  \
# 0                                                NaN
# 1  [{'name': 'Noble Knight Games', 'sku': '214918...
# 2  [{'name': 'Noble Knight Games', 'sku': '214919...
# 3                                                NaN
# 4                                                NaN
#
#                        skus specs store_images_url  \
# 0                       NaN    []              NaN
# 1  [2149184041, 2149209107]    []              NaN
# 2              [2149191519]    []              NaN
# 3                       NaN    []              NaN
# 4                       NaN    []              NaN
#
#                                                 tags  \
# 0  [1830: Ferrovie e Capitani d'Industria, 1830: ...
# 1  [1846 The Race to the Midwest Printing, 1846: ...
# 2  [1862: Railway Mania in the Eastern Counties, ...
# 3                                     [18Chesapeake]
# 4  [1844/1854 Switzerland/Austria, 1844/1854, 184...
#
#                                            thumb_url  trending_rank  type  \
# 0  https://s3-us-west-1.amazonaws.com/5cc.images/...             98  game
# 1  https://s3-us-west-1.amazonaws.com/5cc.images/...              0  game
# 2  https://s3-us-west-1.amazonaws.com/5cc.images/...              0  game
# 3  https://s3-us-west-1.amazonaws.com/5cc.images/...              0  game
# 4  https://s3-us-west-1.amazonaws.com/5cc.images/...              0  game
#
#             upc                                                url  \
# 0           NaN  https://www.boardgameatlas.com/game/o6knI5ct0u...
# 1  817054011155  https://www.boardgameatlas.com/game/eSCVHuUFPs...
# 2  817054011704  https://www.boardgameatlas.com/game/uEPtE5OOOU...
# 3           NaN  https://www.boardgameatlas.com/game/Krn8i8C0fI...
# 4           NaN  https://www.boardgameatlas.com/game/eJuGpFzljd...
#
#   video_links  visits  weight_amount weight_units  year_published
# 0         NaN    1894            NaN          NaN          1986.0
# 1         NaN    1072            NaN          NaN          2005.0
# 2         NaN    1053            NaN          NaN          2013.0
# 3         NaN     862            NaN          NaN          2020.0
# 4         NaN     500            NaN          NaN          2016.0

# %% [markdown]
# ##### 6. Save dataset

# %%
# Save dataset 
no_duplicate_categ_df.to_csv("board_games_api.csv", sep=';' , quotechar='"')

# %% [markdown]
# ## **III. Join datasets**

# %%
# Import datasets
board_games = pd.read_csv("board_games_raw.csv", sep=';')
# board_games.columns = [str(col) + '_base' for col in board_games.columns]
board_games.head()
# Out:
#    Unnamed: 0  game_id                                        description  \
# 0           0        1  Die Macher is a game about seven sequential po...
# 1           1        2  Dragonmaster is a trick-taking card game based...
# 2           2        3  Part of the Knizia tile-laying trilogy, Samura...
# 3           3        4  When you see the triangular box and the luxuri...
# 4           4        5  In Acquire, each player strategically invests ...
#
#    max_players  max_playtime  min_age  min_players  min_playtime  \
# 0            5           240       14            3           240
# 1            4            30       12            3            30
# 2            4            60       10            2            30
# 3            4            60       12            2            60
# 4            6            90       12            3            90
#
#              name  playing_time  year_published                       artist  \
# 0      Die Macher           240            1986          Marcus Gschwendtner
# 1    Dragonmaster            30            1981                   Bob Pepper
# 2         Samurai            60            1998              Franz Vohwinkel
# 3  Tal der Könige            60            1992                          NaN
# 4         Acquire            90            1964  Scott Okumura,Peter Whitley
#
#                          category               designer  \
# 0  Economic,Negotiation,Political     Karl-Heinz Schmiel
# 1               Card Game,Fantasy  G. W. "Jerry" D'Arcey
# 2      Abstract Strategy,Medieval          Reiner Knizia
# 3                         Ancient      Christian Beierer
# 4                        Economic            Sid Sackson
#
#                                               family  \
# 0         Country: Germany,Valley Games Classic Line
# 1                                   Animals: Dragons
# 2  Asian Theme,Country: Japan,Knizia tile-laying ...
# 3             Country: Egypt,Promotional Board Games
# 4                                3M Bookshelf Series
#
#                                             mechanic  \
# 0  Area Control / Area Influence,Auction/Bidding,...
# 1                                       Trick-taking
# 2  Area Control / Area Influence,Hand Management,...
# 3  Action Point Allowance System,Area Control / A...
# 4       Hand Management,Stock Holding,Tile Placement
#
#                                            publisher  average_rating  \
# 0  Hans im Glück Verlags-GmbH,Moskito Spiele,Vall...         7.66508
# 1                           E.S. Lowe,Milton Bradley         6.60815
# 2  999 Games,ABACUSSPIELE,Astrel Games,Ceilikan J...         7.44119
# 3                                             KOSMOS         6.60675
# 4  3M,Avalon Hill,Avalon Hill (Hasbro),Dujardin,G...         7.35830
#
#    users_rated      name_lower
# 0         4498      die macher
# 1          478    dragonmaster
# 2        12019         samurai
# 3          314  tal der könige
# 4        15195         acquire

# %%
# Import datasets
board_games_api = pd.read_csv("board_games_api.csv", sep=';')
# board_games_api.columns = [str(col) + '_api' for col in board_games_api.columns]
board_games_api.head()
# Out:
#    Unnamed: 0  active  amazon_rank  \
# 0           0    True     559911.0
# 1           1    True     125448.0
# 2           2    True          NaN
# 3           3    True          NaN
# 4           4    True     473334.0
#
#                                              artists availability_status  \
# 0  ['Mike Atkinson', 'Jared Blando', 'Charles Kib...                 NaN
# 1  ['Chris Lawson', 'Rodger B. MacGowan', 'Kurt M...                 NaN
# 2                                    ['Mike Hutton']                 NaN
# 3                            ['Brigette Indelicato']                 NaN
# 4                                  ['Klemens Franz']                 NaN
#
#    average_learning_complexity  average_strategy_complexity  \
# 0                          3.0                          4.5
# 1                          4.0                          4.0
# 2                          0.0                          0.0
# 3                          3.0                          4.0
# 4                          0.0                          0.0
#
#    average_user_rating                                         categories  \
# 0             4.006944  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...
# 1             3.885135  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...
# 2             4.111111  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...
# 3             4.454545  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...
# 4             4.000000  [{'id': '2bdFPJUvFo', 'url': 'https://www.boar...
#
#    comment_count commentary  cs_rating  \
# 0              0        NaN        NaN
# 1              0        NaN        NaN
# 2              0        NaN        NaN
# 3              0        NaN        NaN
# 4              0        NaN        NaN
#
#                                          description  \
# 0  <p>1830. It is the dawn of the &quot;Age of Ra...
# 1  <p>1846 - the midwest railroad boom has gone b...
# 2  <p>1862: Railway Mania in the Eastern Counties...
# 3  <p>18Chesapeake is a member of the <a href="ht...
# 4  <p>The railway history of both Switzerland and...
#
#                                  description_preview  \
# 0   1830. It is the dawn of the "Age of Railroadi...
# 1   1846 - the midwest railroad boom has gone bus...
# 2   1862: Railway Mania in the Eastern Counties i...
# 3   18Chesapeake is a member of the  18xx  series...
# 4   The railway history of both Switzerland and A...
#
#                                            designers developers  discount  \
# 0  [{'id': 'RpZJ6vqsPR', 'num_games': None, 'scor...         []      0.20
# 1  [{'id': 'CeUZNYVdQj', 'num_games': None, 'scor...         []      0.32
# 2  [{'id': 'xMrDEmBdTo', 'num_games': None, 'scor...         []      0.27
# 3  [{'id': 'fN0XCgUAPZ', 'num_games': None, 'scor...         []      0.00
# 4  [{'id': 'gFwNqit3MM', 'num_games': None, 'scor...         []      0.26
#
#                                             edit_url  faq  \
# 0  https://www.boardgameatlas.com/game/o6knI5ct0u...  NaN
# 1  https://www.boardgameatlas.com/game/eSCVHuUFPs...  NaN
# 2  https://www.boardgameatlas.com/game/uEPtE5OOOU...  NaN
# 3  https://www.boardgameatlas.com/game/Krn8i8C0fI...  NaN
# 4  https://www.boardgameatlas.com/game/eJuGpFzljd...  NaN
#
#                                               handle  \
# 0  mayfair-games-1830-railways-and-robber-barons-...
# 1                      1846-the-race-for-the-midwest
# 2         1862-railway-mania-in-the-eastern-counties
# 3                                       18chesapeake
# 4          184454-switzerland-and-austria-board-game
#
#                                historical_low_prices          id  \
# 0  [{'country': 'UK', 'date': '2021-12-18T12:07:5...  o6knI5ct0u
# 1  [{'country': 'UK', 'date': '2021-12-14T18:14:1...  eSCVHuUFPs
# 2  [{'country': 'UK', 'date': '2021-12-11T11:48:1...  uEPtE5OOOU
# 3  [{'country': 'US', 'date': '2022-02-08T01:34:2...  Krn8i8C0fI
# 4  [{'country': 'UK', 'date': '2021-12-03T08:56:5...  eJuGpFzljd
#
#                                            image_url  \
# 0  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 1  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 2  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 3  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 4  https://s3-us-west-1.amazonaws.com/5cc.images/...
#
#                                               images  is_historical_low  isbn  \
# 0  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...              False   NaN
# 1  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...              False   NaN
# 2  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...              False   NaN
# 3  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...              False   NaN
# 4  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...              False   NaN
#
#    links  listing_clicks  lists matches_specs  max_players  max_playtime  \
# 0      0               0    273           NaN          7.0         360.0
# 1      0               0    226           NaN          5.0         240.0
# 2      1               0    120           NaN          8.0         300.0
# 3      0               0    171           NaN          6.0         180.0
# 4      0               0     51           NaN          7.0         300.0
#
#                                            mechanics  mentions  min_age  \
# 0  [{'id': 'AZxlPpi5oq', 'url': 'https://www.boar...         3     14.0
# 1  [{'id': 'AZxlPpi5oq', 'url': 'https://www.boar...         1     14.0
# 2  [{'id': 'qCXa8MX0wk', 'url': 'https://www.boar...        13     12.0
# 3  [{'id': 'AZxlPpi5oq', 'url': 'https://www.boar...         1     13.0
# 4  [{'id': 'ohABM4GjbC', 'url': 'https://www.boar...         0     12.0
#
#    min_players  min_playtime   msrp msrp_text  \
# 0          2.0         180.0  69.99    $69.99
# 1          3.0         240.0  69.00    $69.00
# 2          1.0         300.0  79.00    $79.00
# 3          2.0         180.0  89.00    $89.00
# 4          3.0         300.0  94.99    $94.99
#
#                                                msrps  \
# 0                [{'country': 'US', 'price': 69.99}]
# 1  [{'country': 'US', 'price': 69}, {'country': '...
# 2                   [{'country': 'US', 'price': 79}]
# 3  [{'country': 'US', 'price': 89}, {'country': '...
# 4  [{'country': 'UK', 'price': 87.99}, {'country'...
#
#                                           name names  num_distributors  \
# 0               1830: Railways & Robber Barons    []                 1
# 1               1846: The Race for the Midwest    []                 3
# 2  1862: Railway Mania in the Eastern Counties    []                 2
# 3                                 18Chesapeake    []                 0
# 4                                  1844 / 1854    []                 0
#
#    num_user_complexity_votes  num_user_ratings  \
# 0                          2                36
# 1                          1                37
# 2                          0                 9
# 3                          1                11
# 4                          0                 6
#
#                                         official_url players  plays playtime  \
# 0  http://www.mayfairgames.com/products/1830-nort...     2-7    240  180-360
# 1  https://www.gmtgames.com/p-847-1846-the-race-t...     3-5    313      240
# 2  https://www.gmtgames.com/p-692-1862-railway-ma...     1-8     70      300
# 3  https://all-aboardgames.com/products/us-only-1...     2-6    158      180
# 4                                                NaN     3-7      5      300
#
#    price  price_au  price_ca  price_text  price_uk  \
# 0  55.99     89.95     74.99      $55.99       0.0
# 1  46.99      0.00     67.95      $46.99       0.0
# 2  57.99    127.99     79.95      $57.99       0.0
# 3   0.00      0.00      0.00  Price: N/A       0.0
# 4  69.99      0.00    112.95      $69.99       0.0
#
#                                     primary_designer  \
# 0  {'id': 'RpZJ6vqsPR', 'name': 'Francis Tresham'...
# 1  {'id': 'CeUZNYVdQj', 'name': 'Thomas Lehmann',...
# 2  {'name': 'Mike Hutton', 'id': 'xMrDEmBdTo', 'u...
# 3  {'id': 'fN0XCgUAPZ', 'name': 'Scott Petersen',...
# 4  {'name': 'Helmut Ohley', 'id': 'gFwNqit3MM', '...
#
#                                    primary_publisher  \
# 0  {'id': 'w1jOf2uAOD', 'name': 'The Avalon Hill ...
# 1  {'id': 'VKIPDDgZ2X', 'name': 'Deep Thought Gam...
# 2  {'name': 'GMT Games', 'id': 'd5oY0duBgG', 'url...
# 3  {'id': 'ZOP4wDStJq', 'name': 'All-Aboard Games...
# 4  {'name': 'Mayfair Games', 'id': '7GTti1NuCH', ...
#
#                                           publishers     rank related_to  \
# 0  [{'id': 'w1jOf2uAOD', 'num_games': None, 'scor...      874         []
# 1  [{'id': 'VKIPDDgZ2X', 'num_games': None, 'scor...      927         []
# 2  [{'id': 'd5oY0duBgG', 'num_games': None, 'scor...  9999999         []
# 3  [{'id': 'ZOP4wDStJq', 'num_games': None, 'scor...  9999999         []
# 4  [{'id': '7GTti1NuCH', 'num_games': None, 'scor...  9999999         []
#
#                                            rules_url sell_sheet_url  \
# 0  https://lookout-spiele.de/wp-content/uploads/1...            NaN
# 1  https://s3-us-west-2.amazonaws.com/gmtwebsitea...            NaN
# 2  https://gmtwebsiteassets.s3-us-west-2.amazonaw...            NaN
# 3                                                NaN            NaN
# 4                                                NaN            NaN
#
#    size_depth  size_height size_units  size_width      sku  \
# 0         NaN          NaN        NaN         NaN      NaN
# 1         NaN          NaN        NaN         NaN  GMT1605
# 2         3.0          9.0        NaN         NaN  GMT1904
# 3         NaN          NaN        NaN         NaN      NaN
# 4         NaN          NaN        NaN         NaN      NaN
#
#                                          sku_objects  \
# 0                                                NaN
# 1  [{'name': 'Noble Knight Games', 'sku': '214918...
# 2  [{'name': 'Noble Knight Games', 'sku': '214919...
# 3                                                NaN
# 4                                                NaN
#
#                            skus specs store_images_url  \
# 0                           NaN    []              NaN
# 1  ['2149184041', '2149209107']    []              NaN
# 2                ['2149191519']    []              NaN
# 3                           NaN    []              NaN
# 4                           NaN    []              NaN
#
#                                                 tags  \
# 0  ["1830: Ferrovie e Capitani d'Industria", '183...
# 1  ['1846 The Race to the Midwest Printing', '184...
# 2  ['1862: Railway Mania in the Eastern Counties'...
# 3                                   ['18Chesapeake']
# 4  ['1844/1854 Switzerland/Austria', '1844/1854',...
#
#                                            thumb_url  trending_rank  type  \
# 0  https://s3-us-west-1.amazonaws.com/5cc.images/...             98  game
# 1  https://s3-us-west-1.amazonaws.com/5cc.images/...              0  game
# 2  https://s3-us-west-1.amazonaws.com/5cc.images/...              0  game
# 3  https://s3-us-west-1.amazonaws.com/5cc.images/...              0  game
# 4  https://s3-us-west-1.amazonaws.com/5cc.images/...              0  game
#
#             upc                                                url  \
# 0           NaN  https://www.boardgameatlas.com/game/o6knI5ct0u...
# 1  817054011155  https://www.boardgameatlas.com/game/eSCVHuUFPs...
# 2  817054011704  https://www.boardgameatlas.com/game/uEPtE5OOOU...
# 3           NaN  https://www.boardgameatlas.com/game/Krn8i8C0fI...
# 4           NaN  https://www.boardgameatlas.com/game/eJuGpFzljd...
#
#   video_links  visits  weight_amount weight_units  year_published
# 0         NaN    1894            NaN          NaN          1986.0
# 1         NaN    1072            NaN          NaN          2005.0
# 2         NaN    1053            NaN          NaN          2013.0
# 3         NaN     862            NaN          NaN          2020.0
# 4         NaN     500            NaN          NaN          2016.0

# %%
# Merge datasets on name and year_published
united_df = pd.merge(board_games, 
                     board_games_api, 
                     how='inner', 
                     left_on=['name', 'year_published'], 
                     right_on=['name', 'year_published'])

# %%
len(united_df)
# Out:
# 1176

# %%
# Merge datasets on name and year_published
united_df2 = pd.merge(board_games_raw, 
                     board_games_api, 
                     how='inner', 
                     left_on=['name'], 
                     right_on=['name'])

# %%
len(united_df2)
# Out:
# 1336

# %%
united_df.head()
# Out:
#    game_id                                      description_x  max_players_x  \
# 0        1  Die Macher is a game about seven sequential po...              5
# 1        3  Part of the Knizia tile-laying trilogy, Samura...              4
# 2       11  Bohnanza is the first in the Bohnanza family o...              7
# 3       13  In Catan (formerly The Settlers of Catan), pla...              4
# 4       19  A long time ago, in a village far, far away, s...              4
#
#    max_playtime_x  min_age_x  min_players_x  min_playtime_x              name  \
# 0             240         14              3             240        Die Macher
# 1              60         10              2              30           Samurai
# 2              45         13              2              45          Bohnanza
# 3             120         10              3              60             Catan
# 4              45          9              2              30  Wacky Wacky West
#
#    playing_time  year_published  \
# 0           240            1986
# 1            60            1998
# 2            45            1997
# 3           120            1995
# 4            45            1991
#
#                                               artist  \
# 0                                Marcus Gschwendtner
# 1                                    Franz Vohwinkel
# 2  Fréderic Bertrand,Marek Bláha,Andrea Boekhoff,...
# 3  Volkan Baga,Tanja Donner,Pete Fenlon,Jason Haw...
# 4                  Chris McGloughlin,Franz Vohwinkel
#
#                                category            designer  \
# 0        Economic,Negotiation,Political  Karl-Heinz Schmiel
# 1            Abstract Strategy,Medieval       Reiner Knizia
# 2         Card Game,Farming,Negotiation       Uwe Rosenberg
# 3                           Negotiation        Klaus Teuber
# 4  American West,Bluffing,City Building        Klaus Teuber
#
#                                               family  \
# 0         Country: Germany,Valley Games Classic Line
# 1  Asian Theme,Country: Japan,Knizia tile-laying ...
# 2                        Bohnanza,Lookout Bean Games
# 3                      Catan,Promotional Board Games
# 4                                                NaN
#
#                                             mechanic  \
# 0  Area Control / Area Influence,Auction/Bidding,...
# 1  Area Control / Area Influence,Hand Management,...
# 2             Hand Management,Set Collection,Trading
# 3  Dice Rolling,Hand Management,Modular Board,Rou...
# 4                              Tile Placement,Voting
#
#                                            publisher  average_rating  \
# 0  Hans im Glück Verlags-GmbH,Moskito Spiele,Vall...         7.66508
# 1  999 Games,ABACUSSPIELE,Astrel Games,Ceilikan J...         7.44119
# 2  AMIGO Spiel + Freizeit GmbH,999 Games,Brain Ga...         7.06751
# 3  KOSMOS,999 Games,Albi,Astrel Games,Bergsala En...         7.26569
# 4           Hans im Glück Verlags-GmbH,Mayfair Games         6.31166
#
#    users_rated        name_lower  active  amazon_rank  \
# 0         4498        die macher    True    1320612.0
# 1        12019           samurai    True     223428.0
# 2        28354          bohnanza    True       2960.0
# 3        67655             catan    True        133.0
# 4         1459  wacky wacky west    True     788427.0
#
#                                              artists availability_status  \
# 0               [Marcus Gschwendtner, Harald Lieske]                 NaN
# 1                                  [Franz Vohwinkel]                 NaN
# 2  [Fréderic Bertrand, Marek Bláha, Andrea Boekho...                 NaN
# 3  [Volkan Baga, Tanja Donner, Pete Fenlon, Jason...                 NaN
# 4               [Chris McGloughlin, Franz Vohwinkel]                 NaN
#
#    average_learning_complexity  average_strategy_complexity  \
# 0                     0.000000                     0.000000
# 1                     0.000000                     0.000000
# 2                     2.000000                     2.500000
# 3                     2.090909                     2.545455
# 4                     0.000000                     0.000000
#
#    average_user_rating                                         categories  \
# 0             3.684783  [{'id': 'N0TkEGfEsF', 'url': 'https://www.boar...
# 1             3.701527  [{'id': 'hBqZ3Ar4RJ', 'url': 'https://www.boar...
# 2             3.416414  [{'id': 'eX8uuNlQkQ', 'url': 'https://www.boar...
# 3             3.253205  [{'id': 'mavSOM8vjH', 'url': 'https://www.boar...
# 4             2.857143  [{'id': '4mOtRRwSoj', 'url': 'https://www.boar...
#
#    comment_count                                         commentary  \
# 0              0
# 1              0
# 2              0
# 3              0  <p>Fun fact: The largest game of Catan was hel...
# 4              0
#
#    cs_rating                                      description_y  \
# 0        NaN  <p>The classic game of German politics for 3 –...
# 1        4.6  <p><em>The year is 1336. Japan's emperor has l...
# 2        4.0  <p>This great card game is about planting, tra...
# 3        NaN  <p>The women and men of your expedition build ...
# 4        NaN  <p>Just south of nowhere, there’s the junction...
#
#                                  description_preview  \
# 0   The classic game of German politics for 3 – 5...
# 1    The year is 1336. Japan's emperor has lost a...
# 2   This great card game is about planting, tradi...
# 3   The women and men of your expedition build th...
# 4   Just south of nowhere, there’s the junction o...
#
#                                            designers developers discount  \
# 0  [{'id': 'JzHNgQv2Kn', 'num_games': None, 'scor...         []     0.00
# 1  [{'id': '6wbg6EN7xD', 'num_games': None, 'scor...         []     0.00
# 2  [{'id': 'T7EeH3OcxR', 'num_games': None, 'scor...         []    -0.25
# 3  [{'id': 'LCjyh7WnHd', 'num_games': None, 'scor...         []     0.29
# 4  [{'id': 'LCjyh7WnHd', 'num_games': None, 'scor...         []     0.00
#
#                                             edit_url faq  \
# 0  https://www.boardgameatlas.com/game/3hGLSZ61Yk...
# 1  https://www.boardgameatlas.com/game/uDl7CD01TP...
# 2  https://www.boardgameatlas.com/game/F1aw7kyGTA...
# 3  https://www.boardgameatlas.com/game/OIXt3DmJU0...
# 4  https://www.boardgameatlas.com/game/MJ7RmhalO3...
#
#                              handle  \
# 0  die-macher-international-edition
# 1                           samurai
# 2                          bohnanza
# 3                             catan
# 4                  wacky-wacky-west
#
#                                historical_low_prices          id  \
# 0  [{'country': 'US', 'date': '2022-03-05T03:33:2...  3hGLSZ61Yk
# 1  [{'country': 'US', 'date': '2021-09-02T17:40:3...  uDl7CD01TP
# 2  [{'country': 'UK', 'date': '2021-06-30T03:52:3...  F1aw7kyGTA
# 3  [{'country': 'AU', 'date': '2022-01-21T16:44:3...  OIXt3DmJU0
# 4  [{'country': 'CA', 'date': '2021-02-01T23:59:1...  MJ7RmhalO3
#
#                                            image_url  \
# 0  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 1  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 2  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 3  https://s3-us-west-1.amazonaws.com/5cc.images/...
# 4  https://s3-us-west-1.amazonaws.com/5cc.images/...
#
#                                               images  is_historical_low isbn  \
# 0  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...              False  NaN
# 1  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...              False  NaN
# 2  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...              False  NaN
# 3  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...              False  NaN
# 4  {'thumb': 'https://d2k4q26owzy373.cloudfront.n...              False  NaN
#
#    links  listing_clicks  lists matches_specs  max_players_y  max_playtime_y  \
# 0      0               0    265          None            5.0           240.0
# 1      1               0    416          None            4.0            60.0
# 2      6               0    888          None            7.0            60.0
# 3     24              12   1665          None            4.0            90.0
# 4      0               0     58          None            4.0            45.0
#
#                                            mechanics  mentions  min_age_y  \
# 0  [{'id': '9NBcz45nN7', 'url': 'https://www.boar...         2       14.0
# 1  [{'id': '9NBcz45nN7', 'url': 'https://www.boar...         0       10.0
# 2  [{'id': 'WPytek5P8l', 'url': 'https://www.boar...        20       13.0
# 3  [{'id': 'R0bGq4cAl4', 'url': 'https://www.boar...       120       10.0
# 4  [{'id': '8PN2HE86wg', 'url': 'https://www.boar...         0        9.0
#
#    min_players_y  min_playtime_y   msrp msrp_text  \
# 0            3.0           240.0     80    $80.00
# 1            2.0            30.0  49.95    $49.95
# 2            2.0            45.0  19.95    $19.95
# 3            3.0            45.0     55    $55.00
# 4            2.0            30.0      0       NaN
#
#                                                msrps names  num_distributors  \
# 0  [{'country': 'US', 'price': 80}, {'country': '...    []                 0
# 1  [{'country': 'US', 'price': 49.95}, {'country'...    []                 0
# 2  [{'country': 'US', 'price': 19.95}, {'country'...    []                 4
# 3  [{'country': 'CA', 'price': 0}, {'country': 'U...    []                 2
# 4  [{'country': 'US', 'price': 0}, {'country': 'C...    []                 0
#
#    num_user_complexity_votes  num_user_ratings  \
# 0                          0                46
# 1                          0               130
# 2                          2               348
# 3                         11               854
# 4                          0                 7
#
#                                         official_url players  plays playtime  \
# 0  https://www.kickstarter.com/projects/indiegame...     3-5    161      240
# 1  https://www.riograndegames.com/games.html?utm_...     2-4    651    30-60
# 2  http://riograndegames.com/Game/36-Bohnanza?utm...     2-7   2033    45-60
# 3  https://www.catan.com/?utm_source=boardgameatl...     3-4   5099    45-90
# 4  http://www.hans-im-glueck.de/drunterdrueber/?u...     2-4     30    30-45
#
#    price price_au price_ca  price_text price_uk  \
# 0   0.00     0.00     0.00  Price: N/A     0.00
# 1   0.00     0.00     0.00  Price: N/A     0.00
# 2  24.90    15.96    18.89      $24.90     0.00
# 3  39.19    52.00    36.97      $39.19    35.78
# 4   0.00     0.00     0.00  Price: N/A     0.00
#
#                                     primary_designer  \
# 0  {'id': 'JzHNgQv2Kn', 'name': 'Karl-Heinz Schmi...
# 1  {'id': '6wbg6EN7xD', 'name': 'Reiner Knizia', ...
# 2  {'id': 'T7EeH3OcxR', 'name': 'Uwe Rosenberg', ...
# 3  {'id': 'LCjyh7WnHd', 'name': 'Klaus Teuber', '...
# 4  {'id': 'LCjyh7WnHd', 'name': 'Klaus Teuber', '...
#
#                                    primary_publisher  \
# 0  {'id': 'M0j3iwMtqL', 'name': 'Hans im Glück', ...
# 1  {'id': 'M0j3iwMtqL', 'name': 'Hans im Glück', ...
# 2  {'id': 'oFIGIC4bxh', 'name': 'AMIGO', 'url': '...
# 3  {'id': 'RY4XltbNAz', 'name': 'KOSMOS', 'url': ...
# 4  {'id': 'M0j3iwMtqL', 'name': 'Hans im Glück', ...
#
#                                           publishers     rank related_to  \
# 0  [{'id': 'M0j3iwMtqL', 'num_games': None, 'scor...      872         []
# 1  [{'id': 'M0j3iwMtqL', 'num_games': None, 'scor...      342         []
# 2  [{'id': 'oFIGIC4bxh', 'num_games': None, 'scor...      103         []
# 3  [{'id': 'RY4XltbNAz', 'num_games': None, 'scor...       22         []
# 4  [{'id': 'M0j3iwMtqL', 'num_games': None, 'scor...  9999999         []
#
#                                            rules_url sell_sheet_url  \
# 0                                               None            NaN
# 1  https://www.riograndegames.com/getFile.php?id=134            NaN
# 2       http://riograndegames.com/getFile.php?id=535            NaN
# 3         https://www.catan.com/game/catan#prof-easy            NaN
# 4                                               None            NaN
#
#    size_depth  size_height size_units  size_width      sku  \
# 0         NaN          NaN        NaN         NaN      NaN
# 1         NaN          NaN        NaN         NaN      NaN
# 2         NaN          6.0        NaN         NaN   RIO155
# 3         3.0         11.6    inches          NaN  CNS3071
# 4         NaN          NaN        NaN         NaN      NaN
#
#                                          sku_objects  \
# 0  [{'name': 'Noble Knight Games', 'sku': '214926...
# 1  [{'name': 'Noble Knight Games', 'sku': '214897...
# 2  [{'name': 'Boarding School Games', 'sku': 'RGG...
# 3  [{'name': 'Boarding School Games', 'sku': 'CN3...
# 4                                                NaN
#
#                                                 skus specs store_images_url  \
# 0                           [2149268339, 2149203479]    []              NaN
# 1                           [2148978132, 2148698946]    []              NaN
# 2                              [RGG 155, 2149270748]    []              NaN
# 3  [CN3071, 2149146897, 2149270668, 2149187433, 2...    []              NaN
# 4                                                NaN    []              NaN
#
#                                                 tags  \
# 0                                 [德国大选, Die Macher]
# 1                                          [Samurai]
# 2  [Babszüret, Bohnanza Pocket-Version, Bohnanza ...
# 3  [Die Siedler von Catan , Les Colons de Catane,...
# 4  [Drunter & Drüber, Sans dessus dessous, Wacky ...
#
#                                            thumb_url  trending_rank  type  \
# 0  https://s3-us-west-1.amazonaws.com/5cc.images/...              0  game
# 1  https://s3-us-west-1.amazonaws.com/5cc.images/...              0  game
# 2  https://s3-us-west-1.amazonaws.com/5cc.images/...              0  game
# 3  https://cdn.shopify.com/s/files/1/0513/4077/15...              0  game
# 4  https://s3-us-west-1.amazonaws.com/5cc.images/...              0  game
#
#             upc                                                url  \
# 0           NaN  https://www.boardgameatlas.com/game/3hGLSZ61Yk...
# 1           NaN  https://www.boardgameatlas.com/game/uDl7CD01TP...
# 2  655132001557  https://www.boardgameatlas.com/game/F1aw7kyGTA...
# 3  029877030712  https://www.boardgameatlas.com/game/OIXt3DmJU0...
# 4           NaN  https://www.boardgameatlas.com/game/MJ7RmhalO3...
#
#   video_links  visits  weight_amount weight_units
# 0         NaN     737            NaN          NaN
# 1         NaN    1457            NaN          NaN
# 2         NaN    2564            NaN          NaN
# 3         NaN    7118            2.0         lbs
# 4         NaN     132            NaN          NaN

# %%
len(united_df)
# Out:
# 1333

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

def fuzzy_merge(df_1, df_2, key1, key2, threshold=90, limit=2):
    s = df_2[key2].tolist()
    
    m = df_1[key1].apply(lambda x: process.extract(x, s, limit=limit))    
    df_1['matches'] = m
    
    m2 = df_1['matches'].apply(lambda x: ', '.join([i[0] for i in x if i[1] >= threshold]))
    df_1['matches'] = m2
    
    return df_1

fuzzy_merge(board_games, board_games_api, 'name', 'name', threshold=99)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\fuzzywuzzy\process.py in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     107         # See if choices is a dictionary-like object.
# --> 108         for key, choice in choices.items():
#     109             processed = pre_processor(processor(choice))
#
# AttributeError: 'list' object has no attribute 'items'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-183-306b23ee43fe> in <module>
#      13     return df_1
#      14
# ---> 15 fuzzy_merge(board_games, board_games_api, 'name', 'name', threshold=99)
#
# <ipython-input-183-306b23ee43fe> in fuzzy_merge(df_1, df_2, key1, key2, threshold, limit)
#       5     s = df_2[key2].tolist()
#       6
# ----> 7     m = df_1[key1].apply(lambda x: process.extract(x, s, limit=limit))
#       8     df_1['matches'] = m
#       9
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-183-306b23ee43fe> in <lambda>(x)
#       5     s = df_2[key2].tolist()
#       6
# ----> 7     m = df_1[key1].apply(lambda x: process.extract(x, s, limit=limit))
#       8     df_1['matches'] = m
#       9
#
# ~\Anaconda3\lib\site-packages\fuzzywuzzy\process.py in extract(query, choices, processor, scorer, limit)
#     166     """
#     167     sl = extractWithoutOrder(query, choices, processor, scorer)
# --> 168     return heapq.nlargest(limit, sl, key=lambda i: i[1]) if limit is not None else \
#     169         sorted(sl, key=lambda i: i[1], reverse=True)
#     170
#
# ~\Anaconda3\lib\heapq.py in nlargest(n, iterable, key)
#     574     order = -n
#     575     _heapreplace = heapreplace
# --> 576     for elem in it:
#     577         k = key(elem)
#     578         if top < k:
#
# ~\Anaconda3\lib\site-packages\fuzzywuzzy\process.py in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     114         # It's a list; just iterate over it.
#     115         for choice in choices:
# --> 116             processed = pre_processor(processor(choice))
#     117             score = scorer(processed_query, processed)
#     118             if score >= score_cutoff:
#
# ~\Anaconda3\lib\site-packages\fuzzywuzzy\utils.py in full_process(s, force_ascii)
#      91
#      92     if force_ascii:
# ---> 93         s = asciidammit(s)
#      94     # Keep only Letters and Numbers (see Unicode docs).
#      95     string_out = StringProcessor.replace_non_letters_non_numbers_with_whitespace(s)
#
# ~\Anaconda3\lib\site-packages\fuzzywuzzy\utils.py in asciidammit(s)
#      64 def asciidammit(s):
#      65     if type(s) is str:
# ---> 66         return asciionly(s)
#      67     elif type(s) is unicode:
#      68         return asciionly(s.encode('ascii', 'ignore'))
#
# KeyboardInterrupt:
